# %% [markdown]
# # Point Process with detection threshold = 3

# %%
import glob
from NewLibraryENGcopia import *
finaldf=[]
output_path='/Users/Gaia_1/Desktop/Data after SS thresh 3'
list_dir=glob.glob(output_path+"/*")
counter=0
for file in tqdm(list_dir):
    file_name = file.split("/")[-1]
    target=1
    stim=0
    if 'health' in file_name:
        target=0
    if 'after' in file_name:
        stim=1
    counter+=1
    df=this_poiproc(file,target,stim)
    finaldf.append(df)
print(counter)
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]
# /Users/Gaia_1/Desktop/Data after SS thresh 3/After2019-01-23T11-41-41Pop1 healthy cortical .h5.txt.txt target 0 stimulation 0
# Original number of neurons:  58
#   0%|          | 0/58 [00:00<?, ?it/s]
#   Neuron with  5926 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='43' class='' max='43' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [43/43 00:00&lt;00:00 logp = 14,556, ||grad|| = 0.14604]
#     </div>
# ks score:  0.03734232363403378
# {'mu1': array(0.029824), 'lam1': array(0.02344159), 'mu2': array(0.04575836), 'sigma2': array(0.02679697), 'mu3': array(0.32379425), 'sigma3': array(0.3818979), 'w1': 0.7881144558443689, 'w2': 0.21188553729181878, 'w3': 6.8638123477722455e-09}
#   Neuron with  6036 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='42' class='' max='42' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [42/42 00:00&lt;00:00 logp = 14,928, ||grad|| = 1.5422]
#     </div>
# ks score:  0.037721630154654295
# {'mu1': array(0.02845293), 'lam1': array(0.02263208), 'mu2': array(0.04559539), 'sigma2': array(0.02791904), 'mu3': array(0.3396322), 'sigma3': array(0.3827521), 'w1': 0.7685962309963755, 'w2': 0.23140373815017046, 'w3': 3.0853454059829766e-08}
#   Neuron with  6007 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='42' class='' max='42' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [42/42 00:00&lt;00:00 logp = 14,826, ||grad|| = 0.013508]
#     </div>
# ks score:  0.04855040260014992
# {'mu1': array(0.02869722), 'lam1': array(0.02382375), 'mu2': array(0.04582527), 'sigma2': array(0.03043222), 'mu3': array(0.33585788), 'sigma3': array(0.37818463), 'w1': 0.7840698958313935, 'w2': 0.21593009403220623, 'w3': 1.0136400292153748e-08}
#   Neuron with  5972 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='49' class='' max='49' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [49/49 00:00&lt;00:00 logp = 14,723, ||grad|| = 0.42028]
#     </div>
# ks score:  0.031006784357154094
# {'mu1': array(0.03075029), 'lam1': array(0.02324133), 'mu2': array(0.04411486), 'sigma2': array(0.02305709), 'mu3': array(0.32557158), 'sigma3': array(0.37423548), 'w1': 0.8156733987528116, 'w2': 0.18432658305162805, 'w3': 1.8195560234005175e-08}
#   Neuron with  6066 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='46' class='' max='46' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [46/46 00:00&lt;00:00 logp = 15,056, ||grad|| = 0.25602]
#     </div>
# ks score:  0.02541784513595685
# {'mu1': array(0.03004105), 'lam1': array(0.0225328), 'mu2': array(0.04501127), 'sigma2': array(0.02135587), 'mu3': array(0.32317789), 'sigma3': array(0.38885576), 'w1': 0.8156556024036693, 'w2': 0.1843443927097221, 'w3': 4.886608518406856e-09}
#   Neuron with  4165 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='39' class='' max='39' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [39/39 00:00&lt;00:00 logp = 8,657.1, ||grad|| = 1.8309]
#     </div>
# ks score:  0.06201303123618568
# {'mu1': array(0.0402467), 'lam1': array(0.02574417), 'mu2': array(0.05457426), 'sigma2': array(0.04735745), 'mu3': array(0.33941941), 'sigma3': array(0.31258671), 'w1': 0.6946372968666773, 'w2': 0.3053626956946371, 'w3': 7.4386854729585595e-09}
#   Neuron with  3149 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='38' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [38/38 00:00&lt;00:00 logp = 5,613.8, ||grad|| = 0.32342]
#     </div>
# ks score:  0.10880280572550627
# {'mu1': array(0.05475872), 'lam1': array(0.02683123), 'mu2': array(0.05025119), 'sigma2': array(0.06533463), 'mu3': array(0.31070291), 'sigma3': array(0.18807531), 'w1': 0.5707498300415473, 'w2': 0.4292501312633269, 'w3': 3.8695125696358736e-08}
#   Neuron with  4368 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='38' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [38/38 00:00&lt;00:00 logp = 9,314.5, ||grad|| = 0.87505]
#     </div>
# ks score:  0.048416270558306496
# {'mu1': array(0.0390311), 'lam1': array(0.0259437), 'mu2': array(0.05602405), 'sigma2': array(0.04061247), 'mu3': array(0.33779469), 'sigma3': array(0.32033202), 'w1': 0.7167845720602453, 'w2': 0.2832154227040939, 'w3': 5.235660944394536e-09}
#   Neuron with  3281 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40' class='' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40/40 00:00&lt;00:00 logp = 5,980.1, ||grad|| = 0.25142]
#     </div>
# ks score:  0.08107980079125399
# {'mu1': array(0.05331076), 'lam1': array(0.0248073), 'mu2': array(0.05945911), 'sigma2': array(0.05363242), 'mu3': array(0.31928077), 'sigma3': array(0.24802298), 'w1': 0.607871733777637, 'w2': 0.39212821005357595, 'w3': 5.61687871515227e-08}
#   Neuron with  4159 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40' class='' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40/40 00:00&lt;00:00 logp = 8,634.5, ||grad|| = 0.066145]
#     </div>
# ks score:  0.0713873501180492
# {'mu1': array(0.03939991), 'lam1': array(0.0253171), 'mu2': array(0.05421473), 'sigma2': array(0.04918776), 'mu3': array(0.341445), 'sigma3': array(0.30937013), 'w1': 0.6808348409096301, 'w2': 0.3191651366885802, 'w3': 2.2401789650100216e-08}
#   Neuron with  2650 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='36' class='' max='36' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [36/36 00:00&lt;00:00 logp = 4,246.1, ||grad|| = 0.33961]
#     </div>
# ks score:  0.2622714484314058
# {'mu1': array(0.059845), 'lam1': array(0.02851939), 'mu2': array(0.00121339), 'sigma2': array(0.11248597), 'mu3': array(0.3225267), 'sigma3': array(0.16033881), 'w1': 0.48512031779403825, 'w2': 0.5148503561572226, 'w3': 2.9326048739114056e-05}
#   Neuron with  2571 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='43' class='' max='43' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [43/43 00:00&lt;00:00 logp = 4,034.7, ||grad|| = 0.019356]
#     </div>
# ks score:  0.31015734031705877
# {'mu1': array(0.0596111), 'lam1': array(0.02935776), 'mu2': array(9.56875951e-07), 'sigma2': array(0.11240654), 'mu3': array(0.27777521), 'sigma3': array(0.0736478), 'w1': 0.3948150877488159, 'w2': 0.6051849093042535, 'w3': 2.946930574370572e-09}
#   Neuron with  2354 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='98' class='' max='98' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [98/98 00:00&lt;00:00 logp = 3,508.7, ||grad|| = 11.671]
#     </div>
# ks score:  0.04729861414182593
# {'mu1': array(0.05937109), 'lam1': array(0.02725679), 'mu2': array(0.06841025), 'sigma2': array(0.04865469), 'mu3': array(0.20000007), 'sigma3': array(0.08329834), 'w1': 0.46055354389834957, 'w2': 0.4070915971217682, 'w3': 0.1323548589798823}
#   Neuron with  2338 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='59' class='' max='59' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [59/59 00:00&lt;00:00 logp = 3,445.1, ||grad|| = 11.928]
#     </div>
# ks score:  0.32599685536792095
# {'mu1': array(0.0687459), 'lam1': array(0.02848499), 'mu2': array(4.94785903e-05), 'sigma2': array(0.11389856), 'mu3': array(0.31093278), 'sigma3': array(0.02141465), 'w1': 0.35352858774354307, 'w2': 0.6366485724984563, 'w3': 0.009822839758000728}
#   Neuron with  2083 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='90' class='' max='90' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [90/90 00:00&lt;00:00 logp = 2,836.7, ||grad|| = 0.18699]
#     </div>
# ks score:  0.07133080573025677
# {'mu1': array(0.07113781), 'lam1': array(0.02442839), 'mu2': array(0.07026098), 'sigma2': array(0.05774096), 'mu3': array(0.20000028), 'sigma3': array(0.07881615), 'w1': 0.38322438188840463, 'w2': 0.4655018494692323, 'w3': 0.15127376864236297}
#   Neuron with  2285 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='98' class='' max='98' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [98/98 00:00&lt;00:00 logp = 3,327.8, ||grad|| = 0.070129]
#     </div>
# ks score:  0.12254872861147875
# {'mu1': array(0.05839424), 'lam1': array(0.02779929), 'mu2': array(0.06203873), 'sigma2': array(0.07530477), 'mu3': array(0.20000138), 'sigma3': array(0.12202263), 'w1': 0.4018676162796213, 'w2': 0.5107084786942986, 'w3': 0.08742390502608005}
#   Neuron with  2342 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='106' class='' max='106' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [106/106 00:01&lt;00:00 logp = 3,463, ||grad|| = 0.064299]
#     </div>
# ks score:  0.09113994462079011
# {'mu1': array(0.06320858), 'lam1': array(0.02758462), 'mu2': array(0.0565923), 'sigma2': array(0.05517835), 'mu3': array(0.20000007), 'sigma3': array(0.08447684), 'w1': 0.39359431250747123, 'w2': 0.47485310759500315, 'w3': 0.13155257989752558}
#   Neuron with  2557 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='133' class='' max='133' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [133/133 00:01&lt;00:00 logp = 4,020.5, ||grad|| = 0.074556]
#     </div>
# ks score:  0.08719360797398865
# {'mu1': array(0.05460271), 'lam1': array(0.02576088), 'mu2': array(0.05841807), 'sigma2': array(0.05530171), 'mu3': array(0.20001081), 'sigma3': array(0.083437), 'w1': 0.43409067644046706, 'w2': 0.46427831020794635, 'w3': 0.10163101335158661}
#   Neuron with  2489 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='103' class='' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [103/103 00:00&lt;00:00 logp = 3,831, ||grad|| = 0.20527]
#     </div>
# ks score:  0.11514733962461915
# {'mu1': array(0.05162232), 'lam1': array(0.0233786), 'mu2': array(0.05341321), 'sigma2': array(0.06019941), 'mu3': array(0.20001181), 'sigma3': array(0.09953056), 'w1': 0.3456003952740569, 'w2': 0.5430602649430919, 'w3': 0.1113393397828513}
#   Neuron with  2366 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='107' class='' max='107' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [107/107 00:01&lt;00:00 logp = 3,543.6, ||grad|| = 0.38381]
#     </div>
# ks score:  0.043273633816291124
# {'mu1': array(0.06574781), 'lam1': array(0.03058193), 'mu2': array(0.06954712), 'sigma2': array(0.0483895), 'mu3': array(0.20000008), 'sigma3': array(0.06384204), 'w1': 0.5009677727287015, 'w2': 0.3909341692724104, 'w3': 0.10809805799888807}
#   Neuron with  3325 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='46' class='' max='46' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [46/46 00:00&lt;00:00 logp = 6,104.6, ||grad|| = 0.13404]
#     </div>
# ks score:  0.1613738802162324
# {'mu1': array(0.05126778), 'lam1': array(0.02826396), 'mu2': array(0.03007902), 'sigma2': array(0.07585695), 'mu3': array(0.32376705), 'sigma3': array(0.2017418), 'w1': 0.5880995661538021, 'w2': 0.41190039889872654, 'w3': 3.4947471475546256e-08}
#   Neuron with  3052 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='48' class='' max='48' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [48/48 00:00&lt;00:00 logp = 5,340, ||grad|| = 1.6336]
#     </div>
# ks score:  0.21150921445598225
# {'mu1': array(0.05145989), 'lam1': array(0.02905067), 'mu2': array(0.01480813), 'sigma2': array(0.09530297), 'mu3': array(0.3198051), 'sigma3': array(0.16280838), 'w1': 0.5345288380124188, 'w2': 0.4654700920861704, 'w3': 1.0699014107471192e-06}
#   Neuron with  3285 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40' class='' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40/40 00:00&lt;00:00 logp = 6,003.1, ||grad|| = 0.22609]
#     </div>
# ks score:  0.15345755690860444
# {'mu1': array(0.04771837), 'lam1': array(0.02670891), 'mu2': array(0.0374487), 'sigma2': array(0.07701054), 'mu3': array(0.31656415), 'sigma3': array(0.22078673), 'w1': 0.5555074532961605, 'w2': 0.44449252210282064, 'w3': 2.4601018772007698e-08}
#   Neuron with  3541 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40' class='' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40/40 00:00&lt;00:00 logp = 6,751.7, ||grad|| = 0.21178]
#     </div>
# ks score:  0.10324521264098271
# {'mu1': array(0.04592071), 'lam1': array(0.02751988), 'mu2': array(0.04944892), 'sigma2': array(0.06454482), 'mu3': array(0.3583868), 'sigma3': array(0.16707504), 'w1': 0.6255239574348639, 'w2': 0.37447602205159164, 'w3': 2.0513544626293264e-08}
#   Neuron with  5142 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='37' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:00&lt;00:00 logp = 11,824, ||grad|| = 0.71863]
#     </div>
# ks score:  0.04331939452443445
# {'mu1': array(0.03465279), 'lam1': array(0.0234426), 'mu2': array(0.04830201), 'sigma2': array(0.03060118), 'mu3': array(0.33722854), 'sigma3': array(0.35186758), 'w1': 0.7555699610041124, 'w2': 0.2444300309017447, 'w3': 8.094142945163463e-09}
#   Neuron with  5174 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='42' class='' max='42' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [42/42 00:00&lt;00:00 logp = 11,924, ||grad|| = 0.73385]
#     </div>
# ks score:  0.053283929792034224
# {'mu1': array(0.03380466), 'lam1': array(0.02411004), 'mu2': array(0.04755661), 'sigma2': array(0.03641034), 'mu3': array(0.35277852), 'sigma3': array(0.33203916), 'w1': 0.7643459332865296, 'w2': 0.23565405923348157, 'w3': 7.479988919604994e-09}
#   Neuron with  5206 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40' class='' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40/40 00:00&lt;00:00 logp = 12,053, ||grad|| = 0.35777]
#     </div>
# ks score:  0.03667512295564135
# {'mu1': array(0.03349552), 'lam1': array(0.02333384), 'mu2': array(0.05092508), 'sigma2': array(0.0307684), 'mu3': array(0.33414439), 'sigma3': array(0.38070285), 'w1': 0.7624962794164611, 'w2': 0.23750360825406183, 'w3': 1.1232947700833317e-07}
#   Neuron with  5143 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='38' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [38/38 00:00&lt;00:00 logp = 11,822, ||grad|| = 0.36861]
#     </div>
# ks score:  0.04463840939810759
# {'mu1': array(0.03430628), 'lam1': array(0.023586), 'mu2': array(0.04856073), 'sigma2': array(0.03127617), 'mu3': array(0.34158519), 'sigma3': array(0.34866981), 'w1': 0.7488722519570182, 'w2': 0.25112771594856204, 'w3': 3.2094419744920724e-08}
#   Neuron with  5087 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='43' class='' max='43' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [43/43 00:00&lt;00:00 logp = 11,646, ||grad|| = 0.026388]
#     </div>
# ks score:  0.04569671810611342
# {'mu1': array(0.03525105), 'lam1': array(0.02521407), 'mu2': array(0.04847978), 'sigma2': array(0.03122276), 'mu3': array(0.34658432), 'sigma3': array(0.34813828), 'w1': 0.7638155994769862, 'w2': 0.23618439267707297, 'w3': 7.845940842586046e-09}
#   Neuron with  5143 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='38' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [38/38 00:00&lt;00:00 logp = 11,834, ||grad|| = 0.90413]
#     </div>
# ks score:  0.042285183268100546
# {'mu1': array(0.0344726), 'lam1': array(0.02438264), 'mu2': array(0.04972027), 'sigma2': array(0.03152137), 'mu3': array(0.33933836), 'sigma3': array(0.3577952), 'w1': 0.7685963764758453, 'w2': 0.231403617163329, 'w3': 6.360825758085114e-09}
#   Neuron with  5173 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='44' class='' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44/44 00:00&lt;00:00 logp = 11,934, ||grad|| = 0.023577]
#     </div>
# ks score:  0.03855633705609485
# {'mu1': array(0.03454263), 'lam1': array(0.02396713), 'mu2': array(0.05079602), 'sigma2': array(0.02985069), 'mu3': array(0.33592082), 'sigma3': array(0.36596918), 'w1': 0.7849583033613609, 'w2': 0.21504168351659803, 'w3': 1.312204108179166e-08}
#   Neuron with  3742 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='42' class='' max='42' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [42/42 00:00&lt;00:00 logp = 7,347.7, ||grad|| = 0.030027]
#     </div>
# ks score:  0.1033314250692281
# {'mu1': array(0.04444733), 'lam1': array(0.02794096), 'mu2': array(0.04579635), 'sigma2': array(0.0608882), 'mu3': array(0.33603328), 'sigma3': array(0.25216527), 'w1': 0.6398860874877733, 'w2': 0.3601139061517983, 'w3': 6.3604283222673e-09}
#   Neuron with  5167 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='39' class='' max='39' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [39/39 00:00&lt;00:00 logp = 11,902, ||grad|| = 0.26516]
#     </div>
# ks score:  0.04658371533405997
# {'mu1': array(0.03391267), 'lam1': array(0.02369103), 'mu2': array(0.04799772), 'sigma2': array(0.03229898), 'mu3': array(0.34705809), 'sigma3': array(0.34779745), 'w1': 0.7435417138904733, 'w2': 0.2564582790942286, 'w3': 7.015298097462112e-09}
#   Neuron with  5180 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='38' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [38/38 00:00&lt;00:00 logp = 11,950, ||grad|| = 0.28921]
#     </div>
# ks score:  0.03897006080095278
# {'mu1': array(0.03390863), 'lam1': array(0.02294291), 'mu2': array(0.04755757), 'sigma2': array(0.02979269), 'mu3': array(0.33725875), 'sigma3': array(0.36053887), 'w1': 0.7262872804874204, 'w2': 0.27371271264924096, 'w3': 6.8633386214732385e-09}
#   Neuron with  5238 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='37' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:00&lt;00:00 logp = 12,175, ||grad|| = 0.24779]
#     </div>
# ks score:  0.03474140284305188
# {'mu1': array(0.03423227), 'lam1': array(0.0243617), 'mu2': array(0.04931707), 'sigma2': array(0.02875091), 'mu3': array(0.33818673), 'sigma3': array(0.35262892), 'w1': 0.778923099723362, 'w2': 0.22107689221441545, 'w3': 8.06222239381663e-09}
#   Neuron with  3485 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='37' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:00&lt;00:00 logp = 6,568.4, ||grad|| = 0.1089]
#     </div>
# ks score:  0.11722631473619022
# {'mu1': array(0.04860023), 'lam1': array(0.02638932), 'mu2': array(0.04660135), 'sigma2': array(0.06190624), 'mu3': array(0.34120058), 'sigma3': array(0.16982363), 'w1': 0.6007862737957622, 'w2': 0.39921368193037665, 'w3': 4.427386100294939e-08}
#   Neuron with  3240 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='32' class='' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [32/32 00:00&lt;00:00 logp = 5,879.7, ||grad|| = 0.41547]
#     </div>
# ks score:  0.08620660456413001
# {'mu1': array(0.05322208), 'lam1': array(0.02963754), 'mu2': array(0.05547331), 'sigma2': array(0.06261281), 'mu3': array(0.34142027), 'sigma3': array(0.23470169), 'w1': 0.6320962079891652, 'w2': 0.3679033770673205, 'w3': 4.149435142372819e-07}
#   Neuron with  3415 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='35' class='' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [35/35 00:00&lt;00:00 logp = 6,365.9, ||grad|| = 0.67364]
#     </div>
# ks score:  0.10516344940356853
# {'mu1': array(0.05146977), 'lam1': array(0.02571436), 'mu2': array(0.04751396), 'sigma2': array(0.05707032), 'mu3': array(0.32155337), 'sigma3': array(0.15960405), 'w1': 0.5640813677357845, 'w2': 0.43591860609876065, 'w3': 2.616545489523526e-08}
#   Neuron with  3256 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='44' class='' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44/44 00:00&lt;00:00 logp = 5,917.9, ||grad|| = 0.093918]
#     </div>
# ks score:  0.14024070389416526
# {'mu1': array(0.05188331), 'lam1': array(0.02964975), 'mu2': array(0.03977896), 'sigma2': array(0.07199044), 'mu3': array(0.3183094), 'sigma3': array(0.1715115), 'w1': 0.5788718327731098, 'w2': 0.42112814074919164, 'w3': 2.6477698404106072e-08}
#   Neuron with  2667 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='43' class='' max='43' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [43/43 00:00&lt;00:00 logp = 4,282.8, ||grad|| = 0.053054]
#     </div>
# ks score:  0.32653912425594717
# {'mu1': array(0.05493006), 'lam1': array(0.02495027), 'mu2': array(3.15447317e-05), 'sigma2': array(0.10844514), 'mu3': array(0.31449303), 'sigma3': array(0.17651042), 'w1': 0.3652550371537422, 'w2': 0.634744416058392, 'w3': 5.467878657545359e-07}
#   Neuron with  2235 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='96' class='' max='96' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [96/96 00:00&lt;00:00 logp = 3,206.3, ||grad|| = 1.6095]
#     </div>
# ks score:  0.08281457191605893
# {'mu1': array(0.05727962), 'lam1': array(0.02797384), 'mu2': array(0.06424798), 'sigma2': array(0.06051098), 'mu3': array(0.2001849), 'sigma3': array(0.09895394), 'w1': 0.3832566500265774, 'w2': 0.4719088036742876, 'w3': 0.1448345462991351}
#   Neuron with  2386 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='46' class='' max='46' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [46/46 00:00&lt;00:00 logp = 3,568.4, ||grad|| = 0.065692]
#     </div>
# ks score:  0.2814178649874096
# {'mu1': array(0.06075939), 'lam1': array(0.02972563), 'mu2': array(2.7811995e-07), 'sigma2': array(0.12908849), 'mu3': array(0.2530688), 'sigma3': array(0.02074241), 'w1': 0.4497542112833291, 'w2': 0.5502457815078664, 'w3': 7.208804446076568e-09}
#   Neuron with  2567 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='99' class='' max='99' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [99/99 00:00&lt;00:00 logp = 4,037.9, ||grad|| = 0.36642]
#     </div>
# ks score:  0.2832581038893118
# {'mu1': array(0.05223599), 'lam1': array(0.03516071), 'mu2': array(6.21473327e-05), 'sigma2': array(0.09514429), 'mu3': array(0.20024198), 'sigma3': array(0.10928823), 'w1': 0.3739422172521517, 'w2': 0.5465061418839222, 'w3': 0.07955164086392591}
#   Neuron with  2297 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='123' class='' max='123' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [123/123 00:01&lt;00:00 logp = 3,352.7, ||grad|| = 0.010961]
#     </div>
# ks score:  0.08471641790961287
# ...
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='91' class='' max='91' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [91/91 00:01&lt;00:00 logp = 2,676.3, ||grad|| = 0.0072387]
#     </div>
# ks score:  0.32523947007359627
# {'mu1': array(0.06811082), 'lam1': array(0.02946097), 'mu2': array(3.39067603e-06), 'sigma2': array(0.10487805), 'mu3': array(0.20008122), 'sigma3': array(0.13826158), 'w1': 0.2490944824388235, 'w2': 0.6140927934439834, 'w3': 0.1368127241171932}
#   Neuron with  2035 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='99' class='' max='99' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [99/99 00:01&lt;00:00 logp = 2,718.9, ||grad|| = 10.558]
#     </div>
# ks score:  0.10682164896818472
# {'mu1': array(0.05915565), 'lam1': array(0.02757607), 'mu2': array(0.06008517), 'sigma2': array(0.06490417), 'mu3': array(0.20001576), 'sigma3': array(0.13335957), 'w1': 0.34511759145709114, 'w2': 0.4709509977736792, 'w3': 0.1839314107692296}
#   Neuron with  2223 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='145' class='' max='145' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [145/145 00:02&lt;00:00 logp = 3,187.1, ||grad|| = 0.26506]
#     </div>
# ks score:  0.06781572898555263
# {'mu1': array(0.05412585), 'lam1': array(0.02766118), 'mu2': array(0.06886384), 'sigma2': array(0.05456048), 'mu3': array(0.20000058), 'sigma3': array(0.09498529), 'w1': 0.3727561021660279, 'w2': 0.4680682223628456, 'w3': 0.15917567547112663}
#   Neuron with  2192 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='111' class='' max='111' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [111/111 00:01&lt;00:00 logp = 3,092.6, ||grad|| = 0.015671]
#     </div>
# ks score:  0.19062526110817388
# {'mu1': array(0.05869042), 'lam1': array(0.03437862), 'mu2': array(0.03618633), 'sigma2': array(0.08689959), 'mu3': array(0.20000179), 'sigma3': array(0.12245542), 'w1': 0.3533563017074186, 'w2': 0.5223577452276839, 'w3': 0.12428595306489752}
#   Neuron with  2189 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='102' class='' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [102/102 00:01&lt;00:00 logp = 3,093, ||grad|| = 0.54877]
#     </div>
# ks score:  0.09481749580995538
# {'mu1': array(0.07144854), 'lam1': array(0.02921211), 'mu2': array(0.06366769), 'sigma2': array(0.06562667), 'mu3': array(0.20000282), 'sigma3': array(0.08445153), 'w1': 0.3944515506001403, 'w2': 0.4977268527034633, 'w3': 0.10782159669639638}
#   Neuron with  2247 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='54' class='' max='54' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [54/54 00:00&lt;00:00 logp = 3,221.4, ||grad|| = 0.69074]
#     </div>
# ks score:  0.34645058629205977
# {'mu1': array(0.07004415), 'lam1': array(0.0271716), 'mu2': array(3.72222613e-05), 'sigma2': array(0.10353501), 'mu3': array(0.27844733), 'sigma3': array(0.06633046), 'w1': 0.27734706419669797, 'w2': 0.6753574551709554, 'w3': 0.0472954806323467}
#   Neuron with  2204 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='94' class='' max='94' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [94/94 00:01&lt;00:00 logp = 3,121.9, ||grad|| = 0.047789]
#     </div>
# ks score:  0.32361572394479204
# {'mu1': array(0.05929032), 'lam1': array(0.03559429), 'mu2': array(2.44554989e-07), 'sigma2': array(0.10925374), 'mu3': array(0.20001123), 'sigma3': array(0.14160755), 'w1': 0.29586402568034953, 'w2': 0.6191032688796329, 'w3': 0.08503270544001768}
#   Neuron with  2451 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='126' class='' max='126' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [126/126 00:01&lt;00:00 logp = 3,747.3, ||grad|| = 0.05129]
#     </div>
# ks score:  0.09222003928568126
# {'mu1': array(0.05763683), 'lam1': array(0.02977092), 'mu2': array(0.06016935), 'sigma2': array(0.06312875), 'mu3': array(0.20000039), 'sigma3': array(0.08744393), 'w1': 0.46216237769118423, 'w2': 0.43809649343073886, 'w3': 0.09974112887807694}
#   Neuron with  2390 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='121' class='' max='121' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [121/121 00:01&lt;00:00 logp = 3,595.3, ||grad|| = 0.019726]
#     </div>
# ks score:  0.07364854661302303
# {'mu1': array(0.05818012), 'lam1': array(0.02698351), 'mu2': array(0.06297319), 'sigma2': array(0.05422192), 'mu3': array(0.2000002), 'sigma3': array(0.07418977), 'w1': 0.42931523287897905, 'w2': 0.4459428742269867, 'w3': 0.12474189289403437}
#   Neuron with  2656 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='35' class='' max='35' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [35/35 00:00&lt;00:00 logp = 4,279.2, ||grad|| = 0.084062]
#     </div>
# ks score:  0.1739885434095489
# {'mu1': array(0.06002584), 'lam1': array(0.02907011), 'mu2': array(0.03930382), 'sigma2': array(0.09362729), 'mu3': array(0.32330386), 'sigma3': array(0.17892853), 'w1': 0.5059144750421362, 'w2': 0.49407631739391994, 'w3': 9.207563943775528e-06}
#   Neuron with  2990 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='45' class='' max='45' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [45/45 00:00&lt;00:00 logp = 5,175.7, ||grad|| = 0.042093]
#     </div>
# ks score:  0.19395274727559364
# {'mu1': array(0.05061123), 'lam1': array(0.02663499), 'mu2': array(0.02277758), 'sigma2': array(0.096983), 'mu3': array(0.30913754), 'sigma3': array(0.17516955), 'w1': 0.5435819957527338, 'w2': 0.4564178426024155, 'w3': 1.61644850539903e-07}
#   Neuron with  2994 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='37' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:00&lt;00:00 logp = 5,177.4, ||grad|| = 0.1479]
#     </div>
# ks score:  0.113175612079367
# {'mu1': array(0.05755447), 'lam1': array(0.02815481), 'mu2': array(0.05239215), 'sigma2': array(0.06944188), 'mu3': array(0.31446553), 'sigma3': array(0.16610706), 'w1': 0.5760423214015247, 'w2': 0.4239575157566923, 'w3': 1.6284178299071877e-07}
#   Neuron with  2799 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='37' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:00&lt;00:00 logp = 4,637.3, ||grad|| = 0.93669]
#     </div>
# ks score:  0.2844501280143369
# {'mu1': array(0.05325177), 'lam1': array(0.0310826), 'mu2': array(1.18853575e-06), 'sigma2': array(0.1081915), 'mu3': array(0.32182907), 'sigma3': array(0.14587216), 'w1': 0.4454839467889815, 'w2': 0.5545158960863763, 'w3': 1.5712464228945133e-07}
#   Neuron with  2831 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='37' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:00&lt;00:00 logp = 4,728.3, ||grad|| = 0.3563]
#     </div>
# ks score:  0.28256157422944467
# {'mu1': array(0.048758), 'lam1': array(0.02628021), 'mu2': array(7.07838592e-07), 'sigma2': array(0.11134069), 'mu3': array(0.30557247), 'sigma3': array(0.10052689), 'w1': 0.45136559540170607, 'w2': 0.5486341511444847, 'w3': 2.5345380922774025e-07}
#   Neuron with  2427 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='41' class='' max='41' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [41/41 15:44&lt;00:00 logp = 3,675.1, ||grad|| = 0.023786]
#     </div>
# ks score:  0.298287587886818
# {'mu1': array(0.06197436), 'lam1': array(0.03444689), 'mu2': array(1.40732906e-06), 'sigma2': array(0.12174515), 'mu3': array(0.30960961), 'sigma3': array(0.14541209), 'w1': 0.4159089605790638, 'w2': 0.5840907818848056, 'w3': 2.5753613075921745e-07}
# Final number of neurons:  46
# Target =  0
# 17

# %%
import glob
list_dir=glob.glob("/Users/Gaia_1/Desktop/Data after SS thresh 3/*.txt")
for file in list_dir:
    print(file)
print(len(list_dir))

# %%
from NewLibraryENGcopia import *
import glob
finaldf=[]
output_path='/Users/Gaia_1/Desktop/Data after SS thresh 3'
list_dir=glob.glob(output_path+"/*")
file1=list_dir[1]
file2=list_dir[6]
print(file1)
print(file2)
#for file in list_dir:
target=1
stim=0
if 'health' in file:
    target=0
if 'stimulation' in file:
    stim=1

#df=this_poiproc(file,target,stim)
#finaldf.append(df)
# Out:
# /Users/Gaia_1/Desktop/Data after SS thresh 3/After2018-11-28T11-29-05MIP 5 KA 24hrs after.h5.txt.txt
# /Users/Gaia_1/Desktop/Data after SS thresh 3/After2018-11-27T10-03-29MIP4 BL .h5.txt.txt

# %%
file

# %%
#file='/Users/Gaia_1/Desktop/Data after SS thresh 3/After2018-11-27T10-03-29MIP4 BL .h5.txt.txt'
#file=list_dir[3]
list_neurons = np.genfromtxt(file1, delimiter=',')
neuron=list_neurons[0]
neuron=neuron[neuron>0]
neuron=neuron[neuron<200*10000]
ISI_healthy1=np.diff(neuron)/10000
bins = np.arange(0, .5, 1e-3) 
plt.hist(ISI_healthy, bins, color='orange', alpha=0.7, label='Histogram',density=True)
#plt.xlim(0, 0.1)
# Out:
# (array([ 0.        ,  0.        ,  0.        , 11.64596273,  1.55279503,
#          4.65838509,  6.98757764,  3.88198758,  6.98757764,  6.98757764,
#          6.21118012,  8.54037267,  8.54037267,  6.98757764,  6.98757764,
#          4.65838509,  4.65838509,  7.76397516,  3.10559006,  6.98757764,
#          7.76397516,  6.98757764,  6.21118012,  9.31677019,  5.43478261,
#          6.21118012,  6.98757764, 10.86956522,  5.43478261,  4.65838509,
#          8.54037267,  8.54037267,  4.65838509,  5.43478261,  3.88198758,
#          8.54037267,  3.88198758,  6.21118012,  6.21118012,  5.43478261,
#          5.43478261,  8.54037267, 11.64596273, 10.0931677 ,  6.21118012,
#          3.88198758,  3.88198758,  4.65838509,  6.21118012,  7.76397516,
#          5.43478261,  2.32919255,  2.32919255,  2.32919255,  3.10559006,
#          3.88198758,  7.76397516,  6.21118012,  7.76397516,  5.43478261,
#          6.98757764,  3.88198758,  6.98757764,  4.65838509,  7.76397516,
#          0.77639752,  6.21118012,  6.98757764,  5.43478261,  6.21118012,
#          3.88198758,  3.88198758,  4.65838509,  5.43478261,  2.32919255,
#          8.54037267,  6.21118012,  4.65838509,  7.76397516,  0.77639752,
#          0.77639752,  5.43478261,  3.88198758,  2.32919255,  2.32919255,
#          3.10559006,  7.76397516,  0.        ,  2.32919255,  3.10559006,
#          3.88198758,  2.32919255,  5.43478261,  4.65838509,  3.88198758,
#          5.43478261,  2.32919255,  5.43478261,  2.32919255,  6.98757764,
#          6.21118012,  4.65838509,  3.88198758,  2.32919255,  1.55279503,
#          3.10559006,  5.43478261,  3.88198758,  4.65838509,  3.88198758,
#          3.10559006,  0.77639752,  3.88198758,  6.21118012,  4.65838509,
#          1.55279503,  3.88198758,  1.55279503,  3.10559006,  2.32919255,
#          2.32919255,  3.88198758,  0.77639752,  5.43478261,  1.55279503,
#          1.55279503,  4.65838509,  3.10559006,  4.65838509,  1.55279503,
#          0.77639752,  4.65838509,  3.88198758,  3.88198758,  3.10559006,
#          1.55279503,  1.55279503,  3.88198758,  2.32919255,  2.32919255,
#          5.43478261,  3.10559006,  2.32919255,  2.32919255,  0.        ,
#          2.32919255,  3.88198758,  3.10559006,  2.32919255,  6.21118012,
#          2.32919255,  1.55279503,  2.32919255,  3.10559006,  2.32919255,
#          0.77639752,  0.77639752,  2.32919255,  0.77639752,  2.32919255,
#          1.55279503,  2.32919255,  0.77639752,  3.10559006,  3.10559006,
#          1.55279503,  1.55279503,  4.65838509,  5.43478261,  2.32919255,
#          0.77639752,  3.88198758,  1.55279503,  3.10559006,  1.55279503,
#          0.77639752,  1.55279503,  0.        ,  0.77639752,  1.55279503,
#          0.77639752,  0.77639752,  0.77639752,  2.32919255,  2.32919255,
#          0.        ,  1.55279503,  0.77639752,  0.77639752,  2.32919255,
#          1.55279503,  0.77639752,  0.77639752,  1.55279503,  0.77639752,
#          0.        ,  3.10559006,  5.43478261,  0.        ,  3.10559006,
#          3.10559006,  2.32919255,  1.55279503,  0.77639752,  0.77639752,
#          3.88198758,  1.55279503,  0.77639752,  2.32919255,  1.55279503,
#          0.77639752,  0.        ,  3.88198758,  0.        ,  0.        ,
#          0.        ,  0.77639752,  1.55279503,  2.32919255,  3.10559006,
#          0.77639752,  2.32919255,  0.77639752,  0.77639752,  2.32919255,
#          0.77639752,  0.77639752,  0.77639752,  0.77639752,  1.55279503,
#          0.        ,  1.55279503,  1.55279503,  0.77639752,  1.55279503,
#          1.55279503,  1.55279503,  3.10559006,  2.32919255,  0.77639752,
#          1.55279503,  0.77639752,  2.32919255,  0.77639752,  2.32919255,
#          1.55279503,  0.77639752,  1.55279503,  0.77639752,  1.55279503,
#          0.        ,  0.        ,  0.77639752,  3.10559006,  3.10559006,
#          0.        ,  2.32919255,  0.77639752,  0.77639752,  0.77639752,
#          0.        ,  0.77639752,  1.55279503,  0.77639752,  1.55279503,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.        ,
#          0.        ,  1.55279503,  0.77639752,  0.        ,  0.77639752,
#          1.55279503,  0.77639752,  2.32919255,  2.32919255,  0.77639752,
#          0.        ,  0.        ,  0.77639752,  0.        ,  1.55279503,
#          2.32919255,  1.55279503,  0.        ,  0.77639752,  1.55279503,
#          1.55279503,  0.        ,  2.32919255,  0.77639752,  0.        ,
#          0.77639752,  2.32919255,  0.77639752,  0.77639752,  0.77639752,
#          0.        ,  0.77639752,  1.55279503,  0.77639752,  0.77639752,
#          0.        ,  0.77639752,  1.55279503,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.77639752,  1.55279503,  0.77639752,
#          1.55279503,  0.77639752,  0.        ,  1.55279503,  0.77639752,
#          0.77639752,  0.        ,  0.77639752,  0.        ,  0.        ,
#          1.55279503,  0.        ,  1.55279503,  0.77639752,  1.55279503,
#          0.        ,  0.77639752,  0.77639752,  1.55279503,  0.        ,
#          0.        ,  0.77639752,  0.77639752,  0.77639752,  0.        ,
#          0.        ,  0.77639752,  0.77639752,  0.        ,  0.        ,
#          1.55279503,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        ,  1.55279503,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.        ,  1.55279503,  0.        ,
#          1.55279503,  0.        ,  1.55279503,  0.        ,  0.        ,
#          0.77639752,  0.        ,  0.        ,  0.        ,  0.77639752,
#          0.77639752,  1.55279503,  0.77639752,  1.55279503,  0.        ,
#          1.55279503,  0.77639752,  0.        ,  2.32919255,  0.77639752,
#          0.        ,  0.        ,  0.        ,  0.77639752,  1.55279503,
#          0.77639752,  0.77639752,  0.        ,  2.32919255,  0.        ,
#          0.77639752,  0.77639752,  0.77639752,  0.77639752,  0.        ,
#          0.        ,  1.55279503,  0.        ,  0.        ,  0.        ,
#          0.        ,  1.55279503,  0.77639752,  0.77639752,  0.77639752,
#          1.55279503,  0.77639752,  1.55279503,  0.77639752,  2.32919255,
#          0.        ,  1.55279503,  0.        ,  0.77639752,  2.32919255,
#          0.        ,  0.        ,  0.        ,  0.        ,  1.55279503,
#          0.77639752,  0.        ,  0.        ,  0.        ,  0.77639752,
#          0.        ,  0.        ,  0.        ,  0.77639752,  0.77639752,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.        ,  0.77639752,  0.        ,
#          0.        ,  0.        ,  0.77639752,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.77639752,  0.77639752,  0.        ,
#          0.        ,  0.        ,  1.55279503,  0.77639752,  1.55279503,
#          0.        ,  0.77639752,  0.        ,  0.77639752,  0.        ,
#          0.        ,  0.77639752,  2.32919255,  0.77639752,  0.77639752,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.77639752,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.77639752,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.77639752,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.77639752,  0.77639752]),
#  array([0.   , 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008,
#         0.009, 0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017,
#         0.018, 0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026,
#         0.027, 0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035,
#         0.036, 0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044,
#         0.045, 0.046, 0.047, 0.048, 0.049, 0.05 , 0.051, 0.052, 0.053,
#         0.054, 0.055, 0.056, 0.057, 0.058, 0.059, 0.06 , 0.061, 0.062,
#         0.063, 0.064, 0.065, 0.066, 0.067, 0.068, 0.069, 0.07 , 0.071,
#         0.072, 0.073, 0.074, 0.075, 0.076, 0.077, 0.078, 0.079, 0.08 ,
#         0.081, 0.082, 0.083, 0.084, 0.085, 0.086, 0.087, 0.088, 0.089,
#         0.09 , 0.091, 0.092, 0.093, 0.094, 0.095, 0.096, 0.097, 0.098,
#         0.099, 0.1  , 0.101, 0.102, 0.103, 0.104, 0.105, 0.106, 0.107,
#         0.108, 0.109, 0.11 , 0.111, 0.112, 0.113, 0.114, 0.115, 0.116,
#         0.117, 0.118, 0.119, 0.12 , 0.121, 0.122, 0.123, 0.124, 0.125,
#         0.126, 0.127, 0.128, 0.129, 0.13 , 0.131, 0.132, 0.133, 0.134,
#         0.135, 0.136, 0.137, 0.138, 0.139, 0.14 , 0.141, 0.142, 0.143,
#         0.144, 0.145, 0.146, 0.147, 0.148, 0.149, 0.15 , 0.151, 0.152,
#         0.153, 0.154, 0.155, 0.156, 0.157, 0.158, 0.159, 0.16 , 0.161,
#         0.162, 0.163, 0.164, 0.165, 0.166, 0.167, 0.168, 0.169, 0.17 ,
#         0.171, 0.172, 0.173, 0.174, 0.175, 0.176, 0.177, 0.178, 0.179,
#         0.18 , 0.181, 0.182, 0.183, 0.184, 0.185, 0.186, 0.187, 0.188,
#         0.189, 0.19 , 0.191, 0.192, 0.193, 0.194, 0.195, 0.196, 0.197,
#         0.198, 0.199, 0.2  , 0.201, 0.202, 0.203, 0.204, 0.205, 0.206,
#         0.207, 0.208, 0.209, 0.21 , 0.211, 0.212, 0.213, 0.214, 0.215,
#         0.216, 0.217, 0.218, 0.219, 0.22 , 0.221, 0.222, 0.223, 0.224,
#         0.225, 0.226, 0.227, 0.228, 0.229, 0.23 , 0.231, 0.232, 0.233,
#         0.234, 0.235, 0.236, 0.237, 0.238, 0.239, 0.24 , 0.241, 0.242,
#         0.243, 0.244, 0.245, 0.246, 0.247, 0.248, 0.249, 0.25 , 0.251,
#         0.252, 0.253, 0.254, 0.255, 0.256, 0.257, 0.258, 0.259, 0.26 ,
#         0.261, 0.262, 0.263, 0.264, 0.265, 0.266, 0.267, 0.268, 0.269,
#         0.27 , 0.271, 0.272, 0.273, 0.274, 0.275, 0.276, 0.277, 0.278,
#         0.279, 0.28 , 0.281, 0.282, 0.283, 0.284, 0.285, 0.286, 0.287,
#         0.288, 0.289, 0.29 , 0.291, 0.292, 0.293, 0.294, 0.295, 0.296,
#         0.297, 0.298, 0.299, 0.3  , 0.301, 0.302, 0.303, 0.304, 0.305,
#         0.306, 0.307, 0.308, 0.309, 0.31 , 0.311, 0.312, 0.313, 0.314,
#         0.315, 0.316, 0.317, 0.318, 0.319, 0.32 , 0.321, 0.322, 0.323,
#         0.324, 0.325, 0.326, 0.327, 0.328, 0.329, 0.33 , 0.331, 0.332,
#         0.333, 0.334, 0.335, 0.336, 0.337, 0.338, 0.339, 0.34 , 0.341,
#         0.342, 0.343, 0.344, 0.345, 0.346, 0.347, 0.348, 0.349, 0.35 ,
#         0.351, 0.352, 0.353, 0.354, 0.355, 0.356, 0.357, 0.358, 0.359,
#         0.36 , 0.361, 0.362, 0.363, 0.364, 0.365, 0.366, 0.367, 0.368,
#         0.369, 0.37 , 0.371, 0.372, 0.373, 0.374, 0.375, 0.376, 0.377,
#         0.378, 0.379, 0.38 , 0.381, 0.382, 0.383, 0.384, 0.385, 0.386,
#         0.387, 0.388, 0.389, 0.39 , 0.391, 0.392, 0.393, 0.394, 0.395,
#         0.396, 0.397, 0.398, 0.399, 0.4  , 0.401, 0.402, 0.403, 0.404,
#         0.405, 0.406, 0.407, 0.408, 0.409, 0.41 , 0.411, 0.412, 0.413,
#         0.414, 0.415, 0.416, 0.417, 0.418, 0.419, 0.42 , 0.421, 0.422,
#         0.423, 0.424, 0.425, 0.426, 0.427, 0.428, 0.429, 0.43 , 0.431,
#         0.432, 0.433, 0.434, 0.435, 0.436, 0.437, 0.438, 0.439, 0.44 ,
#         0.441, 0.442, 0.443, 0.444, 0.445, 0.446, 0.447, 0.448, 0.449,
#         0.45 , 0.451, 0.452, 0.453, 0.454, 0.455, 0.456, 0.457, 0.458,
#         0.459, 0.46 , 0.461, 0.462, 0.463, 0.464, 0.465, 0.466, 0.467,
#         0.468, 0.469, 0.47 , 0.471, 0.472, 0.473, 0.474, 0.475, 0.476,
#         0.477, 0.478, 0.479, 0.48 , 0.481, 0.482, 0.483, 0.484, 0.485,
#         0.486, 0.487, 0.488, 0.489, 0.49 , 0.491, 0.492, 0.493, 0.494,
#         0.495, 0.496, 0.497, 0.498, 0.499]),
#  <BarContainer object of 499 artists>)

# %%
len(neuron)
# Out:
# 1343

# %%
list_neurons = np.genfromtxt(file2, delimiter=',')
neuron=list_neurons[0]
neuron=neuron[neuron>0]
neuron=neuron[neuron<200*10000]
ISI_healthy2=np.diff(neuron)/10000
bins = np.arange(0, .5, 1e-3) 
plt.hist(ISI_healthy, bins, color='orange', alpha=0.7, label='Histogram',density=True)
#plt.xlim(0, 0.1)
# Out:
# (array([ 0.        ,  0.        ,  0.        , 11.64596273,  1.55279503,
#          4.65838509,  6.98757764,  3.88198758,  6.98757764,  6.98757764,
#          6.21118012,  8.54037267,  8.54037267,  6.98757764,  6.98757764,
#          4.65838509,  4.65838509,  7.76397516,  3.10559006,  6.98757764,
#          7.76397516,  6.98757764,  6.21118012,  9.31677019,  5.43478261,
#          6.21118012,  6.98757764, 10.86956522,  5.43478261,  4.65838509,
#          8.54037267,  8.54037267,  4.65838509,  5.43478261,  3.88198758,
#          8.54037267,  3.88198758,  6.21118012,  6.21118012,  5.43478261,
#          5.43478261,  8.54037267, 11.64596273, 10.0931677 ,  6.21118012,
#          3.88198758,  3.88198758,  4.65838509,  6.21118012,  7.76397516,
#          5.43478261,  2.32919255,  2.32919255,  2.32919255,  3.10559006,
#          3.88198758,  7.76397516,  6.21118012,  7.76397516,  5.43478261,
#          6.98757764,  3.88198758,  6.98757764,  4.65838509,  7.76397516,
#          0.77639752,  6.21118012,  6.98757764,  5.43478261,  6.21118012,
#          3.88198758,  3.88198758,  4.65838509,  5.43478261,  2.32919255,
#          8.54037267,  6.21118012,  4.65838509,  7.76397516,  0.77639752,
#          0.77639752,  5.43478261,  3.88198758,  2.32919255,  2.32919255,
#          3.10559006,  7.76397516,  0.        ,  2.32919255,  3.10559006,
#          3.88198758,  2.32919255,  5.43478261,  4.65838509,  3.88198758,
#          5.43478261,  2.32919255,  5.43478261,  2.32919255,  6.98757764,
#          6.21118012,  4.65838509,  3.88198758,  2.32919255,  1.55279503,
#          3.10559006,  5.43478261,  3.88198758,  4.65838509,  3.88198758,
#          3.10559006,  0.77639752,  3.88198758,  6.21118012,  4.65838509,
#          1.55279503,  3.88198758,  1.55279503,  3.10559006,  2.32919255,
#          2.32919255,  3.88198758,  0.77639752,  5.43478261,  1.55279503,
#          1.55279503,  4.65838509,  3.10559006,  4.65838509,  1.55279503,
#          0.77639752,  4.65838509,  3.88198758,  3.88198758,  3.10559006,
#          1.55279503,  1.55279503,  3.88198758,  2.32919255,  2.32919255,
#          5.43478261,  3.10559006,  2.32919255,  2.32919255,  0.        ,
#          2.32919255,  3.88198758,  3.10559006,  2.32919255,  6.21118012,
#          2.32919255,  1.55279503,  2.32919255,  3.10559006,  2.32919255,
#          0.77639752,  0.77639752,  2.32919255,  0.77639752,  2.32919255,
#          1.55279503,  2.32919255,  0.77639752,  3.10559006,  3.10559006,
#          1.55279503,  1.55279503,  4.65838509,  5.43478261,  2.32919255,
#          0.77639752,  3.88198758,  1.55279503,  3.10559006,  1.55279503,
#          0.77639752,  1.55279503,  0.        ,  0.77639752,  1.55279503,
#          0.77639752,  0.77639752,  0.77639752,  2.32919255,  2.32919255,
#          0.        ,  1.55279503,  0.77639752,  0.77639752,  2.32919255,
#          1.55279503,  0.77639752,  0.77639752,  1.55279503,  0.77639752,
#          0.        ,  3.10559006,  5.43478261,  0.        ,  3.10559006,
#          3.10559006,  2.32919255,  1.55279503,  0.77639752,  0.77639752,
#          3.88198758,  1.55279503,  0.77639752,  2.32919255,  1.55279503,
#          0.77639752,  0.        ,  3.88198758,  0.        ,  0.        ,
#          0.        ,  0.77639752,  1.55279503,  2.32919255,  3.10559006,
#          0.77639752,  2.32919255,  0.77639752,  0.77639752,  2.32919255,
#          0.77639752,  0.77639752,  0.77639752,  0.77639752,  1.55279503,
#          0.        ,  1.55279503,  1.55279503,  0.77639752,  1.55279503,
#          1.55279503,  1.55279503,  3.10559006,  2.32919255,  0.77639752,
#          1.55279503,  0.77639752,  2.32919255,  0.77639752,  2.32919255,
#          1.55279503,  0.77639752,  1.55279503,  0.77639752,  1.55279503,
#          0.        ,  0.        ,  0.77639752,  3.10559006,  3.10559006,
#          0.        ,  2.32919255,  0.77639752,  0.77639752,  0.77639752,
#          0.        ,  0.77639752,  1.55279503,  0.77639752,  1.55279503,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.        ,
#          0.        ,  1.55279503,  0.77639752,  0.        ,  0.77639752,
#          1.55279503,  0.77639752,  2.32919255,  2.32919255,  0.77639752,
#          0.        ,  0.        ,  0.77639752,  0.        ,  1.55279503,
#          2.32919255,  1.55279503,  0.        ,  0.77639752,  1.55279503,
#          1.55279503,  0.        ,  2.32919255,  0.77639752,  0.        ,
#          0.77639752,  2.32919255,  0.77639752,  0.77639752,  0.77639752,
#          0.        ,  0.77639752,  1.55279503,  0.77639752,  0.77639752,
#          0.        ,  0.77639752,  1.55279503,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.77639752,  1.55279503,  0.77639752,
#          1.55279503,  0.77639752,  0.        ,  1.55279503,  0.77639752,
#          0.77639752,  0.        ,  0.77639752,  0.        ,  0.        ,
#          1.55279503,  0.        ,  1.55279503,  0.77639752,  1.55279503,
#          0.        ,  0.77639752,  0.77639752,  1.55279503,  0.        ,
#          0.        ,  0.77639752,  0.77639752,  0.77639752,  0.        ,
#          0.        ,  0.77639752,  0.77639752,  0.        ,  0.        ,
#          1.55279503,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        ,  1.55279503,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.        ,  1.55279503,  0.        ,
#          1.55279503,  0.        ,  1.55279503,  0.        ,  0.        ,
#          0.77639752,  0.        ,  0.        ,  0.        ,  0.77639752,
#          0.77639752,  1.55279503,  0.77639752,  1.55279503,  0.        ,
#          1.55279503,  0.77639752,  0.        ,  2.32919255,  0.77639752,
#          0.        ,  0.        ,  0.        ,  0.77639752,  1.55279503,
#          0.77639752,  0.77639752,  0.        ,  2.32919255,  0.        ,
#          0.77639752,  0.77639752,  0.77639752,  0.77639752,  0.        ,
#          0.        ,  1.55279503,  0.        ,  0.        ,  0.        ,
#          0.        ,  1.55279503,  0.77639752,  0.77639752,  0.77639752,
#          1.55279503,  0.77639752,  1.55279503,  0.77639752,  2.32919255,
#          0.        ,  1.55279503,  0.        ,  0.77639752,  2.32919255,
#          0.        ,  0.        ,  0.        ,  0.        ,  1.55279503,
#          0.77639752,  0.        ,  0.        ,  0.        ,  0.77639752,
#          0.        ,  0.        ,  0.        ,  0.77639752,  0.77639752,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.        ,  0.77639752,  0.        ,
#          0.        ,  0.        ,  0.77639752,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.77639752,  0.77639752,  0.        ,
#          0.        ,  0.        ,  1.55279503,  0.77639752,  1.55279503,
#          0.        ,  0.77639752,  0.        ,  0.77639752,  0.        ,
#          0.        ,  0.77639752,  2.32919255,  0.77639752,  0.77639752,
#          0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.77639752,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.77639752,
#          0.        ,  0.77639752,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.77639752,  0.77639752,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.77639752,  0.77639752]),
#  array([0.   , 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008,
#         0.009, 0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017,
#         0.018, 0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026,
#         0.027, 0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035,
#         0.036, 0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044,
#         0.045, 0.046, 0.047, 0.048, 0.049, 0.05 , 0.051, 0.052, 0.053,
#         0.054, 0.055, 0.056, 0.057, 0.058, 0.059, 0.06 , 0.061, 0.062,
#         0.063, 0.064, 0.065, 0.066, 0.067, 0.068, 0.069, 0.07 , 0.071,
#         0.072, 0.073, 0.074, 0.075, 0.076, 0.077, 0.078, 0.079, 0.08 ,
#         0.081, 0.082, 0.083, 0.084, 0.085, 0.086, 0.087, 0.088, 0.089,
#         0.09 , 0.091, 0.092, 0.093, 0.094, 0.095, 0.096, 0.097, 0.098,
#         0.099, 0.1  , 0.101, 0.102, 0.103, 0.104, 0.105, 0.106, 0.107,
#         0.108, 0.109, 0.11 , 0.111, 0.112, 0.113, 0.114, 0.115, 0.116,
#         0.117, 0.118, 0.119, 0.12 , 0.121, 0.122, 0.123, 0.124, 0.125,
#         0.126, 0.127, 0.128, 0.129, 0.13 , 0.131, 0.132, 0.133, 0.134,
#         0.135, 0.136, 0.137, 0.138, 0.139, 0.14 , 0.141, 0.142, 0.143,
#         0.144, 0.145, 0.146, 0.147, 0.148, 0.149, 0.15 , 0.151, 0.152,
#         0.153, 0.154, 0.155, 0.156, 0.157, 0.158, 0.159, 0.16 , 0.161,
#         0.162, 0.163, 0.164, 0.165, 0.166, 0.167, 0.168, 0.169, 0.17 ,
#         0.171, 0.172, 0.173, 0.174, 0.175, 0.176, 0.177, 0.178, 0.179,
#         0.18 , 0.181, 0.182, 0.183, 0.184, 0.185, 0.186, 0.187, 0.188,
#         0.189, 0.19 , 0.191, 0.192, 0.193, 0.194, 0.195, 0.196, 0.197,
#         0.198, 0.199, 0.2  , 0.201, 0.202, 0.203, 0.204, 0.205, 0.206,
#         0.207, 0.208, 0.209, 0.21 , 0.211, 0.212, 0.213, 0.214, 0.215,
#         0.216, 0.217, 0.218, 0.219, 0.22 , 0.221, 0.222, 0.223, 0.224,
#         0.225, 0.226, 0.227, 0.228, 0.229, 0.23 , 0.231, 0.232, 0.233,
#         0.234, 0.235, 0.236, 0.237, 0.238, 0.239, 0.24 , 0.241, 0.242,
#         0.243, 0.244, 0.245, 0.246, 0.247, 0.248, 0.249, 0.25 , 0.251,
#         0.252, 0.253, 0.254, 0.255, 0.256, 0.257, 0.258, 0.259, 0.26 ,
#         0.261, 0.262, 0.263, 0.264, 0.265, 0.266, 0.267, 0.268, 0.269,
#         0.27 , 0.271, 0.272, 0.273, 0.274, 0.275, 0.276, 0.277, 0.278,
#         0.279, 0.28 , 0.281, 0.282, 0.283, 0.284, 0.285, 0.286, 0.287,
#         0.288, 0.289, 0.29 , 0.291, 0.292, 0.293, 0.294, 0.295, 0.296,
#         0.297, 0.298, 0.299, 0.3  , 0.301, 0.302, 0.303, 0.304, 0.305,
#         0.306, 0.307, 0.308, 0.309, 0.31 , 0.311, 0.312, 0.313, 0.314,
#         0.315, 0.316, 0.317, 0.318, 0.319, 0.32 , 0.321, 0.322, 0.323,
#         0.324, 0.325, 0.326, 0.327, 0.328, 0.329, 0.33 , 0.331, 0.332,
#         0.333, 0.334, 0.335, 0.336, 0.337, 0.338, 0.339, 0.34 , 0.341,
#         0.342, 0.343, 0.344, 0.345, 0.346, 0.347, 0.348, 0.349, 0.35 ,
#         0.351, 0.352, 0.353, 0.354, 0.355, 0.356, 0.357, 0.358, 0.359,
#         0.36 , 0.361, 0.362, 0.363, 0.364, 0.365, 0.366, 0.367, 0.368,
#         0.369, 0.37 , 0.371, 0.372, 0.373, 0.374, 0.375, 0.376, 0.377,
#         0.378, 0.379, 0.38 , 0.381, 0.382, 0.383, 0.384, 0.385, 0.386,
#         0.387, 0.388, 0.389, 0.39 , 0.391, 0.392, 0.393, 0.394, 0.395,
#         0.396, 0.397, 0.398, 0.399, 0.4  , 0.401, 0.402, 0.403, 0.404,
#         0.405, 0.406, 0.407, 0.408, 0.409, 0.41 , 0.411, 0.412, 0.413,
#         0.414, 0.415, 0.416, 0.417, 0.418, 0.419, 0.42 , 0.421, 0.422,
#         0.423, 0.424, 0.425, 0.426, 0.427, 0.428, 0.429, 0.43 , 0.431,
#         0.432, 0.433, 0.434, 0.435, 0.436, 0.437, 0.438, 0.439, 0.44 ,
#         0.441, 0.442, 0.443, 0.444, 0.445, 0.446, 0.447, 0.448, 0.449,
#         0.45 , 0.451, 0.452, 0.453, 0.454, 0.455, 0.456, 0.457, 0.458,
#         0.459, 0.46 , 0.461, 0.462, 0.463, 0.464, 0.465, 0.466, 0.467,
#         0.468, 0.469, 0.47 , 0.471, 0.472, 0.473, 0.474, 0.475, 0.476,
#         0.477, 0.478, 0.479, 0.48 , 0.481, 0.482, 0.483, 0.484, 0.485,
#         0.486, 0.487, 0.488, 0.489, 0.49 , 0.491, 0.492, 0.493, 0.494,
#         0.495, 0.496, 0.497, 0.498, 0.499]),
#  <BarContainer object of 499 artists>)

# %%
plt.hist(ISI_healthy, bins, color='orange', alpha=0.7, label='Histogram',density=True)
plt.xlim(0, 0.1)

# %%
len(neuron)
# Out:
# 1342

# %%
df=this_poiproc(file1,1,1)
#map_est=this_Bayesian_mixture_model2(ISI_healthy1)
# Out:
# /Users/Gaia_1/Desktop/Data after SS thresh 3/After2018-11-28T11-29-05MIP 5 KA 24hrs after.h5.txt.txt target 1 stimulation 1
# Original number of neurons:  58
#   0%|          | 0/58 [00:00<?, ?it/s]
#   Neuron with  1343 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='62' class='' max='62' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [62/62 00:00&lt;00:00 logp = 1,238, ||grad|| = 0.010499]
#     </div>
# ks score:  KstestResult(statistic=0.29222354435852826, pvalue=5.769297997229319e-100, statistic_location=0.0031, statistic_sign=-1)
# {'mu1': array(0.10592015), 'lam1': array(0.04977284), 'mu2': array(2.07347166e-34), 'sigma2': array(0.18153201), 'mu3': array(0.20000651), 'sigma3': array(0.32282882), 'w1': 0.3794706107452516, 'w2': 0.525959104081547, 'w3': 0.09457028517320132}
#   Neuron with  1403 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='68' class='' max='68' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [68/68 00:00&lt;00:00 logp = 1,363.3, ||grad|| = 0.28949]
#     </div>
# ks score:  KstestResult(statistic=0.1674622267244236, pvalue=1.4145242991597463e-34, statistic_location=0.0031, statistic_sign=-1)
# {'mu1': array(0.11447472), 'lam1': array(0.04783536), 'mu2': array(0.05194103), 'sigma2': array(0.11074538), 'mu3': array(0.39282801), 'sigma3': array(0.14281543), 'w1': 0.3846233448832456, 'w2': 0.5068820098329876, 'w3': 0.10849464528376691}
#   Neuron with  1363 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='61' class='' max='61' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [61/61 00:00&lt;00:00 logp = 1,274.9, ||grad|| = 0.014962]
#     </div>
# ks score:  KstestResult(statistic=0.2422890668841563, pvalue=7.130844484795507e-70, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.13194095), 'lam1': array(0.04323466), 'mu2': array(3.202271e-12), 'sigma2': array(0.11163116), 'mu3': array(0.20000322), 'sigma3': array(0.20089423), 'w1': 0.35361600727919734, 'w2': 0.3933010357528422, 'w3': 0.2530829569679604}
#   Neuron with  1370 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='54' class='' max='54' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [54/54 00:00&lt;00:00 logp = 1,297.3, ||grad|| = 0.012847]
#     </div>
# ks score:  KstestResult(statistic=0.2574542523937872, pvalue=3.0506620235776293e-79, statistic_location=0.0032, statistic_sign=-1)
# {'mu1': array(0.10251533), 'lam1': array(0.05761126), 'mu2': array(6.03248312e-23), 'sigma2': array(0.16685563), 'mu3': array(0.20000085), 'sigma3': array(0.37227999), 'w1': 0.44745779962473914, 'w2': 0.44226546763326, 'w3': 0.11027673274200088}
#     Excluded neuron with n spikes =  620
#   Neuron with  895 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='78' class='' max='78' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [78/78 00:00&lt;00:00 logp = 462.3, ||grad|| = 0.017628]
#     </div>
# ks score:  KstestResult(statistic=0.31190459403470716, pvalue=5.72573859615088e-76, statistic_location=0.0032, statistic_sign=-1)
# {'mu1': array(0.12576721), 'lam1': array(0.06906431), 'mu2': array(0.04988015), 'sigma2': array(0.21340733), 'mu3': array(0.20000463), 'sigma3': array(0.48887924), 'w1': 0.21728592898166071, 'w2': 0.6151877855009795, 'w3': 0.16752628551735962}
#   Neuron with  907 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='74' class='' max='74' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [74/74 00:00&lt;00:00 logp = 476.73, ||grad|| = 0.0053493]
#     </div>
# ks score:  KstestResult(statistic=0.2800710978525446, pvalue=3.745178853488071e-62, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.09329912), 'lam1': array(0.03022558), 'mu2': array(0.08080331), 'sigma2': array(0.17458238), 'mu3': array(0.20000037), 'sigma3': array(0.4194817), 'w1': 0.14049913328175825, 'w2': 0.6191530146646438, 'w3': 0.24034785205359796}
#     Excluded neuron with n spikes =  772
#     Excluded neuron with n spikes =  607
#   Neuron with  861 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='61' class='' max='61' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [61/61 00:00&lt;00:00 logp = 408.19, ||grad|| = 0.001801]
#     </div>
# ks score:  KstestResult(statistic=0.3274132786592316, pvalue=1.676807934690552e-80, statistic_location=0.0036, statistic_sign=-1)
# {'mu1': array(0.12561758), 'lam1': array(0.07408934), 'mu2': array(0.02830419), 'sigma2': array(0.20795621), 'mu3': array(0.31769496), 'sigma3': array(0.42042023), 'w1': 0.17114492304885365, 'w2': 0.6164960285513295, 'w3': 0.212359048399817}
#     Excluded neuron with n spikes =  796
#   Neuron with  833 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='64' class='' max='64' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [64/64 00:00&lt;00:00 logp = 368.54, ||grad|| = 0.0065523]
#     </div>
# ks score:  KstestResult(statistic=0.3945602827612335, pvalue=6.280035578309122e-113, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.10862385), 'lam1': array(0.05899204), 'mu2': array(1.19535754e-12), 'sigma2': array(0.26877847), 'mu3': array(0.59999086), 'sigma3': array(0.35940232), 'w1': 0.13353981641243393, 'w2': 0.7732135291935456, 'w3': 0.09324665439402055}
#   Neuron with  843 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='84' class='' max='84' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [84/84 00:00&lt;00:00 logp = 381.19, ||grad|| = 0.0094845]
#     </div>
# ks score:  KstestResult(statistic=0.18507208875964104, pvalue=1.7823784667952377e-25, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.15166466), 'lam1': array(0.0415129), 'mu2': array(0.10528497), 'sigma2': array(0.10075767), 'mu3': array(0.20000026), 'sigma3': array(0.34084289), 'w1': 0.17530559428098502, 'w2': 0.3730721920347903, 'w3': 0.45162221368422467}
#     Excluded neuron with n spikes =  545
#   Neuron with  902 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='70' class='' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [70/70 00:00&lt;00:00 logp = 467.32, ||grad|| = 0.055722]
#     </div>
# ks score:  KstestResult(statistic=0.4217131367463896, pvalue=1.3247790611876347e-139, statistic_location=0.0034, statistic_sign=-1)
# {'mu1': array(0.08418164), 'lam1': array(0.02357264), 'mu2': array(3.32856288e-06), 'sigma2': array(0.19615434), 'mu3': array(0.2000002), 'sigma3': array(0.39936325), 'w1': 0.06049818166671699, 'w2': 0.6573535866119514, 'w3': 0.2821482317213317}
#   Neuron with  827 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='64' class='' max='64' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [64/64 00:00&lt;00:00 logp = 357.07, ||grad|| = 0.0031024]
#     </div>
# ks score:  KstestResult(statistic=0.41244654896273647, pvalue=1.7918475255316834e-122, statistic_location=0.0032, statistic_sign=-1)
# {'mu1': array(0.11556578), 'lam1': array(0.0370951), 'mu2': array(2.40004109e-10), 'sigma2': array(0.25145124), 'mu3': array(0.20000244), 'sigma3': array(0.57829447), 'w1': 0.14025772188521982, 'w2': 0.7012309958610887, 'w3': 0.15851128225369138}
#     Excluded neuron with n spikes =  752
#   Neuron with  871 spikes
# KeyboardInterrupt

# %%
df=this_poiproc(file2,1,0)
#map_est=this_Bayesian_mixture_model2(ISI_healthy2)
# Out:
# /Users/Gaia_1/Desktop/Data after SS thresh 3/After2018-11-27T10-03-29MIP4 BL .h5.txt.txt target 1 stimulation 0
# Original number of neurons:  58
#   0%|          | 0/58 [00:00<?, ?it/s]
#   Neuron with  1342 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='57' class='' max='57' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [57/57 00:00&lt;00:00 logp = 1,236, ||grad|| = 0.33308]
#     </div>
# ks score:  KstestResult(statistic=0.1823515505394736, pvalue=3.7130952717597685e-39, statistic_location=0.0031, statistic_sign=-1)
# {'mu1': array(0.11112128), 'lam1': array(0.04862652), 'mu2': array(0.04699787), 'sigma2': array(0.08926857), 'mu3': array(0.2000114), 'sigma3': array(0.22225454), 'w1': 0.300837383847568, 'w2': 0.41253866945791806, 'w3': 0.286623946694514}
#   Neuron with  1321 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='56' class='' max='56' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [56/56 00:00&lt;00:00 logp = 1,190.3, ||grad|| = 0.43245]
#     </div>
# ks score:  KstestResult(statistic=0.28539700976577004, pvalue=8.201438110633718e-94, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.13711132), 'lam1': array(0.05351963), 'mu2': array(0.0006508), 'sigma2': array(0.11907957), 'mu3': array(0.20032), 'sigma3': array(0.21803023), 'w1': 0.27373457021949904, 'w2': 0.46957328268245885, 'w3': 0.2566921470980421}
#   Neuron with  1343 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='59' class='' max='59' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [59/59 00:00&lt;00:00 logp = 1,233.7, ||grad|| = 0.044588]
#     </div>
# ks score:  KstestResult(statistic=0.2761003698268777, pvalue=2.767943690365222e-89, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.12856188), 'lam1': array(0.06219554), 'mu2': array(2.46865203e-08), 'sigma2': array(0.12940428), 'mu3': array(0.20000032), 'sigma3': array(0.24157704), 'w1': 0.3355165076210272, 'w2': 0.4581237186964552, 'w3': 0.20635977368251765}
#   Neuron with  1344 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='77' class='' max='77' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [77/77 00:00&lt;00:00 logp = 1,239.7, ||grad|| = 0.045231]
#     </div>
# ks score:  KstestResult(statistic=0.24491078676635897, pvalue=2.147596731407569e-70, statistic_location=0.0031, statistic_sign=-1)
# {'mu1': array(0.09614546), 'lam1': array(0.03074987), 'mu2': array(0.04265256), 'sigma2': array(0.10532605), 'mu3': array(0.20000515), 'sigma3': array(0.26812282), 'w1': 0.2263204288171982, 'w2': 0.5349047409733801, 'w3': 0.23877483020942164}
#   Neuron with  1312 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='65' class='' max='65' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [65/65 00:00&lt;00:00 logp = 1,172.7, ||grad|| = 0.02917]
#     </div>
# ks score:  KstestResult(statistic=0.32809204251525925, pvalue=5.2990488071220255e-123, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.10224224), 'lam1': array(0.0503699), 'mu2': array(2.69650221e-08), 'sigma2': array(0.14791302), 'mu3': array(0.20000273), 'sigma3': array(0.28818467), 'w1': 0.2560674736972215, 'w2': 0.552686962597122, 'w3': 0.1912455637056565}
#   Neuron with  988 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='89' class='' max='89' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [89/89 00:00&lt;00:00 logp = 606.55, ||grad|| = 1.7412]
#     </div>
# ks score:  KstestResult(statistic=0.19364668878990368, pvalue=1.4229967566106102e-32, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.18), 'lam1': array(0.02720144), 'mu2': array(0.06523152), 'sigma2': array(0.0795521), 'mu3': array(0.2), 'sigma3': array(0.30089864), 'w1': 0.18497215680692403, 'w2': 0.40272001683468645, 'w3': 0.41230782635838953}
#   Neuron with  1286 spikes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df=this_poiproc(file2,1,0)
#
# Cell In[52], line 22, in this_poiproc(file, target, stim)
#      20 ISI_healthy = np.diff(neuron)/10000
#      21 try:
# ---> 22     map_estimate = this_Bayesian_mixture_model2(ISI_healthy)
#      23 except Exception as e:
#      24     print(f"An error occurred: {e}")
#
# Cell In[54], line 21, in this_Bayesian_mixture_model2(ISI_data)
#      18     w = pm.Dirichlet('w', a=np.array([1., 1., 1.]))
#      19     like = pm.Mixture('like', w=w, comp_dists = [obs1, obs2, obs3], observed=ISI_data)
# ---> 21 map_estimate = pm.find_MAP(model=model)
#      22 d= np.linspace(0.00, 1, len(ISI_data))
#      23 map_estimate['w1'] = map_estimate['w'][0]
#
# File ~/anaconda3/lib/python3.11/site-packages/pymc/tuning/starting.py:125, in find_MAP(start, vars, method, return_raw, include_transformed, progressbar, maxeval, model, seed, *args, **kwargs)
#     118 ipfn = make_initial_point_fn(
#     119     model=model,
#     120     jitter_rvs=set(),
#     121     return_transformed=True,
#     122     overrides=start,
#     123 )
#     124 start = ipfn(seed)
# --> 125 model.check_start_vals(start)
#     127 vars_dict = {var.name: var for var in vars}
#     128 x0 = DictToArrayBijection.map(
#     129     {var_name: value for var_name, value in start.items() if var_name in vars_dict}
#     130 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pymc/model/core.py:1691, in Model.check_start_vals(self, start)
#    1685     valid_keys = ", ".join(value_names_set)
#    1686     raise KeyError(
#    1687         "Some start parameters do not appear in the model!\n"
#    1688         f"Valid keys are: {valid_keys}, but {extra_keys} was supplied"
#    1689     )
# -> 1691 initial_eval = self.point_logps(point=elem)
#    1693 if not all(np.isfinite(v) for v in initial_eval.values()):
#    1694     raise SamplingError(
#    1695         "Initial evaluation of model at starting point failed!\n"
#    1696         f"Starting values:\n{elem}\n\n"
#    1697         f"Logp initial evaluation results:\n{initial_eval}\n"
#    1698         "You can call `model.debug()` for more details."
#    1699     )
#
# File ~/anaconda3/lib/python3.11/site-packages/pymc/model/core.py:1726, in Model.point_logps(self, point, round_vals)
#    1720 factors = self.basic_RVs + self.potentials
#    1721 factor_logps_fn = [pt.sum(factor) for factor in self.logp(factors, sum=False)]
#    1722 return {
#    1723     factor.name: np.round(np.asarray(factor_logp), round_vals)
#    1724     for factor, factor_logp in zip(
#    1725         factors,
# -> 1726         self.compile_fn(factor_logps_fn)(point),
#    1727     )
#    1728 }
#
# File ~/anaconda3/lib/python3.11/site-packages/pymc/model/core.py:1570, in Model.compile_fn(self, outs, inputs, mode, point_fn, **kwargs)
#    1567     inputs = inputvars(outs)
#    1569 with self:
# -> 1570     fn = compile_pymc(
#    1571         inputs,
#    1572         outs,
#    1573         allow_input_downcast=True,
#    1574         accept_inplace=True,
#    1575         mode=mode,
#    1576         **kwargs,
#    1577     )
#    1579 if point_fn:
#    1580     return PointFunc(fn)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymc/pytensorf.py:1195, in compile_pymc(inputs, outputs, random_seed, mode, **kwargs)
#    1193 opt_qry = mode.provided_optimizer.including("random_make_inplace", check_parameter_opt)
#    1194 mode = Mode(linker=mode.linker, optimizer=opt_qry)
# -> 1195 pytensor_function = pytensor.function(
#    1196     inputs,
#    1197     outputs,
#    1198     updates={**rng_updates, **kwargs.pop("updates", {})},
#    1199     mode=mode,
#    1200     **kwargs,
#    1201 )
#    1202 return pytensor_function
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/__init__.py:315, in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     309     fn = orig_function(
#     310         inputs, outputs, mode=mode, accept_inplace=accept_inplace, name=name
#     311     )
#     312 else:
#     313     # note: pfunc will also call orig_function -- orig_function is
#     314     #      a choke point that all compilation must pass through
# --> 315     fn = pfunc(
#     316         params=inputs,
#     317         outputs=outputs,
#     318         mode=mode,
#     319         updates=updates,
#     320         givens=givens,
#     321         no_default_updates=no_default_updates,
#     322         accept_inplace=accept_inplace,
#     323         name=name,
#     324         rebuild_strict=rebuild_strict,
#     325         allow_input_downcast=allow_input_downcast,
#     326         on_unused_input=on_unused_input,
#     327         profile=profile,
#     328         output_keys=output_keys,
#     329     )
#     330 return fn
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/pfunc.py:469, in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys, fgraph)
#     455     profile = ProfileStats(message=profile)
#     457 inputs, cloned_outputs = construct_pfunc_ins_and_outs(
#     458     params,
#     459     outputs,
#    (...)
#     466     fgraph=fgraph,
#     467 )
# --> 469 return orig_function(
#     470     inputs,
#     471     cloned_outputs,
#     472     mode,
#     473     accept_inplace=accept_inplace,
#     474     name=name,
#     475     profile=profile,
#     476     on_unused_input=on_unused_input,
#     477     output_keys=output_keys,
#     478     fgraph=fgraph,
#     479 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/types.py:1744, in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys, fgraph)
#    1742 try:
#    1743     Maker = getattr(mode, "function_maker", FunctionMaker)
# -> 1744     m = Maker(
#    1745         inputs,
#    1746         outputs,
#    1747         mode,
#    1748         accept_inplace=accept_inplace,
#    1749         profile=profile,
#    1750         on_unused_input=on_unused_input,
#    1751         output_keys=output_keys,
#    1752         name=name,
#    1753         fgraph=fgraph,
#    1754     )
#    1755     with config.change_flags(compute_test_value="off"):
#    1756         fn = m.create(defaults)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/types.py:1518, in FunctionMaker.__init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys, name, no_fgraph_prep)
#    1515 self.fgraph = fgraph
#    1517 if not no_fgraph_prep:
# -> 1518     self.prepare_fgraph(inputs, outputs, found_updates, fgraph, mode, profile)
#    1520 assert len(fgraph.outputs) == len(outputs + found_updates)
#    1522 # The 'no_borrow' outputs are the ones for which that we can't
#    1523 # return the internal storage pointer.
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/types.py:1411, in FunctionMaker.prepare_fgraph(inputs, outputs, additional_outputs, fgraph, mode, profile)
#    1404 rewrite_time = None
#    1406 with config.change_flags(
#    1407     mode=mode,
#    1408     compute_test_value=config.compute_test_value_opt,
#    1409     traceback__limit=config.traceback__compile_limit,
#    1410 ):
# -> 1411     rewriter_profile = rewriter(fgraph)
#    1413     end_rewriter = time.perf_counter()
#    1414     rewrite_time = end_rewriter - start_rewriter
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:125, in GraphRewriter.__call__(self, fgraph)
#     123 def __call__(self, fgraph):
#     124     """Rewrite a `FunctionGraph`."""
# --> 125     return self.rewrite(fgraph)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:121, in GraphRewriter.rewrite(self, fgraph, *args, **kwargs)
#     112 """
#     113
#     114 This is meant as a shortcut for the following::
#    (...)
#     118
#     119 """
#     120 self.add_requirements(fgraph)
# --> 121 return self.apply(fgraph, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:292, in SequentialGraphRewriter.apply(self, fgraph)
#     290 nb_nodes_before = len(fgraph.apply_nodes)
#     291 t0 = time.perf_counter()
# --> 292 sub_prof = rewriter.apply(fgraph)
#     293 l.append(float(time.perf_counter() - t0))
#     294 sub_profs.append(sub_prof)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:2458, in EquilibriumGraphRewriter.apply(self, fgraph, start_from)
#    2456 nb = change_tracker.nb_imported
#    2457 t_rewrite = time.perf_counter()
# -> 2458 sub_prof = grewrite.apply(fgraph)
#    2459 time_rewriters[grewrite] += time.perf_counter() - t_rewrite
#    2460 sub_profs.append(sub_prof)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:2040, in WalkingGraphRewriter.apply(self, fgraph, start_from)
#    2038             continue
#    2039         current_node = node
# -> 2040         nb += self.process_node(fgraph, node)
#    2041     loop_t = time.perf_counter() - t0
#    2042 finally:
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:1922, in NodeProcessingGraphRewriter.process_node(self, fgraph, node, node_rewriter)
#    1920 assert node_rewriter is not None
#    1921 try:
# -> 1922     replacements = node_rewriter.transform(fgraph, node)
#    1923 except Exception as e:
#    1924     if self.failure_callback is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:1082, in FromFunctionNodeRewriter.transform(self, fgraph, node)
#    1077     if not (
#    1078         node.op in self._tracks or isinstance(node.op, self._tracked_types)
#    1079     ):
#    1080         return False
# -> 1082 return self.fn(fgraph, node)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/rewriting/basic.py:1106, in constant_folding(fgraph, node)
#    1103     storage_map[o] = [None]
#    1104     compute_map[o] = [False]
# -> 1106 thunk = node.op.make_thunk(node, storage_map, compute_map, no_recycling=[])
#    1107 required = thunk()
#    1109 # A node whose inputs are all provided should always return successfully
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/link/c/op.py:119, in COp.make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     115 self.prepare_node(
#     116     node, storage_map=storage_map, compute_map=compute_map, impl="c"
#     117 )
#     118 try:
# --> 119     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#     120 except (NotImplementedError, MethodNotDefined):
#     121     # We requested the c code, so don't catch the error.
#     122     if impl == "c":
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/link/c/op.py:84, in COp.make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#      82         print(f"Disabling C code for {self} due to unsupported float16")
#      83         raise NotImplementedError("float16")
# ---> 84 outputs = cl.make_thunk(
#      85     input_storage=node_input_storage, output_storage=node_output_storage
#      86 )
#      87 thunk, node_input_filters, node_output_filters = outputs
#      89 @is_cthunk_wrapper_type
#      90 def rval():
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/link/c/basic.py:1200, in CLinker.make_thunk(self, input_storage, output_storage, storage_map, cache, **kwargs)
#    1165 """Compile this linker's `self.fgraph` and return a function that performs the computations.
#    1166
#    1167 The return values can be used as follows:
#    (...)
#    1197
#    1198 """
#    1199 init_tasks, tasks = self.get_init_tasks()
# -> 1200 cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#    1201     input_storage, output_storage, storage_map, cache
#    1202 )
#    1204 res = _CThunk(cthunk, init_tasks, tasks, error_storage, module)
#    1205 res.nodes = self.node_order
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/link/c/basic.py:1120, in CLinker.__compile__(self, input_storage, output_storage, storage_map, cache)
#    1118 input_storage = tuple(input_storage)
#    1119 output_storage = tuple(output_storage)
# -> 1120 thunk, module = self.cthunk_factory(
#    1121     error_storage,
#    1122     input_storage,
#    1123     output_storage,
#    1124     storage_map,
#    1125     cache,
#    1126 )
#    1127 return (
#    1128     thunk,
#    1129     module,
#    (...)
#    1138     error_storage,
#    1139 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/link/c/basic.py:1644, in CLinker.cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, cache)
#    1642     if cache is None:
#    1643         cache = get_module_cache()
# -> 1644     module = cache.module_from_key(key=key, lnk=self)
#    1646 vars = self.inputs + self.outputs + self.orphans
#    1647 # List of indices that should be ignored when passing the arguments
#    1648 # (basically, everything that the previous call to uniq eliminated)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/link/c/cmodule.py:1197, in ModuleCache.module_from_key(self, key, lnk)
#    1195 # Is the source code already in the cache?
#    1196 module_hash = get_module_hash(src_code, key)
# -> 1197 module = self._get_from_hash(module_hash, key)
#    1198 if module is not None:
#    1199     return module
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/link/c/cmodule.py:1111, in ModuleCache._get_from_hash(self, module_hash, key)
#    1107     # We need the lock while we check in case of parallel
#    1108     # process that could be changing the file at the same
#    1109     # time.
#    1110     if key[0] and not key_broken and self.check_for_broken_eq:
# -> 1111         self.check_key(key, key_data.key_pkl)
#    1112 self._update_mappings(
#    1113     key, key_data, module.__file__, check_in_keys=not key_broken
#    1114 )
#    1115 return module
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/link/c/cmodule.py:1281, in ModuleCache.check_key(self, key, key_pkl)
#    1279 try:
#    1280     with open(key_pkl, "rb") as f:
# -> 1281         key_data = pickle.load(f)
#    1282     break
#    1283 except EOFError:
#    1284     # This file is probably getting written/updated at the
#    1285     # same time.  This can happen as we read the cache
#    1286     # without taking the lock.
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/elemwise.py:187, in DimShuffle.__setstate__(self, state)
#     184     if self.inplace:
#     185         self.view_map = {0: [0]}
# --> 187 def __setstate__(self, state):
#     188     self.__dict__.update(state)
#     189     if not hasattr(self, "func_files"):
#     190         # Perhaps we are loading an old `Op` version of DimShuffle.
#     191         # Let's just build the ExternalCOp.
#
# KeyboardInterrupt:

# %% [markdown]
# # Functions

# %%
def this_Bayesian_mixture_model2(ISI_data):
    import scipy.stats as st
    with pm.Model() as model:
        ##### WALD DISTRIBUTION (INVERSE GAUSSIAN)
        mu1 = pm.Uniform('mu1',lower=0,upper=0.18)
        lam1 = pm.Uniform('lam1',lower=0.001,upper=0.5)
        obs1 = pm.Wald.dist(mu=mu1,lam=lam1)


        mu2 = pm.Uniform('mu2',lower=0,upper=0.18)
        sigma2 = pm.Uniform('sigma2',lower=0.01,upper=0.7)
        obs2 = pm.TruncatedNormal.dist(mu=mu2, sigma=sigma2, lower=0.0)

        mu3 = pm.Uniform('mu3',lower=0.2,upper=0.6)
        sigma3 = pm.Uniform('sigma3',lower=0.01,upper=0.7)
        obs3 = pm.TruncatedNormal.dist(mu=mu3, sigma=sigma3, lower=0.0)
        
        w = pm.Dirichlet('w', a=np.array([1., 1., 1.]))
        like = pm.Mixture('like', w=w, comp_dists = [obs1, obs2, obs3], observed=ISI_data)
        
    map_estimate = pm.find_MAP(model=model)
    d= np.linspace(0.00, 1, len(ISI_data))
    map_estimate['w1'] = map_estimate['w'][0]
    map_estimate['w2'] = map_estimate['w'][1]
    map_estimate['w3'] = map_estimate['w'][2]
    
    mu1=map_estimate['mu1']
    mu2=map_estimate['mu2']
    mu3=map_estimate['mu3']
    lam1=map_estimate['lam1']
    sigma2=map_estimate['sigma2']
    sigma3=map_estimate['sigma3']
    w1=map_estimate['w1']
    w2=map_estimate['w2']
    w3=map_estimate['w3']       
    
    pdf = w1*st.invgauss.pdf(d, mu1/lam1, scale = lam1) + w2*st.norm.pdf(d, mu2, sigma2) + w3*st.norm.pdf(d, mu3, sigma3)
    bins = np.arange(0, .5, 1e-3) 
    
    #plt.hist(ISI_data, bins, color='orange', alpha=0.7, label='Histogram',density=True)
    #plt.plot(d, pdf, color='blue', label='PDF')
    #plt.xlim(0, 0.2)
    #plt.show()

    cdf_2gauss = lambda x: w1 * st.invgauss.cdf(x,mu1/lam1, scale = lam1) + w2 * st.norm.cdf(x, mu2, sigma2) + w3*st.norm.cdf(x, mu3, sigma3)
    ks_score=st.ks_1samp(ISI_data[ISI_data>0],  cdf_2gauss, method = 'asymp')
    print('ks score: ',ks_score[0])
    
    del map_estimate['w_simplex__']
    del map_estimate['mu1_interval__']
    del map_estimate['lam1_interval__']
    del map_estimate['mu2_interval__']
    del map_estimate['sigma2_interval__']
    del map_estimate['mu3_interval__']
    del map_estimate['sigma3_interval__']
    
    del map_estimate['w']

    print(map_estimate)
    if ks_score[0]>0.3:
        map_estimate=0
    return map_estimate

# %%
def this_poiproc(file,target,stim,):
    file_name = file.split("/")[-1]
    print(file,'target',target,'stimulation',stim)
    dataframe = pd.DataFrame()
    counter=0
    list_neurons = np.genfromtxt(file, delimiter=',')
    counter=0
    print('Original number of neurons: ',len(list_neurons))
    for neuron in tqdm(list_neurons):
        neuron=neuron[neuron>0*10000]
        neuron=neuron[neuron<200*10000]
        #print('  Neuron with ',neuron.shape[0],'spikes')
        if neuron.shape[0]>800:
            
            print('  Neuron with ',neuron.shape[0],'spikes')
        else:
            print('    Excluded neuron with n spikes = ',neuron.shape[0])
            continue
        
        ISI_healthy = np.diff(neuron)/10000
        try:
            map_estimate = this_Bayesian_mixture_model2(ISI_healthy)
        except Exception as e:
            print(f"An error occurred: {e}")
            continue
        if map_estimate!=0:
            counter+=1
            map_estimate['Target']=target
            map_estimate['Stimulation']=stim
            df = pd.DataFrame.from_dict(map_estimate,orient='index')
            dataframe = pd.concat([dataframe,df],axis = 1)
    print('Final number of neurons: ',counter)
    print('Target = ',target)
    final = dataframe.T
    final.to_csv('Data after PP third version/'+file_name)
    return dataframe

# %%
def this_Bayesian_mixture_model1(ISI_data):
    import scipy.stats as st
    with pm.Model() as model:
        ##### WALD DISTRIBUTION (INVERSE GAUSSIAN)
        mu1 = pm.Uniform('mu1',lower=0,upper=0.2)
        lam1 = pm.Uniform('lam1',lower=0.001,upper=2)
        obs1 = pm.Wald.dist(mu=mu1,lam=lam1)


        mu2 = pm.Uniform('mu2',lower=0,upper=0.2)
        sigma2 = pm.Uniform('sigma2',lower=0.01,upper=2)
        obs2 = pm.TruncatedNormal.dist(mu=mu2, sigma=sigma2, lower=0.0)
        
        w = pm.Dirichlet('w', a=np.array([1., 1.]))
        like = pm.Mixture('like', w=w, comp_dists = [obs1, obs2], observed=ISI_data)
        
    map_estimate = pm.find_MAP(model=model)
    d= np.linspace(0.00, 1, len(ISI_data))
    map_estimate['w1'] = map_estimate['w'][0]
    map_estimate['w2'] = map_estimate['w'][1]
    
    mu1=map_estimate['mu1']
    mu2=map_estimate['mu2']
    lam1=map_estimate['lam1']
    sigma2=map_estimate['sigma2']
    w1=map_estimate['w1']
    w2=map_estimate['w2']
    
    pdf = w1*st.invgauss.pdf(d, mu1/lam1, scale = lam1) + w2*st.norm.pdf(d, mu2, sigma2) 
    bins = np.arange(0, .5, 1e-3) 
    
    plt.hist(ISI_data, bins, color='orange', alpha=0.7, label='Histogram',density=True)
    plt.plot(d, pdf, color='blue', label='PDF')
    #plt.xlim(0, 0.2)
    plt.show()

    cdf_2gauss = lambda x: w1 * st.invgauss.cdf(x,mu1/lam1, scale = lam1) + w2 * st.norm.cdf(x, mu2, sigma2)
    ks_score=st.ks_1samp(ISI_data[ISI_data>0],  cdf_2gauss, method = 'asymp')
    print('ks score: ',ks_score)
    
    del map_estimate['w_simplex__']
    del map_estimate['mu1_interval__']
    del map_estimate['lam1_interval__']
    del map_estimate['mu2_interval__']
    del map_estimate['sigma2_interval__']
    
    del map_estimate['w']

    print(map_estimate)
    return map_estimate

# %%
def this_Bayesian_mixture_model(ISI_data):
    import scipy.stats as st
    with pm.Model() as model:
        ##### WALD DISTRIBUTION (INVERSE GAUSSIAN)
        mu1 = pm.Uniform('mu1',lower=0.015,upper=0.1)
        lam1 = pm.Uniform('lam1',lower=0.001,upper=0.5)
        obs1 = pm.Wald.dist(mu=mu1,lam=lam1)


        mu2 = pm.Uniform('mu2',lower=0,upper=0.1)
        sigma2 = pm.Uniform('sigma2',lower=0.01,upper=0.7)
        obs2 = pm.TruncatedNormal.dist(mu=mu2, sigma=sigma2, lower=0.0)

        mu3 = pm.Uniform('mu3',lower=0.1,upper=0.6)
        sigma3 = pm.Uniform('sigma3',lower=0.01,upper=0.7)
        obs3 = pm.TruncatedNormal.dist(mu=mu3, sigma=sigma3, lower=0.0)
        
        w = pm.Dirichlet('w', a=np.array([1., 1., 1.]))
        like = pm.Mixture('like', w=w, comp_dists = [obs1, obs2, obs3], observed=ISI_data)
        
    map_estimate = pm.find_MAP(model=model)
    d= np.linspace(0.00, 1, len(ISI_data))
    map_estimate['w1'] = map_estimate['w'][0]
    map_estimate['w2'] = map_estimate['w'][1]
    map_estimate['w3'] = map_estimate['w'][2]
    
    mu1=map_estimate['mu1']
    mu2=map_estimate['mu2']
    mu3=map_estimate['mu3']
    lam1=map_estimate['lam1']
    sigma2=map_estimate['sigma2']
    sigma3=map_estimate['sigma3']
    w1=map_estimate['w1']
    w2=map_estimate['w2']
    w3=map_estimate['w3']       
    
    pdf = w1*st.invgauss.pdf(d, mu1/lam1, scale = lam1) + w2*st.norm.pdf(d, mu2, sigma2) + w3*st.norm.pdf(d, mu3, sigma3)
    bins = np.arange(0, .5, 1e-3) 
    
    plt.hist(ISI_data, bins, color='orange', alpha=0.7, label='Histogram',density=True)
    plt.plot(d, pdf, color='blue', label='PDF')
    #plt.xlim(0, 0.2)
    plt.show()

    cdf_2gauss = lambda x: w1 * st.invgauss.cdf(x,mu1/lam1, scale = lam1) + w2 * st.norm.cdf(x, mu2, sigma2) + w3*st.norm.cdf(x, mu3, sigma3)
    ks_score=st.ks_1samp(ISI_data[ISI_data>0],  cdf_2gauss, method = 'asymp')
    print('ks score: ',ks_score)
    
    del map_estimate['w_simplex__']
    del map_estimate['mu1_interval__']
    del map_estimate['lam1_interval__']
    del map_estimate['mu2_interval__']
    del map_estimate['sigma2_interval__']
    del map_estimate['mu3_interval__']
    del map_estimate['sigma3_interval__']
    
    del map_estimate['w']

    print(map_estimate)
    if ks_score[0]>0.3:
        map_estimate=0
    return map_estimate
