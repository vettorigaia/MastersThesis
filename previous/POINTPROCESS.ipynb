# %% [markdown]
# # Point Process

# %%
import glob
list_dir=glob.glob("/Users/Gaia_1/Desktop/tesi/Data after SS new/*.txt")
for file in list_dir:
    print(file)
print(len(list_dir))
# Out:
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-28T11-55-53MIP3 KA 24hrs after.h5.txt.txt
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T10-03-29MIP4 BL .h5.txt.txt
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T09-22-44MIP 5 BL .h5.txt.txt
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T10-17-41POP 1 BL .h5.txt.txt
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T10-29-42POP 2 BL .h5.txt.txt
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T09-49-48MIP 3 BL .h5.txt.txt
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2019-01-23T11-05-52MIP3 health cortical .h5.txt.txt
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2019-01-23T11-30-29MEA2 healthy cortical .h5.txt.txt
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T10-40-53POP 3 BL .h5.txt.txt
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2019-01-23T11-19-05PoP1 healthy cortical .h5.txt.txt
# 10

# %%
from NewLibraryENGcopia import *
import glob
finaldf=[]
output_path='/Users/Gaia_1/Desktop/tesi/Data after SS new'
list_dir=glob.glob(output_path+"/*")

for file in list_dir:
    target=1
    stim=0
    if 'health' in file:
        target=0
    if 'stimulation' in file:
        stim=1
    print(file,'target',target,'stimulation',stim)
    df=poiproc(file,target,stim)
    finaldf.append(df)
# Out:
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-28T11-55-53MIP3 KA 24hrs after.h5.txt.txt target 1 stimulation 0
# Original number of neurons:  58
#   0%|          | 0/58 [00:00<?, ?it/s]
#     Excluded neuron with n spikes =  146
#     Excluded neuron with n spikes =  155
#     Excluded neuron with n spikes =  165
#     Excluded neuron with n spikes =  172
#     Excluded neuron with n spikes =  168
#     Excluded neuron with n spikes =  177
#     Excluded neuron with n spikes =  100
#     Excluded neuron with n spikes =  131
#     Excluded neuron with n spikes =  102
#     Excluded neuron with n spikes =  155
#     Excluded neuron with n spikes =  130
#     Excluded neuron with n spikes =  129
#     Excluded neuron with n spikes =  129
#     Excluded neuron with n spikes =  114
#     Excluded neuron with n spikes =  68
#     Excluded neuron with n spikes =  107
#     Excluded neuron with n spikes =  110
#     Excluded neuron with n spikes =  123
#     Excluded neuron with n spikes =  109
#     Excluded neuron with n spikes =  103
#     Excluded neuron with n spikes =  162
#     Excluded neuron with n spikes =  125
#     Excluded neuron with n spikes =  308
#     Excluded neuron with n spikes =  369
#     Excluded neuron with n spikes =  182
#     Excluded neuron with n spikes =  167
#     Excluded neuron with n spikes =  160
#     Excluded neuron with n spikes =  192
#     Excluded neuron with n spikes =  174
#     Excluded neuron with n spikes =  182
#     Excluded neuron with n spikes =  172
#     Excluded neuron with n spikes =  174
#     Excluded neuron with n spikes =  152
#     Excluded neuron with n spikes =  172
#     Excluded neuron with n spikes =  176
#     Excluded neuron with n spikes =  486
#     Excluded neuron with n spikes =  682
#     Excluded neuron with n spikes =  283
#     Excluded neuron with n spikes =  127
#     Excluded neuron with n spikes =  98
#     Excluded neuron with n spikes =  101
#     Excluded neuron with n spikes =  99
#     Excluded neuron with n spikes =  117
#     Excluded neuron with n spikes =  105
#     Excluded neuron with n spikes =  122
#     Excluded neuron with n spikes =  119
#     Excluded neuron with n spikes =  120
#     Excluded neuron with n spikes =  120
#     Excluded neuron with n spikes =  102
#     Excluded neuron with n spikes =  202
#     Excluded neuron with n spikes =  75
#     Excluded neuron with n spikes =  178
#     Excluded neuron with n spikes =  109
#     Excluded neuron with n spikes =  166
#     Excluded neuron with n spikes =  155
#     Excluded neuron with n spikes =  157
#     Excluded neuron with n spikes =  165
#     Excluded neuron with n spikes =  105
# Final number of neurons:  0
# Target =  1
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T10-03-29MIP4 BL .h5.txt.txt target 1 stimulation 0
# Original number of neurons:  58
#   0%|          | 0/58 [00:00<?, ?it/s]
#     Excluded neuron with n spikes =  707
#     Excluded neuron with n spikes =  691
#     Excluded neuron with n spikes =  692
#     Excluded neuron with n spikes =  669
#     Excluded neuron with n spikes =  637
#   Neuron with  4288 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='54' class='' max='54' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [54/54 00:00&lt;00:00 logp = 9,046.3, ||grad|| = 0.062952]
#     </div>
# ks score:  KstestResult(statistic=0.14126125556237978, pvalue=9.925115633115646e-75, statistic_location=0.0109, statistic_sign=-1)
# {'mu1': array(0.01999999), 'lam1': array(0.02), 'mu2': array(0.03642193), 'sigma2': array(0.0283828), 'mu3': array(0.04), 'sigma3': array(0.12157407), 'w1': 0.3432572208166995, 'w2': 0.4832674512512305, 'w3': 0.17347532793207}
#   Neuron with  1101 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='37' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:00&lt;00:00 logp = 788.54, ||grad|| = 0.85848]
#     </div>
# ks score:  KstestResult(statistic=0.4499132610318285, pvalue=7.896201541861902e-194, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.01999826), 'lam1': array(0.01999996), 'mu2': array(0.02000041), 'sigma2': array(0.11662025), 'mu3': array(0.04), 'sigma3': array(0.42519051), 'w1': 3.070217174590474e-21, 'w2': 0.6621775860352973, 'w3': 0.3378224139647027}
#     Excluded neuron with n spikes =  698
#     Excluded neuron with n spikes =  893
#   Neuron with  2955 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='37' class='' max='37' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:00&lt;00:00 logp = 5,129.6, ||grad|| = 2.9494]
#     </div>
# ks score:  KstestResult(statistic=0.19082098732373165, pvalue=7.464917874114572e-94, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.01999766), 'lam1': array(0.02), 'mu2': array(0.03808772), 'sigma2': array(0.03319658), 'mu3': array(0.04), 'sigma3': array(0.18069283), 'w1': 0.17058860108276522, 'w2': 0.5880041702032569, 'w3': 0.2414072287139779}
#     Excluded neuron with n spikes =  185
#     Excluded neuron with n spikes =  124
#     Excluded neuron with n spikes =  136
#     Excluded neuron with n spikes =  142
#     Excluded neuron with n spikes =  92
#     Excluded neuron with n spikes =  136
#     Excluded neuron with n spikes =  128
#     Excluded neuron with n spikes =  115
#     Excluded neuron with n spikes =  115
#     Excluded neuron with n spikes =  125
#   Neuron with  3385 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='42' class='' max='42' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [42/42 00:00&lt;00:00 logp = 6,285.5, ||grad|| = 0.028919]
#     </div>
# ks score:  KstestResult(statistic=0.18044969925699372, pvalue=3.900341734711934e-96, statistic_location=0.0088, statistic_sign=-1)
# {'mu1': array(0.01999991), 'lam1': array(0.02), 'mu2': array(0.03976592), 'sigma2': array(0.03235157), 'mu3': array(0.04), 'sigma3': array(0.12184164), 'w1': 0.2272727000915836, 'w2': 0.49258632480423326, 'w3': 0.2801409751041831}
#   Neuron with  3584 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='53' class='' max='53' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [53/53 00:00&lt;00:00 logp = 6,893.3, ||grad|| = 0.12435]
#     </div>
# ks score:  KstestResult(statistic=0.15824376400980622, pvalue=2.340446561453393e-78, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03999997), 'sigma2': array(0.03033269), 'mu3': array(0.04), 'sigma3': array(0.11724898), 'w1': 0.2955801589655439, 'w2': 0.4309607252461865, 'w3': 0.27345911578826965}
#   Neuron with  2815 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='51' class='' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [51/51 00:00&lt;00:00 logp = 4,728.8, ||grad|| = 0.01682]
#     </div>
# ks score:  KstestResult(statistic=0.18992223954229734, pvalue=1.3717714839347492e-88, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03999997), 'sigma2': array(0.0312754), 'mu3': array(0.04), 'sigma3': array(0.16312472), 'w1': 0.23480466825253513, 'w2': 0.44511391285854884, 'w3': 0.320081418888916}
#   Neuron with  5052 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='60' class='' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60/60 00:00&lt;00:00 logp = 11,564, ||grad|| = 0.82901]
#     </div>
# ks score:  KstestResult(statistic=0.0983736854735727, pvalue=6.9824040651588665e-43, statistic_location=0.012, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03538898), 'sigma2': array(0.0179941), 'mu3': array(0.04), 'sigma3': array(0.08881386), 'w1': 0.4618137751261256, 'w2': 0.3296025796473263, 'w3': 0.2085836452265482}
#     Excluded neuron with n spikes =  303
#     Excluded neuron with n spikes =  313
#     Excluded neuron with n spikes =  293
#     Excluded neuron with n spikes =  289
#     Excluded neuron with n spikes =  298
#     Excluded neuron with n spikes =  297
#     Excluded neuron with n spikes =  301
#   Neuron with  3038 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='60' class='' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60/60 00:00&lt;00:00 logp = 5,303.3, ||grad|| = 0.51231]
#     </div>
# ks score:  KstestResult(statistic=0.2130250779292065, pvalue=3.924185352540718e-120, statistic_location=0.0077, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03999981), 'sigma2': array(0.04291992), 'mu3': array(0.04), 'sigma3': array(0.15398191), 'w1': 0.20614602242450214, 'w2': 0.565464032843971, 'w3': 0.228389944731527}
#     Excluded neuron with n spikes =  293
#     Excluded neuron with n spikes =  296
#     Excluded neuron with n spikes =  290
#   Neuron with  2109 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='83' class='' max='83' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:00&lt;00:00 logp = 2,885.6, ||grad|| = 0.017348]
#     </div>
# ks score:  KstestResult(statistic=0.29094871188551585, pvalue=2.0229882835342103e-155, statistic_location=0.0031, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03999983), 'sigma2': array(0.05626624), 'mu3': array(0.04), 'sigma3': array(0.19756196), 'w1': 0.09613472259881553, 'w2': 0.5692709928366853, 'w3': 0.3345942845644993}
#   Neuron with  5410 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='54' class='' max='54' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [54/54 00:00&lt;00:00 logp = 12,809, ||grad|| = 0.17882]
#     </div>
# ks score:  KstestResult(statistic=0.08350652376983864, pvalue=3.458615647818125e-33, statistic_location=0.0083, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03496737), 'sigma2': array(0.01842304), 'mu3': array(0.04), 'sigma3': array(0.09555975), 'w1': 0.5187065970881699, 'w2': 0.32389465489767555, 'w3': 0.15739874801415446}
#   Neuron with  1631 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='41' class='' max='41' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [41/41 00:00&lt;00:00 logp = 1,811.7, ||grad|| = 0.0249]
#     </div>
# ks score:  KstestResult(statistic=0.42864383133625555, pvalue=1.473189906357281e-260, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.0127935), 'lam1': array(0.01999999), 'mu2': array(0.02000005), 'sigma2': array(0.08494023), 'mu3': array(0.04000001), 'sigma3': array(0.27549405), 'w1': 3.4334766428606425e-15, 'w2': 0.6926632180918805, 'w3': 0.3073367819081162}
#     Excluded neuron with n spikes =  134
#     Excluded neuron with n spikes =  109
#     Excluded neuron with n spikes =  125
#     Excluded neuron with n spikes =  134
#     Excluded neuron with n spikes =  139
#     Excluded neuron with n spikes =  130
#     Excluded neuron with n spikes =  178
#     Excluded neuron with n spikes =  153
#     Excluded neuron with n spikes =  145
#     Excluded neuron with n spikes =  131
#     Excluded neuron with n spikes =  136
#   Neuron with  1557 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='68' class='' max='68' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [68/68 00:00&lt;00:00 logp = 1,670.4, ||grad|| = 0.12138]
#     </div>
# ks score:  KstestResult(statistic=0.4127687031563665, pvalue=1.073984318355211e-230, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.01999992), 'lam1': array(0.02), 'mu2': array(0.02), 'sigma2': array(0.08783828), 'mu3': array(0.04), 'sigma3': array(0.33466022), 'w1': 0.048796149932723014, 'w2': 0.6782970750043422, 'w3': 0.27290677506293476}
#     Excluded neuron with n spikes =  607
#     Excluded neuron with n spikes =  709
#   Neuron with  2427 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='51' class='' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [51/51 00:00&lt;00:00 logp = 3,701.1, ||grad|| = 0.03056]
#     </div>
# ks score:  KstestResult(statistic=0.36316425695396326, pvalue=2.434838579532479e-278, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.01999998), 'lam1': array(0.02), 'mu2': array(0.02), 'sigma2': array(0.05865934), 'mu3': array(0.04), 'sigma3': array(0.22410475), 'w1': 0.09361545482904118, 'w2': 0.6800696019657997, 'w3': 0.22631494320515927}
#     Excluded neuron with n spikes =  690
#     Excluded neuron with n spikes =  713
#     Excluded neuron with n spikes =  704
#     Excluded neuron with n spikes =  710
#     Excluded neuron with n spikes =  907
# Final number of neurons:  9
# Target =  1
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T09-22-44MIP 5 BL .h5.txt.txt target 1 stimulation 0
# Original number of neurons:  58
#   0%|          | 0/58 [00:00<?, ?it/s]
#     Excluded neuron with n spikes =  852
#     Excluded neuron with n spikes =  884
#     Excluded neuron with n spikes =  907
#     Excluded neuron with n spikes =  890
#     Excluded neuron with n spikes =  808
#     Excluded neuron with n spikes =  688
#     Excluded neuron with n spikes =  513
#     Excluded neuron with n spikes =  127
#     Excluded neuron with n spikes =  567
#     Excluded neuron with n spikes =  118
#     Excluded neuron with n spikes =  111
#     Excluded neuron with n spikes =  118
#     Excluded neuron with n spikes =  134
#     Excluded neuron with n spikes =  90
#     Excluded neuron with n spikes =  122
#     Excluded neuron with n spikes =  122
#     Excluded neuron with n spikes =  109
#     Excluded neuron with n spikes =  116
#     Excluded neuron with n spikes =  114
#     Excluded neuron with n spikes =  143
#     Excluded neuron with n spikes =  197
#     Excluded neuron with n spikes =  133
#     Excluded neuron with n spikes =  304
#     Excluded neuron with n spikes =  687
#     Excluded neuron with n spikes =  684
#     Excluded neuron with n spikes =  768
#     Excluded neuron with n spikes =  749
#     Excluded neuron with n spikes =  732
#     Excluded neuron with n spikes =  762
#     Excluded neuron with n spikes =  726
#     Excluded neuron with n spikes =  547
#     Excluded neuron with n spikes =  758
#     Excluded neuron with n spikes =  743
#     Excluded neuron with n spikes =  757
#     Excluded neuron with n spikes =  132
#     Excluded neuron with n spikes =  358
#     Excluded neuron with n spikes =  369
#     Excluded neuron with n spikes =  159
#     Excluded neuron with n spikes =  118
#     Excluded neuron with n spikes =  128
#     Excluded neuron with n spikes =  106
#     Excluded neuron with n spikes =  125
#     Excluded neuron with n spikes =  96
#     Excluded neuron with n spikes =  110
#     Excluded neuron with n spikes =  144
#     Excluded neuron with n spikes =  136
#     Excluded neuron with n spikes =  110
#     Excluded neuron with n spikes =  104
#     Excluded neuron with n spikes =  118
#     Excluded neuron with n spikes =  136
#     Excluded neuron with n spikes =  461
#     Excluded neuron with n spikes =  948
#   Neuron with  2201 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='43' class='' max='43' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [43/43 00:00&lt;00:00 logp = 3,133.4, ||grad|| = 0.15888]
#     </div>
# ks score:  KstestResult(statistic=0.36559989350288, pvalue=7.663659552535095e-256, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.01999475), 'lam1': array(0.02), 'mu2': array(0.02019689), 'sigma2': array(0.06972367), 'mu3': array(0.04), 'sigma3': array(0.24802586), 'w1': 0.12041362755866114, 'w2': 0.6576284974856142, 'w3': 0.22195787495572458}
#   Neuron with  1409 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='51' class='' max='51' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [51/51 00:00&lt;00:00 logp = 1,350.7, ||grad|| = 0.023067]
#     </div>
# ks score:  KstestResult(statistic=0.42461460673399953, pvalue=6.337673840411131e-221, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.01999995), 'lam1': array(0.02), 'mu2': array(0.02000001), 'sigma2': array(0.1115596), 'mu3': array(0.04), 'sigma3': array(0.3285105), 'w1': 0.04647901372097406, 'w2': 0.671710675564083, 'w3': 0.28181031071494295}
#     Excluded neuron with n spikes =  924
#     Excluded neuron with n spikes =  890
#     Excluded neuron with n spikes =  915
#     Excluded neuron with n spikes =  407
# Final number of neurons:  0
# Target =  1
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T10-17-41POP 1 BL .h5.txt.txt target 1 stimulation 0
# Original number of neurons:  58
#   0%|          | 0/58 [00:00<?, ?it/s]
#     Excluded neuron with n spikes =  235
#     Excluded neuron with n spikes =  239
#     Excluded neuron with n spikes =  214
#     Excluded neuron with n spikes =  250
#     Excluded neuron with n spikes =  220
#   Neuron with  1967 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='58' class='' max='58' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [58/58 00:00&lt;00:00 logp = 2,560.7, ||grad|| = 0.15152]
#     </div>
# ks score:  KstestResult(statistic=0.2958365655771357, pvalue=7.064820437104364e-150, statistic_location=0.0031, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03999973), 'sigma2': array(0.05475256), 'mu3': array(0.04), 'sigma3': array(0.1917552), 'w1': 0.12373541690408434, 'w2': 0.4519855657066509, 'w3': 0.42427901738926466}
#     Excluded neuron with n spikes =  261
#     Excluded neuron with n spikes =  618
#     Excluded neuron with n spikes =  374
#     Excluded neuron with n spikes =  726
#     Excluded neuron with n spikes =  157
#     Excluded neuron with n spikes =  185
#     Excluded neuron with n spikes =  178
#     Excluded neuron with n spikes =  197
#     Excluded neuron with n spikes =  133
#     Excluded neuron with n spikes =  144
#     Excluded neuron with n spikes =  179
#     Excluded neuron with n spikes =  172
#     Excluded neuron with n spikes =  155
#     Excluded neuron with n spikes =  150
#     Excluded neuron with n spikes =  288
#     Excluded neuron with n spikes =  182
#   Neuron with  1207 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='47' class='' max='47' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [47/47 00:00&lt;00:00 logp = 978.53, ||grad|| = 0.050023]
#     </div>
# ks score:  KstestResult(statistic=0.44137016690342323, pvalue=1.723774740778754e-204, statistic_location=0.0031, statistic_sign=-1)
# {'mu1': array(0.01999977), 'lam1': array(0.02), 'mu2': array(0.02000003), 'sigma2': array(0.09677937), 'mu3': array(0.04), 'sigma3': array(0.33500691), 'w1': 3.870248338342329e-25, 'w2': 0.5803936918944749, 'w3': 0.41960630810552524}
#   Neuron with  1094 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='42' class='' max='42' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [42/42 00:00&lt;00:00 logp = 781.39, ||grad|| = 0.0040975]
#     </div>
# ks score:  KstestResult(statistic=0.44010030882408024, pvalue=2.627992423247182e-184, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.01999929), 'lam1': array(0.02), 'mu2': array(0.02), 'sigma2': array(0.12643581), 'mu3': array(0.04), 'sigma3': array(0.37940755), 'w1': 0.028169219722212053, 'w2': 0.5994700119916373, 'w3': 0.3723607682861505}
#     Excluded neuron with n spikes =  100
#     Excluded neuron with n spikes =  112
#     Excluded neuron with n spikes =  123
#     Excluded neuron with n spikes =  95
#     Excluded neuron with n spikes =  86
#     Excluded neuron with n spikes =  116
#     Excluded neuron with n spikes =  114
#     Excluded neuron with n spikes =  772
#     Excluded neuron with n spikes =  112
#     Excluded neuron with n spikes =  111
#     Excluded neuron with n spikes =  107
#     Excluded neuron with n spikes =  252
#   Neuron with  1305 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='46' class='' max='46' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [46/46 00:00&lt;00:00 logp = 1,173.1, ||grad|| = 0.21141]
#     </div>
# ks score:  KstestResult(statistic=0.4184134405432063, pvalue=1.023203451824742e-198, statistic_location=0.0044, statistic_sign=-1)
# {'mu1': array(0.01998951), 'lam1': array(0.02), 'mu2': array(0.02021412), 'sigma2': array(0.09661228), 'mu3': array(0.04000012), 'sigma3': array(0.32928595), 'w1': 0.05507363595464003, 'w2': 0.5714238281326882, 'w3': 0.37350253591267163}
#     Excluded neuron with n spikes =  514
#     Excluded neuron with n spikes =  211
#     Excluded neuron with n spikes =  168
#     Excluded neuron with n spikes =  153
#     Excluded neuron with n spikes =  181
#     Excluded neuron with n spikes =  162
#     Excluded neuron with n spikes =  141
#     Excluded neuron with n spikes =  163
#     Excluded neuron with n spikes =  211
#     Excluded neuron with n spikes =  166
#     Excluded neuron with n spikes =  161
#     Excluded neuron with n spikes =  189
#     Excluded neuron with n spikes =  185
#     Excluded neuron with n spikes =  614
#     Excluded neuron with n spikes =  251
#   Neuron with  3661 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='45' class='' max='45' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [45/45 00:00&lt;00:00 logp = 7,133.9, ||grad|| = 0.53776]
#     </div>
# ks score:  KstestResult(statistic=0.15326977479298637, pvalue=4.171778579044481e-75, statistic_location=0.0089, statistic_sign=-1)
# {'mu1': array(0.01999691), 'lam1': array(0.01999999), 'mu2': array(0.03717452), 'sigma2': array(0.02135432), 'mu3': array(0.04000111), 'sigma3': array(0.11039712), 'w1': 0.34880884608894935, 'w2': 0.30803328330752777, 'w3': 0.34315787060352293}
#     Excluded neuron with n spikes =  226
#     Excluded neuron with n spikes =  218
#     Excluded neuron with n spikes =  203
#     Excluded neuron with n spikes =  210
#     Excluded neuron with n spikes =  454
# Final number of neurons:  2
# Target =  1
# /Users/Gaia_1/Desktop/tesi/Data after SS new/After2018-11-27T10-29-42POP 2 BL .h5.txt.txt target 1 stimulation 0
# Original number of neurons:  58
#   0%|          | 0/58 [00:00<?, ?it/s]
#     Excluded neuron with n spikes =  162
#     Excluded neuron with n spikes =  162
#     Excluded neuron with n spikes =  178
#     Excluded neuron with n spikes =  203
#     Excluded neuron with n spikes =  157
#   Neuron with  2824 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='60' class='' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [60/60 00:00&lt;00:00 logp = 4,720.6, ||grad|| = 0.26872]
#     </div>
# ks score:  KstestResult(statistic=0.2279659007320947, pvalue=7.464509152299886e-128, statistic_location=0.0124, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03999029), 'sigma2': array(0.04951387), 'mu3': array(0.04), 'sigma3': array(0.16839577), 'w1': 0.21558588825627695, 'w2': 0.5552048838031648, 'w3': 0.22920922794055829}
#     Excluded neuron with n spikes =  520
#   Neuron with  1372 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='44' class='' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44/44 00:00&lt;00:00 logp = 1,293.9, ||grad|| = 0.016122]
#     </div>
# ks score:  KstestResult(statistic=0.4360616328413185, pvalue=7.310818750389672e-227, statistic_location=0.003, statistic_sign=-1)
# {'mu1': array(0.00283976), 'lam1': array(0.02), 'mu2': array(0.0200001), 'sigma2': array(0.09154421), 'mu3': array(0.04), 'sigma3': array(0.32063486), 'w1': 1.000960308313315e-63, 'w2': 0.6493283129062404, 'w3': 0.35067168709375957}
#     Excluded neuron with n spikes =  751
#   Neuron with  2690 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='47' class='' max='47' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [47/47 00:00&lt;00:00 logp = 4,348.6, ||grad|| = 0.10502]
#     </div>
# ks score:  KstestResult(statistic=0.3496615866587544, pvalue=5.4786500723182035e-286, statistic_location=0.0083, statistic_sign=-1)
# {'mu1': array(0.01999988), 'lam1': array(0.02), 'mu2': array(0.02003667), 'sigma2': array(0.06317603), 'mu3': array(0.04000001), 'sigma3': array(0.18672551), 'w1': 0.14680790131952212, 'w2': 0.6489052302746147, 'w3': 0.20428686840586324}
#     Excluded neuron with n spikes =  236
#     Excluded neuron with n spikes =  233
#     Excluded neuron with n spikes =  222
#     Excluded neuron with n spikes =  208
#     Excluded neuron with n spikes =  176
#     Excluded neuron with n spikes =  235
#     Excluded neuron with n spikes =  238
#     Excluded neuron with n spikes =  232
#     Excluded neuron with n spikes =  389
#     Excluded neuron with n spikes =  198
#     Excluded neuron with n spikes =  558
#     Excluded neuron with n spikes =  375
#   Neuron with  6903 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='42' class='' max='42' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [42/42 00:00&lt;00:00 logp = 18,127, ||grad|| = 0.024892]
#     </div>
# ks score:  KstestResult(statistic=0.03720892303258383, pvalue=1.0021376354136394e-08, statistic_location=0.0137, statistic_sign=-1)
# {'mu1': array(0.01999941), 'lam1': array(0.01999993), 'mu2': array(0.03247401), 'sigma2': array(0.01487762), 'mu3': array(0.06284079), 'sigma3': array(0.0434991), 'w1': 0.6649753820869149, 'w2': 0.22885425507384413, 'w3': 0.10617036283924092}
#   Neuron with  3494 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='46' class='' max='46' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [46/46 00:00&lt;00:00 logp = 6,586.5, ||grad|| = 2.1349]
#     </div>
# ks score:  KstestResult(statistic=0.18401561766989152, pvalue=3.6738619071559695e-103, statistic_location=0.0111, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03935254), 'sigma2': array(0.03621202), 'mu3': array(0.04), 'sigma3': array(0.12616867), 'w1': 0.26325983547805587, 'w2': 0.4972203762978325, 'w3': 0.23951978822411155}
#     Excluded neuron with n spikes =  324
#     Excluded neuron with n spikes =  347
#     Excluded neuron with n spikes =  340
#     Excluded neuron with n spikes =  340
#     Excluded neuron with n spikes =  348
#     Excluded neuron with n spikes =  324
#     Excluded neuron with n spikes =  351
#   Neuron with  3944 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='57' class='' max='57' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [57/57 00:00&lt;00:00 logp = 7,938.1, ||grad|| = 2.7321]
#     </div>
# ks score:  KstestResult(statistic=0.15714436946908256, pvalue=5.329265713869536e-85, statistic_location=0.0134, statistic_sign=-1)
# {'mu1': array(0.01999568), 'lam1': array(0.01999994), 'mu2': array(0.03819334), 'sigma2': array(0.02870429), 'mu3': array(0.04000612), 'sigma3': array(0.10244068), 'w1': 0.31170844011096477, 'w2': 0.4309531038660225, 'w3': 0.2573384560230127}
#     Excluded neuron with n spikes =  320
#     Excluded neuron with n spikes =  338
#     Excluded neuron with n spikes =  334
#     Excluded neuron with n spikes =  807
#   Neuron with  1894 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='47' class='' max='47' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [47/47 00:00&lt;00:00 logp = 2,389.7, ||grad|| = 0.035646]
#     </div>
# ks score:  KstestResult(statistic=0.3937787581866593, pvalue=2.20055658890544e-255, statistic_location=0.0031, statistic_sign=-1)
# {'mu1': array(0.01999999), 'lam1': array(0.02), 'mu2': array(0.02000001), 'sigma2': array(0.07864086), 'mu3': array(0.04), 'sigma3': array(0.23663668), 'w1': 0.07221726812852067, 'w2': 0.6346399582828203, 'w3': 0.29314277358865903}
#     Excluded neuron with n spikes =  981
#     Excluded neuron with n spikes =  230
#     Excluded neuron with n spikes =  207
#     Excluded neuron with n spikes =  224
#     Excluded neuron with n spikes =  209
#     Excluded neuron with n spikes =  209
#     Excluded neuron with n spikes =  222
#     Excluded neuron with n spikes =  251
#     Excluded neuron with n spikes =  247
#     Excluded neuron with n spikes =  252
#     Excluded neuron with n spikes =  221
#     Excluded neuron with n spikes =  254
#   Neuron with  3274 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='53' class='' max='53' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [53/53 00:00&lt;00:00 logp = 6,000.8, ||grad|| = 0.13481]
#     </div>
# ks score:  KstestResult(statistic=0.1938235116189942, pvalue=3.166243586225716e-107, statistic_location=0.0134, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03956025), 'sigma2': array(0.04743461), 'mu3': array(0.04), 'sigma3': array(0.16272593), 'w1': 0.33955850389941494, 'w2': 0.46843799529685215, 'w3': 0.1920035008037329}
#   Neuron with  1578 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='74' class='' max='74' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [74/74 00:00&lt;00:00 logp = 1,714.6, ||grad|| = 0.0084719]
#     </div>
# ks score:  KstestResult(statistic=0.3377727737601981, pvalue=1.0567020831476586e-156, statistic_location=0.0047, statistic_sign=-1)
# {'mu1': array(0.01999997), 'lam1': array(0.02), 'mu2': array(0.03999942), 'sigma2': array(0.07254747), 'mu3': array(0.04), 'sigma3': array(0.27617471), 'w1': 0.08343264418000594, 'w2': 0.5616985169030463, 'w3': 0.3548688389169478}
#     Excluded neuron with n spikes =  161
#   Neuron with  1185 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='44' class='' max='44' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44/44 00:00&lt;00:00 logp = 939.21, ||grad|| = 0.0154]
#     </div>
# ks score:  KstestResult(statistic=0.431744162722223, pvalue=4.003339282738322e-192, statistic_location=0.0052, statistic_sign=-1)
# {'mu1': array(0.01999999), 'lam1': array(0.02), 'mu2': array(0.02000001), 'sigma2': array(0.13028169), 'mu3': array(0.04), 'sigma3': array(0.3985805), 'w1': 0.050472849321045885, 'w2': 0.6623451036270024, 'w3': 0.28718204705195166}
#     Excluded neuron with n spikes =  150
#     Excluded neuron with n spikes =  168
#     Excluded neuron with n spikes =  179
#     Excluded neuron with n spikes =  186
#   Neuron with  1091 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='40' class='' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [40/40 00:00&lt;00:00 logp = 781.24, ||grad|| = 0.07335]
#     </div>
# ks score:  KstestResult(statistic=0.45016127120577776, pvalue=2.7815664253264355e-192, statistic_location=0.0043, statistic_sign=-1)
# ...
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03999963), 'sigma2': array(0.0452849), 'mu3': array(0.04000007), 'sigma3': array(0.13524603), 'w1': 0.23774507493205604, 'w2': 0.4583624580982686, 'w3': 0.3038924669696754}
#   Neuron with  3067 spikes
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='59' class='' max='59' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [59/59 00:00&lt;00:00 logp = 5,389.7, ||grad|| = 0.063794]
#     </div>
# ks score:  KstestResult(statistic=0.2130742517515879, pvalue=2.4824322451932064e-121, statistic_location=0.009, statistic_sign=-1)
# {'mu1': array(0.02), 'lam1': array(0.02), 'mu2': array(0.03999997), 'sigma2': array(0.03789497), 'mu3': array(0.04), 'sigma3': array(0.12366113), 'w1': 0.2435702844136981, 'w2': 0.4149932765699951, 'w3': 0.3414364390163067}
#   Neuron with  2184 spikes
# Exception ignored in: <function tqdm.__del__ at 0x112cdfec0>
# Traceback (most recent call last):
#   File "/Users/Gaia_1/anaconda3/lib/python3.11/site-packages/tqdm/std.py", line 1144, in __del__
#     def __del__(self):
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 15
#      13     stim=1
#      14 print(file,'target',target,'stimulation',stim)
# ---> 15 df=poiproc(file,target,stim)
#      16 finaldf.append(df)
#
# File ~/Desktop/tesi/NewLibraryENGcopia.py:142, in poiproc(file, target, stim)
#     139     continue
#     141 ISI_healthy = np.diff(neuron)/10000
# --> 142 map_estimate = Bayesian_mixture_model(ISI_healthy)
#     143 if map_estimate!=0:
#     144     counter+=1
#
# File ~/Desktop/tesi/NewLibraryENGcopia.py:235, in Bayesian_mixture_model(ISI_data)
#     232     w = pm.Dirichlet('w', a=np.array([1., 1., 1.]))
#     233     like = pm.Mixture('like', w=w, comp_dists = [obs1, obs2, obs3], observed=ISI_data)
# --> 235 map_estimate = pm.find_MAP(model=model)
#     236 d= np.linspace(0.00, 1, len(ISI_data))
#     237 map_estimate['w1'] = map_estimate['w'][0]
#
# File ~/anaconda3/lib/python3.11/site-packages/pymc/tuning/starting.py:142, in find_MAP(start, vars, method, return_raw, include_transformed, progressbar, maxeval, model, seed, *args, **kwargs)
#     137 rvs = [model.values_to_rvs[vars_dict[name]] for name, _, _ in x0.point_map_info]
#     138 try:
#     139     # This might be needed for calls to `dlogp_func`
#     140     # start_map_info = tuple((v.name, v.shape, v.dtype) for v in vars)
#     141     compiled_dlogp_func = DictToArrayBijection.mapf(
# --> 142         model.compile_dlogp(rvs, jacobian=False), start
#     143     )
#     144     dlogp_func = lambda x: compiled_dlogp_func(RaveledVars(x, x0.point_map_info))
#     145     compute_gradient = True
#
# File ~/anaconda3/lib/python3.11/site-packages/pymc/model/core.py:650, in Model.compile_dlogp(self, vars, jacobian)
#     635 def compile_dlogp(
#     636     self,
#     637     vars: Optional[Union[Variable, Sequence[Variable]]] = None,
#     638     jacobian: bool = True,
#     639 ) -> PointFunc:
#     640     """Compiled log probability density gradient function.
#     641
#     642     Parameters
#    (...)
#     648         Whether to include jacobian terms in logprob graph. Defaults to True.
#     649     """
# --> 650     return self.model.compile_fn(self.dlogp(vars=vars, jacobian=jacobian))
#
# File ~/anaconda3/lib/python3.11/site-packages/pymc/model/core.py:1570, in Model.compile_fn(self, outs, inputs, mode, point_fn, **kwargs)
#    1567     inputs = inputvars(outs)
#    1569 with self:
# -> 1570     fn = compile_pymc(
#    1571         inputs,
#    1572         outs,
#    1573         allow_input_downcast=True,
#    1574         accept_inplace=True,
#    1575         mode=mode,
#    1576         **kwargs,
#    1577     )
#    1579 if point_fn:
#    1580     return PointFunc(fn)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymc/pytensorf.py:1195, in compile_pymc(inputs, outputs, random_seed, mode, **kwargs)
#    1193 opt_qry = mode.provided_optimizer.including("random_make_inplace", check_parameter_opt)
#    1194 mode = Mode(linker=mode.linker, optimizer=opt_qry)
# -> 1195 pytensor_function = pytensor.function(
#    1196     inputs,
#    1197     outputs,
#    1198     updates={**rng_updates, **kwargs.pop("updates", {})},
#    1199     mode=mode,
#    1200     **kwargs,
#    1201 )
#    1202 return pytensor_function
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/__init__.py:315, in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     309     fn = orig_function(
#     310         inputs, outputs, mode=mode, accept_inplace=accept_inplace, name=name
#     311     )
#     312 else:
#     313     # note: pfunc will also call orig_function -- orig_function is
#     314     #      a choke point that all compilation must pass through
# --> 315     fn = pfunc(
#     316         params=inputs,
#     317         outputs=outputs,
#     318         mode=mode,
#     319         updates=updates,
#     320         givens=givens,
#     321         no_default_updates=no_default_updates,
#     322         accept_inplace=accept_inplace,
#     323         name=name,
#     324         rebuild_strict=rebuild_strict,
#     325         allow_input_downcast=allow_input_downcast,
#     326         on_unused_input=on_unused_input,
#     327         profile=profile,
#     328         output_keys=output_keys,
#     329     )
#     330 return fn
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/pfunc.py:469, in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys, fgraph)
#     455     profile = ProfileStats(message=profile)
#     457 inputs, cloned_outputs = construct_pfunc_ins_and_outs(
#     458     params,
#     459     outputs,
#    (...)
#     466     fgraph=fgraph,
#     467 )
# --> 469 return orig_function(
#     470     inputs,
#     471     cloned_outputs,
#     472     mode,
#     473     accept_inplace=accept_inplace,
#     474     name=name,
#     475     profile=profile,
#     476     on_unused_input=on_unused_input,
#     477     output_keys=output_keys,
#     478     fgraph=fgraph,
#     479 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/types.py:1744, in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys, fgraph)
#    1742 try:
#    1743     Maker = getattr(mode, "function_maker", FunctionMaker)
# -> 1744     m = Maker(
#    1745         inputs,
#    1746         outputs,
#    1747         mode,
#    1748         accept_inplace=accept_inplace,
#    1749         profile=profile,
#    1750         on_unused_input=on_unused_input,
#    1751         output_keys=output_keys,
#    1752         name=name,
#    1753         fgraph=fgraph,
#    1754     )
#    1755     with config.change_flags(compute_test_value="off"):
#    1756         fn = m.create(defaults)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/types.py:1518, in FunctionMaker.__init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys, name, no_fgraph_prep)
#    1515 self.fgraph = fgraph
#    1517 if not no_fgraph_prep:
# -> 1518     self.prepare_fgraph(inputs, outputs, found_updates, fgraph, mode, profile)
#    1520 assert len(fgraph.outputs) == len(outputs + found_updates)
#    1522 # The 'no_borrow' outputs are the ones for which that we can't
#    1523 # return the internal storage pointer.
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/compile/function/types.py:1411, in FunctionMaker.prepare_fgraph(inputs, outputs, additional_outputs, fgraph, mode, profile)
#    1404 rewrite_time = None
#    1406 with config.change_flags(
#    1407     mode=mode,
#    1408     compute_test_value=config.compute_test_value_opt,
#    1409     traceback__limit=config.traceback__compile_limit,
#    1410 ):
# -> 1411     rewriter_profile = rewriter(fgraph)
#    1413     end_rewriter = time.perf_counter()
#    1414     rewrite_time = end_rewriter - start_rewriter
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:125, in GraphRewriter.__call__(self, fgraph)
#     123 def __call__(self, fgraph):
#     124     """Rewrite a `FunctionGraph`."""
# --> 125     return self.rewrite(fgraph)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:121, in GraphRewriter.rewrite(self, fgraph, *args, **kwargs)
#     112 """
#     113
#     114 This is meant as a shortcut for the following::
#    (...)
#     118
#     119 """
#     120 self.add_requirements(fgraph)
# --> 121 return self.apply(fgraph, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:292, in SequentialGraphRewriter.apply(self, fgraph)
#     290 nb_nodes_before = len(fgraph.apply_nodes)
#     291 t0 = time.perf_counter()
# --> 292 sub_prof = rewriter.apply(fgraph)
#     293 l.append(float(time.perf_counter() - t0))
#     294 sub_profs.append(sub_prof)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:2428, in EquilibriumGraphRewriter.apply(self, fgraph, start_from)
#    2426 nb = change_tracker.nb_imported
#    2427 t_rewrite = time.perf_counter()
# -> 2428 node_rewriter_change = self.process_node(
#    2429     fgraph, node, node_rewriter
#    2430 )
#    2431 time_rewriters[node_rewriter] += time.perf_counter() - t_rewrite
#    2432 if not node_rewriter_change:
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:1922, in NodeProcessingGraphRewriter.process_node(self, fgraph, node, node_rewriter)
#    1920 assert node_rewriter is not None
#    1921 try:
# -> 1922     replacements = node_rewriter.transform(fgraph, node)
#    1923 except Exception as e:
#    1924     if self.failure_callback is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:1082, in FromFunctionNodeRewriter.transform(self, fgraph, node)
#    1077     if not (
#    1078         node.op in self._tracks or isinstance(node.op, self._tracked_types)
#    1079     ):
#    1080         return False
# -> 1082 return self.fn(fgraph, node)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/rewriting/math.py:2622, in local_greedy_distributor(fgraph, node)
#    2620     continue
#    2621 num.remove(candidate)
# -> 2622 _change, candidate, num, denum = attempt_distribution(
#    2623     candidate,
#    2624     num,
#    2625     denum,
#    2626     out_type,
#    2627 )
#    2629 change |= _change
#    2630 new_num.append(candidate)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/rewriting/math.py:2555, in attempt_distribution(factor, num, denum, out_type)
#    2553 change = False
#    2554 for n in list(num):
# -> 2555     success, pos_pairs, neg_pairs = distribute_greedy(
#    2556         pos_pairs, neg_pairs, [n], [], out_type
#    2557     )
#    2558     if success:
#    2559         change = True
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/rewriting/math.py:2516, in distribute_greedy(pos_pairs, neg_pairs, num, denum, out_type, minscore)
#    2514 # score is number of operations saved, higher is better
#    2515 score = len(num) + div_cost * len(denum)
# -> 2516 new_pos_pairs = list(
#    2517     itertools.starmap(
#    2518         local_mul_canonizer.simplify,
#    2519         [(n + num, d + denum, out_type) for (n, d) in pos_pairs],
#    2520     )
#    2521 )
#    2522 new_neg_pairs = list(
#    2523     itertools.starmap(
#    2524         local_mul_canonizer.simplify,
#    2525         [(n + num, d + denum, out_type) for (n, d) in neg_pairs],
#    2526     )
#    2527 )
#    2528 for (n, d), (nn, dd) in zip(pos_pairs + neg_pairs, new_pos_pairs + new_neg_pairs):
#    2529     # We calculate how many operations we are saving with the new
#    2530     # num and denum
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/rewriting/math.py:942, in AlgebraicCanonizer.simplify(self, num, denum, out_type)
#     933 def simplify(self, num, denum, out_type):
#     934     """
#     935     Shorthand for:
#     936
#    (...)
#     940
#     941     """
# --> 942     rval = self.simplify_constants(
#     943         *self.simplify_factors(num, denum), out_type=out_type
#     944     )
#     945     for reason, simplifier in self.external_simplifiers:
#     946         # TODO: document that 'reason' is associated with this
#     947         #       simplification to help auditing when things go
#     948         #       wrong
#     949         rval = simplifier(*rval)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/rewriting/math.py:1040, in AlgebraicCanonizer.simplify_constants(self, orig_num, orig_denum, out_type)
#    1037     ct = [self.calculate(numct, denumct, aslist=False, out_type=out_type)]
#    1039 # Wrapping ct in a Constant with the right dtype
# -> 1040 ct = [constant(c, dtype=out_type.dtype) for c in ct]
#    1042 if orig_num and len(numct) == 1 and len(denumct) == 0 and ct:
#    1043     # In that case we should only have one constant in `ct`.
#    1044     assert len(ct) == 1
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/rewriting/math.py:1040, in <listcomp>(.0)
#    1037     ct = [self.calculate(numct, denumct, aslist=False, out_type=out_type)]
#    1039 # Wrapping ct in a Constant with the right dtype
# -> 1040 ct = [constant(c, dtype=out_type.dtype) for c in ct]
#    1042 if orig_num and len(numct) == 1 and len(denumct) == 0 and ct:
#    1043     # In that case we should only have one constant in `ct`.
#    1044     assert len(ct) == 1
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/basic.py:232, in constant(x, name, ndim, dtype)
#     228     assert x_.ndim == ndim
#     230 ttype = TensorType(dtype=x_.dtype, shape=x_.shape)
# --> 232 return TensorConstant(ttype, x_, name=name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/variable.py:1021, in TensorConstant.__init__(self, type, data, name)
#    1016     raise ValueError(
#    1017         f"Shape of data ({data_shape}) does not match shape of type ({type.shape})"
#    1018     )
#    1020 # We want all the shape information from `data`
# -> 1021 new_type = type.clone(shape=data_shape)
#    1023 assert not any(s is None for s in new_type.shape)
#    1025 Constant.__init__(self, new_type, data, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/type.py:139, in TensorType.clone(self, dtype, shape, broadcastable, **kwargs)
#     137 if shape is None:
#     138     shape = self.shape
# --> 139 return type(self)(dtype, shape, name=self.name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/type.py:121, in TensorType.__init__(self, dtype, shape, name, broadcastable)
#     116         return s
#     117     raise ValueError(
#     118         f"TensorType broadcastable/shape must be a boolean, integer or None, got {type(s)} {s}"
#     119     )
# --> 121 self.shape = tuple(parse_bcast_and_shape(s) for s in shape)
#     122 self.dtype_specs()  # error checking is done there
#     123 self.name = name
#
# File ~/anaconda3/lib/python3.11/site-packages/pytensor/tensor/type.py:121, in <genexpr>(.0)
#     116         return s
#     117     raise ValueError(
#     118         f"TensorType broadcastable/shape must be a boolean, integer or None, got {type(s)} {s}"
#     119     )
# --> 121 self.shape = tuple(parse_bcast_and_shape(s) for s in shape)
#     122 self.dtype_specs()  # error checking is done there
#     123 self.name = name
#
# KeyboardInterrupt:

# %% [markdown]
# # Functions

# %%
def this_Bayesian_mixture_model(ISI_data):
    import scipy.stats as st
    with pm.Model() as model:
        ##### WALD DISTRIBUTION (INVERSE GAUSSIAN)
        mu1 = pm.Uniform('mu1',lower=0.03,upper=0.1)
        lam1 = pm.Uniform('lam1',lower=0.000001,upper=0.04)
        obs1 = pm.Wald.dist(mu=mu1,lam=lam1)


        mu2 = pm.Uniform('mu2',lower=0.09,upper=0.4)
        sigma2 = pm.Uniform('sigma2',lower=0.01,upper=0.7)
        obs2 = pm.TruncatedNormal.dist(mu=mu2, sigma=sigma2, lower=0.0)
        
        w = pm.Dirichlet('w', a=np.array([1., 1.]))
        like = pm.Mixture('like', w=w, comp_dists = [obs1, obs2], observed=ISI_data)

    map_estimate = pm.find_MAP(model=model)
    d= np.linspace(0.00, 1, len(ISI_data))
    map_estimate['w1'] = map_estimate['w'][0]
    map_estimate['w2'] = map_estimate['w'][1]
    
    mu1=map_estimate['mu1']
    mu2=map_estimate['mu2']
    
    lam1=map_estimate['lam1']
    #lam1=0.008
    sigma2=map_estimate['sigma2']
    
    w1=map_estimate['w1']
    w2=map_estimate['w2']
    
    pdf = w1*st.invgauss.pdf(d, mu1/lam1, scale = lam1) + w2*st.norm.pdf(d, mu2, sigma2)
    bins = np.arange(0, 0.5, 1e-3)
    
    plt.hist(ISI_data, bins, color='orange', alpha=0.7, label='Histogram',density=True)
    plt.plot(d, pdf, color='blue', label='PDF')
    #plt.xlim(0, 0.3)
    plt.show()

    cdf_2gauss = lambda x: w1 * st.invgauss.cdf(x,mu1/lam1, scale = lam1) + w2 * st.norm.cdf(x, mu2, sigma2)
    ks_score=st.ks_1samp(ISI_data[ISI_data>0],  cdf_2gauss, method = 'asymp')
    print('ks score: ',ks_score)
    
    del map_estimate['w_simplex__']
    del map_estimate['mu1_interval__']
    del map_estimate['lam1_interval__']
    del map_estimate['mu2_interval__']
    del map_estimate['sigma2_interval__']

    
    del map_estimate['w']

    print(map_estimate)
    return map_estimate

# %%
def this_poiproc(neurons,target,stim):
    from scipy.stats import ks_2samp
    dataframe = pd.DataFrame()
    #counter_net=1
    counter=0
    #for net in list_dir_ok:
    #print(counter_net,') ',net)
    #counter_net+=1
    list_neurons = neurons #np.genfromtxt(net, delimiter=',')
    counter=0
    print('Original number of neurons: ',len(list_neurons))
    for neuron in tqdm(list_neurons):
        neuron=neuron[neuron>0*10000]
        neuron=neuron[neuron<200*10000]
        print('  Neuron with ',neuron.shape[0],'spikes')
        if neuron.shape[0]>900:
            
            counter+=1
        else:
            print('    Excluded neuron with n spikes = ',neuron.shape[0])
            continue
        
        ISI_healthy = np.diff(neuron)/10000
        map_estimate = this_Bayesian_mixture_model(ISI_healthy)
        map_estimate['Target']=target
        map_estimate['Stimulation']=stim
        df = pd.DataFrame.from_dict(map_estimate,orient='index')
        dataframe = pd.concat([dataframe,df],axis = 1)
    print('Final number of neurons: ',counter)
    print('Target = ',target)
    #ks_2samp(lista_samples,ISI_healthy,mode = 'asymp')
    return dataframe

# %% [markdown]
# def this_Bayesian_mixture_model(ISI_data):
#     import scipy.stats as st
#     with pm.Model() as model:
#         ##### WALD DISTRIBUTION (INVERSE GAUSSIAN)
#         mu1 = pm.Uniform('mu1',lower=0.03,upper=0.1)
#         lam1 = pm.Uniform('lam1',lower=0.000001,upper=0.04)
#         obs1 = pm.Wald.dist(mu=mu1,lam=lam1)
#
#
#         mu2 = pm.Uniform('mu2',lower=0.02,upper=0.04)
#         sigma2 = pm.Uniform('sigma2',lower=0.01,upper=0.7)
#         obs2 = pm.TruncatedNormal.dist(mu=mu2, sigma=sigma2, lower=0.0)
#
#         mu3 = pm.Uniform('mu3',lower=0.04,upper=0.6)
#         sigma3 = pm.Uniform('sigma3',lower=0.01,upper=0.7)
#         obs3 = pm.TruncatedNormal.dist(mu=mu3, sigma=sigma3, lower=0.0)
#
#         w = pm.Dirichlet('w', a=np.array([1., 0.3, 0.3]))
#         like = pm.Mixture('like', w=w, comp_dists = [obs1, obs2, obs3], observed=ISI_data)
#
#         '''
#         if counter==9:
#             step = pm.NUTS(target_accept=0.9)
#             trace = pm.sample(step=step,draws=1000,chains=1,tune=1000,cores=4)
#             ppc_trace = pm.sample_posterior_predictive(trace,model=model)
#             bins = np.arange(0, .5, 1e-3)
#             plt.figure (figsize=(14,10))
#             hist = np.histogram(ppc_trace['posterior_predictive']['like'].values,bins=bins)
#             #plt.axis([-0.01,0.13,0,160])
#             a= plt.hist(ISI_data,bins)
#             plt.plot(hist[1][:-1],hist[0]/1000,linewidth=3)
#             plt.show()
#         '''
#
#     map_estimate = pm.find_MAP(model=model)
#     d= np.linspace(0.00, 1, len(ISI_data))
#     map_estimate['w1'] = map_estimate['w'][0]
#     map_estimate['w2'] = map_estimate['w'][1]
#     map_estimate['w3'] = map_estimate['w'][2]
#
#     mu1=map_estimate['mu1']
#     mu2=map_estimate['mu2']
#     mu3=map_estimate['mu3']
#
#     lam1=map_estimate['lam1']
#     sigma2=map_estimate['sigma2']
#     sigma3=map_estimate['sigma3']
#
#     w1=map_estimate['w1']
#     w2=map_estimate['w2']
#     w3=map_estimate['w3']
#
#     pdf = w1*st.invgauss.pdf(d, mu1/lam1, scale = lam1) + w2*st.norm.pdf(d, mu2, sigma2) + w3*st.norm.pdf(d, mu3, sigma3)
#     bins = np.arange(0, 0.5, 1e-3)
#
#     plt.hist(ISI_data, bins, color='orange', alpha=0.7, label='Histogram',density=True)
#     plt.plot(d, pdf, color='blue', label='PDF')
#     plt.xlim(0, 0.5)
#     plt.show()
#
#     cdf_2gauss = lambda x: w1 * st.invgauss.cdf(x,mu1/lam1, scale = lam1) + w2 * st.norm.cdf(x, mu2, sigma2) + w3*st.norm.cdf(x, mu3, sigma3)
#     ks_score=st.ks_1samp(ISI_data[ISI_data>0],  cdf_2gauss, method = 'asymp')
#     print('ks score: ',ks_score)
#
#     del map_estimate['w_simplex__']
#     del map_estimate['mu1_interval__']
#     del map_estimate['lam1_interval__']
#     del map_estimate['mu2_interval__']
#     del map_estimate['sigma2_interval__']
#     del map_estimate['mu3_interval__']
#     del map_estimate['sigma3_interval__']
#
#
#     del map_estimate['w']
#
#     print(map_estimate)
#     return map_estimate

# %% [markdown]
# def this_Bayesian_mixture_model(ISI_data):
#     import scipy.stats as st
#     with pm.Model() as model:
#         ##### WALD DISTRIBUTION (INVERSE GAUSSIAN)
#         mu1 = pm.Uniform('mu1',lower=0.03,upper=0.04)
#         lam1 = pm.Uniform('lam1',lower=0.01,upper=0.4)
#         obs1 = pm.Wald.dist(mu=mu1,lam=lam1)
#
#
#         mu2 = pm.Uniform('mu2',lower=0.02,upper=0.04)
#         sigma2 = pm.Uniform('sigma2',lower=0.01,upper=0.7)
#         obs2 = pm.TruncatedNormal.dist(mu=mu2, sigma=sigma2, lower=0.0)
#
#         mu3 = pm.Uniform('mu3',lower=0.04,upper=0.6)
#         sigma3 = pm.Uniform('sigma3',lower=0.01,upper=0.7)
#         obs3 = pm.TruncatedNormal.dist(mu=mu3, sigma=sigma3, lower=0.0)
#
#         mu4 = pm.Uniform('mu4',lower=0.04,upper=0.05)
#         lam4 = pm.Uniform('lam4',lower=0.0001,upper=0.04)
#         obs4 = pm.Wald.dist(mu=mu4,lam=lam4)
#
#         w = pm.Dirichlet('w', a=np.array([0.5, 1., 1e-10, 0.5]))
#         like = pm.Mixture('like', w=w, comp_dists = [obs1, obs2, obs3, obs4], observed=ISI_data)
#
#         '''
#         if counter==9:
#             step = pm.NUTS(target_accept=0.9)
#             trace = pm.sample(step=step,draws=1000,chains=1,tune=1000,cores=4)
#             ppc_trace = pm.sample_posterior_predictive(trace,model=model)
#             bins = np.arange(0, .5, 1e-3)
#             plt.figure (figsize=(14,10))
#             hist = np.histogram(ppc_trace['posterior_predictive']['like'].values,bins=bins)
#             #plt.axis([-0.01,0.13,0,160])
#             a= plt.hist(ISI_data,bins)
#             plt.plot(hist[1][:-1],hist[0]/1000,linewidth=3)
#             plt.show()
#         '''
#
#     map_estimate = pm.find_MAP(model=model)
#     d= np.linspace(0.00, 1, len(ISI_data))
#     map_estimate['w1'] = map_estimate['w'][0]
#     map_estimate['w2'] = map_estimate['w'][1]
#     map_estimate['w3'] = map_estimate['w'][2]
#     map_estimate['w4'] = map_estimate['w'][3]
#
#     mu1=map_estimate['mu1']
#     mu2=map_estimate['mu2']
#     mu3=map_estimate['mu3']
#     mu4=map_estimate['mu4']
#
#     lam1=map_estimate['lam1']
#     sigma2=map_estimate['sigma2']
#     sigma3=map_estimate['sigma3']
#     lam4=map_estimate['lam4']
#
#     w1=map_estimate['w1']
#     w2=map_estimate['w2']
#     w3=map_estimate['w3']
#     w4=map_estimate['w4']
#
#     pdf = w1*st.invgauss.pdf(d, mu1/lam1, scale = lam1) + w2*st.norm.pdf(d, mu2, sigma2) + w3*st.norm.pdf(d, mu3, sigma3)+w4*st.invgauss.pdf(d, mu4/lam4, scale = lam4)
#     bins = np.arange(0, 0.5, 1e-3)
#
#     plt.hist(ISI_data, bins, color='orange', alpha=0.7, label='Histogram',density=True)
#     plt.plot(d, pdf, color='blue', label='PDF')
#     #plt.xlim(0, 0.5)
#     plt.show()
#
#     cdf_2gauss = lambda x: w1 * st.invgauss.cdf(x,mu1/lam1, scale = lam1) + w2 * st.norm.cdf(x, mu2, sigma2) + w3*st.norm.cdf(x, mu3, sigma3)+w4 * st.invgauss.cdf(x,mu4/lam4, scale = lam4)
#     ks_score=st.ks_1samp(ISI_data[ISI_data>0],  cdf_2gauss, method = 'asymp')
#     print('ks score: ',ks_score)
#
#     del map_estimate['w_simplex__']
#     del map_estimate['mu1_interval__']
#     del map_estimate['lam1_interval__']
#     del map_estimate['mu2_interval__']
#     del map_estimate['sigma2_interval__']
#     del map_estimate['mu3_interval__']
#     del map_estimate['sigma3_interval__']
#     del map_estimate['mu4_interval__']
#     del map_estimate['lam4_interval__']
#
#
#     del map_estimate['w']
#
#     print(map_estimate)
#     return map_estimate
