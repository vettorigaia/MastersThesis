# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,recall_score,precision_score,roc_auc_score,classification_report
import glob
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
list_dir =glob.glob("/Users/Gaia_1/Desktop/tesi/Data after PP thresh 3/*.txt")
#list_dir =glob.glob("/Users/Gaia_1/Desktop/tesi/Data after PP scores/*.txt")

# List to hold individual DataFrames
dfs = []

# Iterate through each file in the directory
for file in list_dir:
    # Read the file into a DataFrame
    #file_path = os.path.join(directory, filename)
    df = pd.read_csv(file) #, delimiter='\t')  # Assuming tab-separated values
    dfs.append(df)

# Merge all DataFrames into a single DataFrame
merged_df = pd.concat(dfs, ignore_index=True)

# Save the merged DataFrame as CSV
merged_df.to_csv("merged_data.csv", index=False)
dataset=merged_df
dataset
# Out:
#      Unnamed: 0       mu1      lam1       mu2    sigma2       mu3    sigma3  \
# 0             0  0.029989  0.023791  0.050000  0.025455  0.301780  0.317919
# 1             0  0.030000  0.023087  0.050000  0.025142  0.273312  0.328372
# 2             0  0.028645  0.024061  0.050000  0.029190  0.180386  0.221539
# 3             0  0.030000  0.024694  0.050000  0.017556  0.272991  0.290797
# 4             0  0.030000  0.024102  0.051366  0.010000  0.255269  0.292689
# ..          ...       ...       ...       ...       ...       ...       ...
# 805           0  0.030000  0.024695  0.059022  0.036943  0.100000  0.106931
# 806           0  0.030000  0.026658  0.053893  0.049967  0.100000  0.123759
# 807           0  0.029975  0.025515  0.056269  0.033665  0.102328  0.103310
# 808           0  0.030000  0.022255  0.052986  0.031594  0.100000  0.098919
# 809           0  0.030000  0.031514  0.050000  0.067299  0.100000  0.141414
#
#            w1        w2            w3  Target  Stimulation
# 0    0.814444  0.185555  4.704015e-07     0.0          1.0
# 1    0.813396  0.186604  3.058176e-12     0.0          1.0
# 2    0.804252  0.195748  2.771986e-30     0.0          1.0
# 3    0.918604  0.081396  5.773332e-11     0.0          1.0
# 4    0.917414  0.082586  2.747613e-15     0.0          1.0
# ..        ...       ...           ...     ...          ...
# 805  0.435041  0.311040  2.539190e-01     0.0          0.0
# 806  0.376015  0.450747  1.732381e-01     0.0          0.0
# 807  0.341048  0.360353  2.985997e-01     0.0          0.0
# 808  0.366657  0.305299  3.280442e-01     0.0          0.0
# 809  0.269847  0.503332  2.268207e-01     0.0          0.0
#
# [810 rows x 12 columns]

# %% [markdown]
# dataset = pd.read_csv('Data after PP/Data')

# %% [markdown]
# ### Only baseline

# %%
dataset = dataset[dataset['Stimulation'] != 1]
dataset
# Out:
#      Unnamed: 0       mu1      lam1       mu2    sigma2       mu3    sigma3  \
# 297           0  0.030000  0.050000  0.050000  0.082861  0.100000  0.278274
# 298           0  0.030000  0.050000  0.050000  0.100821  0.100000  0.315080
# 299           0  0.030000  0.050000  0.050000  0.101685  0.100000  0.315913
# 300           0  0.030000  0.030716  0.050000  0.100025  0.100000  0.324897
# 301           0  0.030000  0.050000  0.050000  0.111570  0.100000  0.315442
# ..          ...       ...       ...       ...       ...       ...       ...
# 805           0  0.030000  0.024695  0.059022  0.036943  0.100000  0.106931
# 806           0  0.030000  0.026658  0.053893  0.049967  0.100000  0.123759
# 807           0  0.029975  0.025515  0.056269  0.033665  0.102328  0.103310
# 808           0  0.030000  0.022255  0.052986  0.031594  0.100000  0.098919
# 809           0  0.030000  0.031514  0.050000  0.067299  0.100000  0.141414
#
#            w1        w2        w3  Target  Stimulation
# 297  0.106077  0.504020  0.389903     1.0          0.0
# 298  0.109265  0.573969  0.316766     1.0          0.0
# 299  0.115037  0.583479  0.301484     1.0          0.0
# 300  0.124402  0.583667  0.291931     1.0          0.0
# 301  0.116764  0.592597  0.290639     1.0          0.0
# ..        ...       ...       ...     ...          ...
# 805  0.435041  0.311040  0.253919     0.0          0.0
# 806  0.376015  0.450747  0.173238     0.0          0.0
# 807  0.341048  0.360353  0.298600     0.0          0.0
# 808  0.366657  0.305299  0.328044     0.0          0.0
# 809  0.269847  0.503332  0.226821     0.0          0.0
#
# [455 rows x 12 columns]

# %% [markdown]
# ### Dropping stimulation column

# %%
dataset=dataset.drop(['Stimulation'],axis=1)
#dataset=dataset.drop(['score'],axis=1)
dataset = dataset.drop(['Unnamed: 0'],axis=1)

# %%
dataset['Target'].value_counts()
# Out:
# 1.0    282
# 0.0    173
# Name: Target, dtype: int64

# %%
dataset['Target'].value_counts(1)
# Out:
# 1.0    0.61978
# 0.0    0.38022
# Name: Target, dtype: float64

# %%
X = dataset.drop(['Target'],axis=1)
y= dataset['Target']

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.3,
                                                    stratify=y,
                                                    random_state=42)

# %% [markdown]
# # Standardization

# %% [markdown]
# scaler = StandardScaler().fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)

# %% [markdown]
# # CV

# %%
cv = StratifiedKFold(4)

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=7,svd_solver='full')
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
print(pca.fit(X_train).explained_variance_ratio_)
#print(cum_sum((pca.fit(X_train).explained_variance_ratio_)))
# Out:
# [7.32315606e-01 1.72497277e-01 7.72941714e-02 1.41930580e-02
#  2.24268310e-03 8.27984220e-04 6.21529735e-04]

# %% [markdown]
# # Classification Tree

# %%
params = {'max_depth':np.linspace(2,10,dtype='int'),'criterion':['gini','entropy']}

clf = DecisionTreeClassifier(random_state=12)

gs = GridSearchCV(clf, params, scoring='roc_auc',cv=cv,n_jobs=-1)

gs=gs.fit(X_train,y_train)

gs_pca = GridSearchCV(clf, params, scoring='roc_auc',cv=cv,n_jobs=-1)
gs_pca = gs_pca.fit(X_train_pca,y_train)

# %% [markdown]
# ## CT metrics

# %%
print("Best parameters set found :",gs.best_params_,'\n')
print("Classification report on Test set\n")

y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred),3)
precision = round(precision_score(y_true, y_pred),3)
roc_auc = round(roc_auc_score(y_true, y_pred),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
print('ROC AUC: ',roc_auc)
print('\n\n Result with PCA\n')
print("Best parameters set found :",gs_pca.best_params_,'\n')
print("Classification report on Test set\n")

y_true, y_pred = y_test, gs_pca.predict(X_test_pca)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred),3)
precision = round(precision_score(y_true, y_pred),3)
roc_auc = round(roc_auc_score(y_true, y_pred),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
print('ROC AUC: ',roc_auc)
# Out:
# Best parameters set found : {'criterion': 'gini', 'max_depth': 2}
#
# Classification report on Test set
#
# Accuracy:  0.964
# Recall:  0.988
# Precision:  0.955
# ROC AUC:  0.956
#
#
#  Result with PCA
#
# Best parameters set found : {'criterion': 'entropy', 'max_depth': 3}
#
# Classification report on Test set
#
# Accuracy:  0.956
# Recall:  1.0
# Precision:  0.934
# ROC AUC:  0.942

# %% [markdown]
# ## CT matrix

# %%
# Assuming clf is your trained DecisionTreeClassifier
y_pred = gs.predict(X_test)  # Use gs instead of clf if you want to use the grid search optimized model

# Plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Decision Tree')
plt.show()

# %% [markdown]
# ## CT feature info

# %%
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# Assuming X_train is your feature matrix and y_train is your target
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)

# Plot feature importance
plt.figure(figsize=(5, 3))
plt.bar(X.columns, tree.feature_importances_)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importance - Decision Tree')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Random Forest

# %%
params = {'n_estimators':np.linspace(10,150,dtype='int',num=10),'max_depth':np.linspace(2,5,dtype='int'),'criterion':['gini','entropy']}

clf = RandomForestClassifier(n_jobs=-1,random_state=12)

gs = GridSearchCV(clf, params, scoring='roc_auc',cv=cv,verbose=10,n_jobs=-1)

gs=gs.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 1000 candidates, totalling 4000 fits
# [CV 3/4; 1/1000] START criterion=gini, max_depth=2, n_estimators=10.............
# [CV 3/4; 1/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 2/4; 2/1000] START criterion=gini, max_depth=2, n_estimators=25.............
# [CV 2/4; 2/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 3/4; 4/1000] START criterion=gini, max_depth=2, n_estimators=56.............
# [CV 3/4; 4/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.3s
# [CV 4/4; 4/1000] START criterion=gini, max_depth=2, n_estimators=56.............
# [CV 4/4; 4/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.998 total time=   0.3s
# [CV 3/4; 6/1000] START criterion=gini, max_depth=2, n_estimators=87.............
# [CV 3/4; 6/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.999 total time=   0.4s
# [CV 4/4; 6/1000] START criterion=gini, max_depth=2, n_estimators=87.............
# [CV 4/4; 6/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.4s
# [CV 1/4; 8/1000] START criterion=gini, max_depth=2, n_estimators=118............
# [CV 1/4; 8/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.7s
# [CV 2/4; 8/1000] START criterion=gini, max_depth=2, n_estimators=118............
# [CV 2/4; 8/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.998 total time=   0.8s
# [CV 1/4; 10/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 1/4; 10/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   1.1s
# [CV 2/4; 10/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 2/4; 10/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.998 total time=   1.1s
# [CV 3/4; 12/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 3/4; 12/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.999 total time=   0.2s
# [CV 4/4; 12/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 4/4; 12/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 3/4; 13/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 3/4; 13/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 2/4; 14/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 2/4; 14/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.4s
# [CV 2/4; 15/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 2/4; 15/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.5s
# [CV 2/4; 16/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 2/4; 16/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.7s
# [CV 2/4; 17/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 2/4; 17/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.998 total time=   0.9s
# [CV 3/4; 18/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 3/4; 18/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.999 total time=   0.6s
# [CV 2/4; 19/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 2/4; 19/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.998 total time=   1.0s
# [CV 1/4; 20/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 1/4; 20/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   1.0s
# [CV 2/4; 21/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 2/4; 21/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.998 total time=   0.1s
# [CV 4/4; 21/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 4/4; 21/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.996 total time=   0.1s
# [CV 3/4; 22/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 3/4; 22/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.999 total time=   0.2s
# [CV 2/4; 23/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 2/4; 23/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 1/4; 24/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 1/4; 24/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.997 total time=   0.5s
# [CV 2/4; 25/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 2/4; 25/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.4s
# [CV 1/4; 26/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 1/4; 26/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.997 total time=   0.5s
# [CV 2/4; 27/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 2/4; 27/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.998 total time=   0.7s
# [CV 2/4; 28/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 2/4; 28/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.998 total time=   0.7s
# [CV 2/4; 29/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 2/4; 29/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.998 total time=   0.9s
# [CV 1/4; 30/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 1/4; 30/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   1.0s
# [CV 2/4; 31/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 2/4; 31/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.998 total time=   0.1s
# [CV 4/4; 31/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 4/4; 31/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.996 total time=   0.1s
# [CV 2/4; 32/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 2/4; 32/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 2/4; 33/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 2/4; 33/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.2s
# [CV 3/4; 34/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 3/4; 34/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.4s
# [CV 3/4; 35/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 3/4; 35/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.7s
# [CV 3/4; 36/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 3/4; 36/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.999 total time=   0.8s
# [CV 3/4; 37/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 3/4; 37/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.999 total time=   0.7s
# [CV 3/4; 38/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 3/4; 38/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.999 total time=   0.6s
# [CV 2/4; 39/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 2/4; 39/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.998 total time=   0.7s
# [CV 3/4; 40/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 3/4; 40/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.999 total time=   0.7s
# [CV 1/4; 41/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 1/4; 41/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.991 total time=   0.1s
# [CV 3/4; 41/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 3/4; 41/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 3/4; 42/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 3/4; 42/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.999 total time=   0.2s
# [CV 2/4; 43/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 2/4; 43/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 4/4; 43/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 4/4; 43/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.998 total time=   0.3s
# [CV 4/4; 44/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 4/4; 44/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.998 total time=   0.4s
# [CV 4/4; 45/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 4/4; 45/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.4s
# [CV 4/4; 46/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 4/4; 46/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.5s
# [CV 4/4; 47/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 4/4; 47/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.6s
# [CV 4/4; 48/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 4/4; 48/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.6s
# [CV 4/4; 49/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 4/4; 49/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   0.8s
# [CV 4/4; 50/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 4/4; 50/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   1.1s
# [CV 1/4; 54/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 1/4; 54/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.997 total time=   0.3s
# [CV 1/4; 55/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 1/4; 55/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.6s
# [CV 1/4; 56/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 1/4; 56/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.997 total time=   0.7s
# [CV 3/4; 57/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 3/4; 57/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.999 total time=   0.6s
# [CV 2/4; 58/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 2/4; 58/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.998 total time=   0.6s
# [CV 2/4; 59/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 2/4; 59/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.998 total time=   0.7s
# [CV 1/4; 60/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 1/4; 60/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   0.8s
# [CV 1/4; 61/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 1/4; 61/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.991 total time=   0.1s
# [CV 3/4; 61/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 3/4; 61/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.999 total time=   0.2s
# [CV 3/4; 62/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 3/4; 62/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.999 total time=   0.2s
# [CV 2/4; 63/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 2/4; 63/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 1/4; 64/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 1/4; 64/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.997 total time=   0.4s
# [CV 2/4; 65/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 2/4; 65/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.3s
# [CV 1/4; 66/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 1/4; 66/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.997 total time=   0.5s
# [CV 1/4; 67/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 1/4; 67/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.6s
# [CV 1/4; 68/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 1/4; 68/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.8s
# [CV 1/4; 69/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 1/4; 69/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   1.2s
# [CV 1/4; 70/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 1/4; 70/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   1.5s
# [CV 1/4; 71/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 1/4; 71/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.991 total time=   0.1s
# [CV 2/4; 71/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 2/4; 71/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.998 total time=   0.3s
# [CV 4/4; 71/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 4/4; 71/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.996 total time=   0.3s
# [CV 4/4; 72/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 4/4; 72/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 3/4; 73/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 3/4; 73/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.4s
# [CV 3/4; 74/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 3/4; 74/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.4s
# [CV 3/4; 75/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 3/4; 75/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.6s
# [CV 4/4; 76/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 4/4; 76/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.6s
# [CV 4/4; 77/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 4/4; 77/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   1.0s
# [CV 3/4; 78/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 3/4; 78/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.999 total time=   0.6s
# [CV 3/4; 79/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 3/4; 79/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.999 total time=   0.8s
# [CV 1/4; 80/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 1/4; 80/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   0.9s
# [CV 1/4; 81/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 1/4; 81/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.991 total time=   0.1s
# [CV 1/4; 82/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 1/4; 82/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.997 total time=   0.2s
# [CV 1/4; 83/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 1/4; 83/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.997 total time=   0.2s
# [CV 1/4; 84/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 1/4; 84/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.997 total time=   0.4s
# [CV 1/4; 85/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 1/4; 85/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.3s
# [CV 2/4; 86/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 2/4; 86/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.5s
# [CV 1/4; 1/1000] START criterion=gini, max_depth=2, n_estimators=10.............
# [CV 1/4; 1/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.991 total time=   0.1s
# [CV 1/4; 2/1000] START criterion=gini, max_depth=2, n_estimators=25.............
# [CV 1/4; 2/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.997 total time=   0.2s
# [CV 1/4; 3/1000] START criterion=gini, max_depth=2, n_estimators=41.............
# [CV 1/4; 3/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.997 total time=   0.3s
# [CV 2/4; 3/1000] START criterion=gini, max_depth=2, n_estimators=41.............
# [CV 2/4; 3/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.2s
# [CV 1/4; 5/1000] START criterion=gini, max_depth=2, n_estimators=72.............
# [CV 1/4; 5/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.4s
# [CV 2/4; 5/1000] START criterion=gini, max_depth=2, n_estimators=72.............
# [CV 2/4; 5/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.4s
# [CV 3/4; 7/1000] START criterion=gini, max_depth=2, n_estimators=103............
# [CV 3/4; 7/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.999 total time=   0.7s
# [CV 4/4; 7/1000] START criterion=gini, max_depth=2, n_estimators=103............
# [CV 4/4; 7/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.8s
# [CV 1/4; 9/1000] START criterion=gini, max_depth=2, n_estimators=134............
# [CV 1/4; 9/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   1.0s
# [CV 2/4; 9/1000] START criterion=gini, max_depth=2, n_estimators=134............
# [CV 2/4; 9/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.998 total time=   1.1s
# [CV 3/4; 11/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 3/4; 11/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 4/4; 11/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 4/4; 11/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.996 total time=   0.2s
# [CV 1/4; 13/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 1/4; 13/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.997 total time=   0.3s
# [CV 2/4; 13/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 2/4; 13/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.4s
# [CV 4/4; 14/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 4/4; 14/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.998 total time=   0.3s
# [CV 3/4; 15/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 3/4; 15/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.6s
# [CV 3/4; 16/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 3/4; 16/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.999 total time=   0.7s
# [CV 4/4; 17/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 4/4; 17/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.8s
# [CV 4/4; 18/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 4/4; 18/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.9s
# [CV 4/4; 19/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 4/4; 19/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   1.0s
# [CV 4/4; 20/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 4/4; 20/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   1.4s
# [CV 2/4; 24/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 2/4; 24/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.4s
# [CV 1/4; 25/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 1/4; 25/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.4s
# [CV 2/4; 26/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 2/4; 26/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.6s
# [CV 3/4; 27/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 3/4; 27/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.999 total time=   0.7s
# [CV 3/4; 28/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 3/4; 28/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.999 total time=   0.7s
# [CV 3/4; 29/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 3/4; 29/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.999 total time=   0.9s
# [CV 3/4; 30/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 3/4; 30/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.999 total time=   0.8s
# [CV 1/4; 32/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 1/4; 32/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.997 total time=   0.1s
# [CV 1/4; 33/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 1/4; 33/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.997 total time=   0.3s
# [CV 1/4; 34/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 1/4; 34/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.997 total time=   0.4s
# [CV 1/4; 35/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 1/4; 35/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.7s
# [CV 2/4; 36/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 2/4; 36/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.7s
# [CV 2/4; 37/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 2/4; 37/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.998 total time=   0.7s
# [CV 1/4; 38/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 1/4; 38/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.7s
# [CV 1/4; 39/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 1/4; 39/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   0.6s
# [CV 1/4; 40/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 1/4; 40/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   0.8s
# [CV 2/4; 41/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 2/4; 41/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.998 total time=   0.1s
# [CV 4/4; 41/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 4/4; 41/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.996 total time=   0.1s
# [CV 2/4; 42/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 2/4; 42/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 1/4; 43/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 1/4; 43/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.997 total time=   0.3s
# [CV 1/4; 44/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 1/4; 44/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.997 total time=   0.3s
# [CV 1/4; 45/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 1/4; 45/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.4s
# [CV 1/4; 46/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 1/4; 46/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.997 total time=   0.4s
# [CV 1/4; 47/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 1/4; 47/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.6s
# [CV 1/4; 48/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 1/4; 48/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.6s
# [CV 2/4; 49/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 2/4; 49/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.998 total time=   0.7s
# [CV 1/4; 50/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 1/4; 50/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   0.9s
# [CV 1/4; 51/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 1/4; 51/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.991 total time=   0.1s
# [CV 2/4; 51/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 2/4; 51/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.998 total time=   0.1s
# [CV 4/4; 51/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 4/4; 51/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.996 total time=   0.2s
# [CV 3/4; 52/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 3/4; 52/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.999 total time=   0.2s
# [CV 3/4; 53/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 3/4; 53/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.4s
# [CV 3/4; 54/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 3/4; 54/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.4s
# [CV 4/4; 55/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 4/4; 55/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.5s
# [CV 4/4; 56/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 4/4; 56/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.6s
# [CV 2/4; 57/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 2/4; 57/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.998 total time=   0.6s
# [CV 1/4; 58/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 1/4; 58/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.6s
# [CV 1/4; 59/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 1/4; 59/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   0.7s
# [CV 2/4; 60/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 2/4; 60/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.998 total time=   0.8s
# [CV 2/4; 61/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 2/4; 61/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.998 total time=   0.1s
# [CV 4/4; 61/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 4/4; 61/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.996 total time=   0.1s
# [CV 1/4; 62/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 1/4; 62/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.997 total time=   0.3s
# [CV 1/4; 63/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 1/4; 63/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.997 total time=   0.3s
# [CV 2/4; 64/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 2/4; 64/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.4s
# [CV 1/4; 65/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 1/4; 65/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.4s
# [CV 2/4; 66/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 2/4; 66/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.5s
# [CV 2/4; 67/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 2/4; 67/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.998 total time=   0.7s
# [CV 2/4; 68/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 2/4; 68/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.998 total time=   0.9s
# [CV 2/4; 69/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 2/4; 69/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.998 total time=   1.1s
# [CV 2/4; 70/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 2/4; 70/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.998 total time=   1.7s
# [CV 3/4; 71/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 3/4; 71/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 1/4; 72/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 1/4; 72/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.997 total time=   0.3s
# [CV 1/4; 73/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 1/4; 73/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.997 total time=   0.4s
# [CV 2/4; 74/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 2/4; 74/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.5s
# [CV 2/4; 75/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 2/4; 75/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.5s
# [CV 1/4; 76/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 1/4; 76/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.997 total time=   0.7s
# [CV 3/4; 77/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 3/4; 77/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.999 total time=   0.9s
# [CV 1/4; 78/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 1/4; 78/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.7s
# [CV 2/4; 79/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 2/4; 79/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.998 total time=   0.9s
# [CV 3/4; 80/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 3/4; 80/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.999 total time=   1.0s
# [CV 3/4; 82/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 3/4; 82/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.999 total time=   0.1s
# [CV 2/4; 83/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 2/4; 83/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 2/4; 84/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 2/4; 84/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.4s
# [CV 2/4; 85/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 2/4; 85/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.4s
# [CV 3/4; 86/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 3/4; 86/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.999 total time=   0.4s
# [CV 2/4; 87/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 2/4; 87/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.998 total time=   0.5s
# [CV 1/4; 88/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 1/4; 88/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.6s
# [CV 1/4; 89/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 1/4; 89/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   0.8s
# [CV 3/4; 90/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 3/4; 90/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.999 total time=   0.9s
# [CV 4/4; 1/1000] START criterion=gini, max_depth=2, n_estimators=10.............
# [CV 4/4; 1/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.996 total time=   0.1s
# [CV 4/4; 2/1000] START criterion=gini, max_depth=2, n_estimators=25.............
# [CV 4/4; 2/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 1/4; 4/1000] START criterion=gini, max_depth=2, n_estimators=56.............
# [CV 1/4; 4/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.997 total time=   0.3s
# [CV 2/4; 4/1000] START criterion=gini, max_depth=2, n_estimators=56.............
# [CV 2/4; 4/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.3s
# [CV 1/4; 6/1000] START criterion=gini, max_depth=2, n_estimators=87.............
# [CV 1/4; 6/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.997 total time=   0.4s
# [CV 2/4; 6/1000] START criterion=gini, max_depth=2, n_estimators=87.............
# [CV 2/4; 6/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.4s
# [CV 3/4; 8/1000] START criterion=gini, max_depth=2, n_estimators=118............
# [CV 3/4; 8/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.999 total time=   0.7s
# [CV 4/4; 8/1000] START criterion=gini, max_depth=2, n_estimators=118............
# [CV 4/4; 8/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.9s
# [CV 3/4; 10/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 3/4; 10/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.999 total time=   1.3s
# [CV 4/4; 10/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 4/4; 10/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   1.3s
# [CV 1/4; 14/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 1/4; 14/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.997 total time=   0.4s
# [CV 1/4; 15/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 1/4; 15/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.5s
# [CV 1/4; 16/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 1/4; 16/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.997 total time=   0.6s
# [CV 1/4; 17/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 1/4; 17/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.8s
# [CV 1/4; 18/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 1/4; 18/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.8s
# [CV 3/4; 19/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 3/4; 19/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.999 total time=   1.0s
# [CV 3/4; 20/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 3/4; 20/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.999 total time=   0.9s
# [CV 3/4; 21/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 3/4; 21/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 1/4; 22/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 1/4; 22/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.997 total time=   0.2s
# [CV 4/4; 22/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 4/4; 22/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 3/4; 23/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 3/4; 23/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 3/4; 24/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 3/4; 24/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.4s
# [CV 3/4; 25/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 3/4; 25/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.4s
# [CV 3/4; 26/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 3/4; 26/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.999 total time=   0.5s
# [CV 1/4; 27/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 1/4; 27/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.6s
# [CV 1/4; 28/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 1/4; 28/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.7s
# [CV 1/4; 29/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 1/4; 29/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   0.9s
# [CV 2/4; 30/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 2/4; 30/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.998 total time=   0.9s
# [CV 1/4; 31/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 1/4; 31/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.991 total time=   0.1s
# [CV 3/4; 31/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 3/4; 31/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 3/4; 32/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 3/4; 32/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.999 total time=   0.2s
# [CV 4/4; 33/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 4/4; 33/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.998 total time=   0.3s
# [CV 4/4; 34/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 4/4; 34/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.998 total time=   0.5s
# [CV 4/4; 35/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 4/4; 35/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.7s
# [CV 4/4; 36/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 4/4; 36/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   1.0s
# [CV 4/4; 37/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 4/4; 37/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.6s
# [CV 4/4; 38/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 4/4; 38/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.6s
# [CV 4/4; 39/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 4/4; 39/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   0.7s
# [CV 4/4; 40/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 4/4; 40/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.997 total time=   1.0s
# [CV 3/4; 44/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 3/4; 44/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.3s
# [CV 3/4; 45/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 3/4; 45/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.4s
# [CV 3/4; 46/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 3/4; 46/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.999 total time=   0.4s
# [CV 3/4; 47/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 3/4; 47/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.999 total time=   0.5s
# [CV 3/4; 48/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 3/4; 48/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.999 total time=   0.7s
# [CV 3/4; 49/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 3/4; 49/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.999 total time=   0.7s
# [CV 3/4; 50/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 3/4; 50/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.999 total time=   0.9s
# [CV 2/4; 52/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 2/4; 52/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.1s
# [CV 1/4; 53/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 1/4; 53/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.997 total time=   0.3s
# [CV 4/4; 53/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 4/4; 53/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.998 total time=   0.3s
# [CV 4/4; 54/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 4/4; 54/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.998 total time=   0.3s
# [CV 2/4; 55/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 2/4; 55/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.4s
# [CV 2/4; 56/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 2/4; 56/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.6s
# [CV 1/4; 57/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 1/4; 57/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.6s
# [CV 3/4; 58/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 3/4; 58/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.999 total time=   0.7s
# [CV 3/4; 59/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 3/4; 59/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.999 total time=   0.7s
# [CV 3/4; 60/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 3/4; 60/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.999 total time=   1.0s
# [CV 2/4; 62/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 2/4; 62/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.1s
# [CV 4/4; 62/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 4/4; 62/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 3/4; 63/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 3/4; 63/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 3/4; 64/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 3/4; 64/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.3s
# [CV 3/4; 65/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 3/4; 65/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.4s
# [CV 3/4; 66/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 3/4; 66/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.999 total time=   0.5s
# [CV 3/4; 67/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 3/4; 67/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.999 total time=   0.7s
# [CV 3/4; 68/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 3/4; 68/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.999 total time=   1.1s
# [CV 3/4; 69/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 3/4; 69/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.999 total time=   1.1s
# [CV 3/4; 70/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 3/4; 70/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.999 total time=   1.6s
# [CV 2/4; 72/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 2/4; 72/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 3/4; 72/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 3/4; 72/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.999 total time=   0.2s
# [CV 4/4; 73/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 4/4; 73/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.998 total time=   0.4s
# [CV 4/4; 74/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 4/4; 74/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.998 total time=   0.4s
# [CV 4/4; 75/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 4/4; 75/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.997 total time=   0.4s
# [CV 2/4; 76/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 2/4; 76/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.998 total time=   0.6s
# [CV 2/4; 77/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 2/4; 77/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.998 total time=   1.1s
# [CV 4/4; 78/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 4/4; 78/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.997 total time=   0.7s
# [CV 4/4; 79/1000] START criterion=gini, max_depth=2, n_estimators=134...........
# [CV 4/4; 79/1000] END criterion=gini, max_depth=2, n_estimators=134;, score=0.997 total time=   0.8s
# [CV 2/4; 80/1000] START criterion=gini, max_depth=2, n_estimators=150...........
# [CV 2/4; 80/1000] END criterion=gini, max_depth=2, n_estimators=150;, score=0.998 total time=   0.9s
# [CV 3/4; 81/1000] START criterion=gini, max_depth=2, n_estimators=10............
# [CV 3/4; 81/1000] END criterion=gini, max_depth=2, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 2/4; 82/1000] START criterion=gini, max_depth=2, n_estimators=25............
# [CV 2/4; 82/1000] END criterion=gini, max_depth=2, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 3/4; 83/1000] START criterion=gini, max_depth=2, n_estimators=41............
# [CV 3/4; 83/1000] END criterion=gini, max_depth=2, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 3/4; 84/1000] START criterion=gini, max_depth=2, n_estimators=56............
# [CV 3/4; 84/1000] END criterion=gini, max_depth=2, n_estimators=56;, score=0.999 total time=   0.3s
# [CV 3/4; 85/1000] START criterion=gini, max_depth=2, n_estimators=72............
# [CV 3/4; 85/1000] END criterion=gini, max_depth=2, n_estimators=72;, score=0.999 total time=   0.3s
# [CV 1/4; 86/1000] START criterion=gini, max_depth=2, n_estimators=87............
# [CV 1/4; 86/1000] END criterion=gini, max_depth=2, n_estimators=87;, score=0.997 total time=   0.4s
# [CV 1/4; 87/1000] START criterion=gini, max_depth=2, n_estimators=103...........
# [CV 1/4; 87/1000] END criterion=gini, max_depth=2, n_estimators=103;, score=0.997 total time=   0.5s
# [CV 2/4; 88/1000] START criterion=gini, max_depth=2, n_estimators=118...........
# [CV 2/4; 88/1000] END criterion=gini, max_depth=2, n_estimators=118;, score=0.998 total time=   0.6s
# ...
# [CV 1/4; 871/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 1/4; 871/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.992 total time=   0.1s
# [CV 3/4; 871/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 3/4; 871/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 1/4; 872/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 1/4; 872/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 1/4; 873/1000] START criterion=entropy, max_depth=4, n_estimators=41........
# [CV 1/4; 873/1000] END criterion=entropy, max_depth=4, n_estimators=41;, score=0.998 total time=   0.3s
# [CV 1/4; 874/1000] START criterion=entropy, max_depth=4, n_estimators=56........
# [CV 1/4; 874/1000] END criterion=entropy, max_depth=4, n_estimators=56;, score=0.998 total time=   0.4s
# [CV 4/4; 875/1000] START criterion=entropy, max_depth=4, n_estimators=72........
# [CV 4/4; 875/1000] END criterion=entropy, max_depth=4, n_estimators=72;, score=0.998 total time=   0.4s
# [CV 2/4; 876/1000] START criterion=entropy, max_depth=4, n_estimators=87........
# [CV 2/4; 876/1000] END criterion=entropy, max_depth=4, n_estimators=87;, score=0.999 total time=   0.5s
# [CV 1/4; 877/1000] START criterion=entropy, max_depth=4, n_estimators=103.......
# [CV 1/4; 877/1000] END criterion=entropy, max_depth=4, n_estimators=103;, score=0.998 total time=   0.7s
# [CV 1/4; 878/1000] START criterion=entropy, max_depth=4, n_estimators=118.......
# [CV 1/4; 878/1000] END criterion=entropy, max_depth=4, n_estimators=118;, score=0.998 total time=   0.8s
# [CV 3/4; 879/1000] START criterion=entropy, max_depth=4, n_estimators=134.......
# [CV 3/4; 879/1000] END criterion=entropy, max_depth=4, n_estimators=134;, score=1.000 total time=   0.8s
# [CV 4/4; 880/1000] START criterion=entropy, max_depth=4, n_estimators=150.......
# [CV 4/4; 880/1000] END criterion=entropy, max_depth=4, n_estimators=150;, score=0.998 total time=   0.8s
# [CV 1/4; 881/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 1/4; 881/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.992 total time=   0.1s
# [CV 2/4; 881/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 2/4; 881/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 1/4; 882/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 1/4; 882/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.998 total time=   0.3s
# [CV 4/4; 883/1000] START criterion=entropy, max_depth=4, n_estimators=41........
# [CV 4/4; 883/1000] END criterion=entropy, max_depth=4, n_estimators=41;, score=0.998 total time=   0.5s
# [CV 4/4; 884/1000] START criterion=entropy, max_depth=4, n_estimators=56........
# [CV 4/4; 884/1000] END criterion=entropy, max_depth=4, n_estimators=56;, score=0.998 total time=   0.4s
# [CV 4/4; 885/1000] START criterion=entropy, max_depth=4, n_estimators=72........
# [CV 4/4; 885/1000] END criterion=entropy, max_depth=4, n_estimators=72;, score=0.998 total time=   0.5s
# [CV 4/4; 886/1000] START criterion=entropy, max_depth=4, n_estimators=87........
# [CV 4/4; 886/1000] END criterion=entropy, max_depth=4, n_estimators=87;, score=0.998 total time=   0.6s
# [CV 4/4; 887/1000] START criterion=entropy, max_depth=4, n_estimators=103.......
# [CV 4/4; 887/1000] END criterion=entropy, max_depth=4, n_estimators=103;, score=0.998 total time=   0.8s
# [CV 4/4; 888/1000] START criterion=entropy, max_depth=4, n_estimators=118.......
# [CV 4/4; 888/1000] END criterion=entropy, max_depth=4, n_estimators=118;, score=0.998 total time=   0.8s
# [CV 4/4; 889/1000] START criterion=entropy, max_depth=4, n_estimators=134.......
# [CV 4/4; 889/1000] END criterion=entropy, max_depth=4, n_estimators=134;, score=0.998 total time=   0.8s
# [CV 4/4; 890/1000] START criterion=entropy, max_depth=4, n_estimators=150.......
# [CV 4/4; 890/1000] END criterion=entropy, max_depth=4, n_estimators=150;, score=0.998 total time=   1.1s
# [CV 3/4; 894/1000] START criterion=entropy, max_depth=4, n_estimators=56........
# [CV 3/4; 894/1000] END criterion=entropy, max_depth=4, n_estimators=56;, score=0.999 total time=   0.5s
# [CV 3/4; 895/1000] START criterion=entropy, max_depth=4, n_estimators=72........
# [CV 3/4; 895/1000] END criterion=entropy, max_depth=4, n_estimators=72;, score=1.000 total time=   0.4s
# [CV 3/4; 896/1000] START criterion=entropy, max_depth=4, n_estimators=87........
# [CV 3/4; 896/1000] END criterion=entropy, max_depth=4, n_estimators=87;, score=1.000 total time=   0.5s
# [CV 3/4; 897/1000] START criterion=entropy, max_depth=4, n_estimators=103.......
# [CV 3/4; 897/1000] END criterion=entropy, max_depth=4, n_estimators=103;, score=1.000 total time=   0.6s
# [CV 3/4; 898/1000] START criterion=entropy, max_depth=4, n_estimators=118.......
# [CV 3/4; 898/1000] END criterion=entropy, max_depth=4, n_estimators=118;, score=1.000 total time=   0.7s
# [CV 3/4; 899/1000] START criterion=entropy, max_depth=4, n_estimators=134.......
# [CV 3/4; 899/1000] END criterion=entropy, max_depth=4, n_estimators=134;, score=1.000 total time=   0.8s
# [CV 3/4; 900/1000] START criterion=entropy, max_depth=4, n_estimators=150.......
# [CV 3/4; 900/1000] END criterion=entropy, max_depth=4, n_estimators=150;, score=1.000 total time=   0.9s
# [CV 1/4; 902/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 1/4; 902/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 1/4; 903/1000] START criterion=entropy, max_depth=4, n_estimators=41........
# [CV 1/4; 903/1000] END criterion=entropy, max_depth=4, n_estimators=41;, score=0.998 total time=   0.2s
# [CV 1/4; 904/1000] START criterion=entropy, max_depth=4, n_estimators=56........
# [CV 1/4; 904/1000] END criterion=entropy, max_depth=4, n_estimators=56;, score=0.998 total time=   0.3s
# [CV 1/4; 905/1000] START criterion=entropy, max_depth=4, n_estimators=72........
# [CV 1/4; 905/1000] END criterion=entropy, max_depth=4, n_estimators=72;, score=0.998 total time=   0.5s
# [CV 1/4; 906/1000] START criterion=entropy, max_depth=4, n_estimators=87........
# [CV 1/4; 906/1000] END criterion=entropy, max_depth=4, n_estimators=87;, score=0.998 total time=   0.5s
# [CV 2/4; 907/1000] START criterion=entropy, max_depth=4, n_estimators=103.......
# [CV 2/4; 907/1000] END criterion=entropy, max_depth=4, n_estimators=103;, score=0.999 total time=   0.6s
# [CV 2/4; 908/1000] START criterion=entropy, max_depth=4, n_estimators=118.......
# [CV 2/4; 908/1000] END criterion=entropy, max_depth=4, n_estimators=118;, score=0.999 total time=   0.7s
# [CV 2/4; 909/1000] START criterion=entropy, max_depth=4, n_estimators=134.......
# [CV 2/4; 909/1000] END criterion=entropy, max_depth=4, n_estimators=134;, score=0.999 total time=   0.7s
# [CV 2/4; 910/1000] START criterion=entropy, max_depth=4, n_estimators=150.......
# [CV 2/4; 910/1000] END criterion=entropy, max_depth=4, n_estimators=150;, score=0.999 total time=   0.7s
# [CV 1/4; 911/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 1/4; 911/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.992 total time=   0.1s
# [CV 3/4; 911/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 3/4; 911/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 2/4; 912/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 2/4; 912/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.998 total time=   0.1s
# [CV 3/4; 912/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 3/4; 912/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.999 total time=   0.2s
# [CV 2/4; 913/1000] START criterion=entropy, max_depth=4, n_estimators=41........
# [CV 2/4; 913/1000] END criterion=entropy, max_depth=4, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 1/4; 914/1000] START criterion=entropy, max_depth=4, n_estimators=56........
# [CV 1/4; 914/1000] END criterion=entropy, max_depth=4, n_estimators=56;, score=0.998 total time=   0.3s
# [CV 1/4; 915/1000] START criterion=entropy, max_depth=4, n_estimators=72........
# [CV 1/4; 915/1000] END criterion=entropy, max_depth=4, n_estimators=72;, score=0.998 total time=   0.4s
# [CV 1/4; 916/1000] START criterion=entropy, max_depth=4, n_estimators=87........
# [CV 1/4; 916/1000] END criterion=entropy, max_depth=4, n_estimators=87;, score=0.998 total time=   0.5s
# [CV 1/4; 917/1000] START criterion=entropy, max_depth=4, n_estimators=103.......
# [CV 1/4; 917/1000] END criterion=entropy, max_depth=4, n_estimators=103;, score=0.998 total time=   0.6s
# [CV 1/4; 918/1000] START criterion=entropy, max_depth=4, n_estimators=118.......
# [CV 1/4; 918/1000] END criterion=entropy, max_depth=4, n_estimators=118;, score=0.998 total time=   0.7s
# [CV 2/4; 919/1000] START criterion=entropy, max_depth=4, n_estimators=134.......
# [CV 2/4; 919/1000] END criterion=entropy, max_depth=4, n_estimators=134;, score=0.999 total time=   0.8s
# [CV 2/4; 920/1000] START criterion=entropy, max_depth=4, n_estimators=150.......
# [CV 2/4; 920/1000] END criterion=entropy, max_depth=4, n_estimators=150;, score=0.999 total time=   0.9s
# [CV 2/4; 921/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 2/4; 921/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 4/4; 921/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 4/4; 921/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.998 total time=   0.1s
# [CV 2/4; 922/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 2/4; 922/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 2/4; 923/1000] START criterion=entropy, max_depth=4, n_estimators=41........
# [CV 2/4; 923/1000] END criterion=entropy, max_depth=4, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 2/4; 924/1000] START criterion=entropy, max_depth=4, n_estimators=56........
# [CV 2/4; 924/1000] END criterion=entropy, max_depth=4, n_estimators=56;, score=0.999 total time=   0.3s
# [CV 2/4; 925/1000] START criterion=entropy, max_depth=4, n_estimators=72........
# [CV 2/4; 925/1000] END criterion=entropy, max_depth=4, n_estimators=72;, score=0.999 total time=   0.4s
# [CV 1/4; 926/1000] START criterion=entropy, max_depth=4, n_estimators=87........
# [CV 1/4; 926/1000] END criterion=entropy, max_depth=4, n_estimators=87;, score=0.998 total time=   0.4s
# [CV 1/4; 927/1000] START criterion=entropy, max_depth=4, n_estimators=103.......
# [CV 1/4; 927/1000] END criterion=entropy, max_depth=4, n_estimators=103;, score=0.998 total time=   0.6s
# [CV 1/4; 928/1000] START criterion=entropy, max_depth=4, n_estimators=118.......
# [CV 1/4; 928/1000] END criterion=entropy, max_depth=4, n_estimators=118;, score=0.998 total time=   0.7s
# [CV 3/4; 929/1000] START criterion=entropy, max_depth=4, n_estimators=134.......
# [CV 3/4; 929/1000] END criterion=entropy, max_depth=4, n_estimators=134;, score=1.000 total time=   0.8s
# [CV 3/4; 930/1000] START criterion=entropy, max_depth=4, n_estimators=150.......
# [CV 3/4; 930/1000] END criterion=entropy, max_depth=4, n_estimators=150;, score=1.000 total time=   0.8s
# [CV 2/4; 931/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 2/4; 931/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 1/4; 932/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 1/4; 932/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.998 total time=   0.2s
# [CV 4/4; 932/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 4/4; 932/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.998 total time=   0.1s
# [CV 3/4; 933/1000] START criterion=entropy, max_depth=4, n_estimators=41........
# [CV 3/4; 933/1000] END criterion=entropy, max_depth=4, n_estimators=41;, score=0.999 total time=   0.3s
# [CV 2/4; 934/1000] START criterion=entropy, max_depth=4, n_estimators=56........
# [CV 2/4; 934/1000] END criterion=entropy, max_depth=4, n_estimators=56;, score=0.999 total time=   0.3s
# [CV 2/4; 935/1000] START criterion=entropy, max_depth=4, n_estimators=72........
# [CV 2/4; 935/1000] END criterion=entropy, max_depth=4, n_estimators=72;, score=0.999 total time=   0.5s
# [CV 2/4; 936/1000] START criterion=entropy, max_depth=4, n_estimators=87........
# [CV 2/4; 936/1000] END criterion=entropy, max_depth=4, n_estimators=87;, score=0.999 total time=   0.5s
# [CV 1/4; 937/1000] START criterion=entropy, max_depth=4, n_estimators=103.......
# [CV 1/4; 937/1000] END criterion=entropy, max_depth=4, n_estimators=103;, score=0.998 total time=   0.7s
# [CV 2/4; 938/1000] START criterion=entropy, max_depth=4, n_estimators=118.......
# [CV 2/4; 938/1000] END criterion=entropy, max_depth=4, n_estimators=118;, score=0.999 total time=   0.6s
# [CV 1/4; 939/1000] START criterion=entropy, max_depth=4, n_estimators=134.......
# [CV 1/4; 939/1000] END criterion=entropy, max_depth=4, n_estimators=134;, score=0.998 total time=   0.8s
# [CV 2/4; 940/1000] START criterion=entropy, max_depth=4, n_estimators=150.......
# [CV 2/4; 940/1000] END criterion=entropy, max_depth=4, n_estimators=150;, score=0.999 total time=   0.9s
# [CV 1/4; 941/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 1/4; 941/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.992 total time=   0.1s
# [CV 3/4; 941/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 3/4; 941/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 3/4; 942/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 3/4; 942/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.999 total time=   0.2s
# [CV 4/4; 943/1000] START criterion=entropy, max_depth=4, n_estimators=41........
# [CV 4/4; 943/1000] END criterion=entropy, max_depth=4, n_estimators=41;, score=0.998 total time=   0.2s
# [CV 2/4; 944/1000] START criterion=entropy, max_depth=4, n_estimators=56........
# [CV 2/4; 944/1000] END criterion=entropy, max_depth=4, n_estimators=56;, score=0.999 total time=   0.3s
# [CV 2/4; 945/1000] START criterion=entropy, max_depth=4, n_estimators=72........
# [CV 2/4; 945/1000] END criterion=entropy, max_depth=4, n_estimators=72;, score=0.999 total time=   0.5s
# [CV 2/4; 946/1000] START criterion=entropy, max_depth=4, n_estimators=87........
# [CV 2/4; 946/1000] END criterion=entropy, max_depth=4, n_estimators=87;, score=0.999 total time=   0.5s
# [CV 2/4; 947/1000] START criterion=entropy, max_depth=4, n_estimators=103.......
# [CV 2/4; 947/1000] END criterion=entropy, max_depth=4, n_estimators=103;, score=0.999 total time=   0.5s
# [CV 1/4; 948/1000] START criterion=entropy, max_depth=4, n_estimators=118.......
# [CV 1/4; 948/1000] END criterion=entropy, max_depth=4, n_estimators=118;, score=0.998 total time=   0.6s
# [CV 2/4; 949/1000] START criterion=entropy, max_depth=4, n_estimators=134.......
# [CV 2/4; 949/1000] END criterion=entropy, max_depth=4, n_estimators=134;, score=0.999 total time=   0.7s
# [CV 1/4; 950/1000] START criterion=entropy, max_depth=4, n_estimators=150.......
# [CV 1/4; 950/1000] END criterion=entropy, max_depth=4, n_estimators=150;, score=0.998 total time=   0.8s
# [CV 1/4; 951/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 1/4; 951/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.992 total time=   0.1s
# [CV 3/4; 951/1000] START criterion=entropy, max_depth=4, n_estimators=10........
# [CV 3/4; 951/1000] END criterion=entropy, max_depth=4, n_estimators=10;, score=0.999 total time=   0.1s
# [CV 2/4; 952/1000] START criterion=entropy, max_depth=4, n_estimators=25........
# [CV 2/4; 952/1000] END criterion=entropy, max_depth=4, n_estimators=25;, score=0.998 total time=   0.2s

# %% [markdown]
# ## RF metrics

# %%
print("Best parameters set found :",gs.best_params_,'\n')
print("Classification report on Test set\n")

y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred),3)
precision = round(precision_score(y_true, y_pred),3)
roc_auc = round(roc_auc_score(y_true, y_pred),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
print('ROC AUC: ',roc_auc)
# Out:
# Best parameters set found : {'criterion': 'entropy', 'max_depth': 5, 'n_estimators': 25}
#
# Classification report on Test set
#
# Accuracy:  0.98
# Recall:  0.97
# Precision:  0.99
# ROC AUC:  0.98

# %% [markdown]
# ## RF matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt  # Importing plt module

# Assuming clf is your trained RandomForestClassifier
y_pred = gs.predict(X_test)  # Use gs instead of clf if you want to use the grid search optimized model

# Plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Random Forest')
plt.show()

# %% [markdown]
# ## RF feature info

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# Assuming X_train is your feature matrix and y_train is your target
forest = RandomForestClassifier()
forest.fit(X_train, y_train)

feature_importances = forest.feature_importances_
feature_names = X.columns  # Assuming X is your DataFrame without the target column

plt.figure(figsize=(5, 3))
plt.bar(feature_names, feature_importances)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importance in Random Forest')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
params = {'C': np.logspace(-3, 3, 50), 'penalty': ['l1', 'l2']}

clf = LogisticRegression(solver='liblinear',random_state=12)

gs = GridSearchCV(clf, params, scoring='roc_auc',cv=cv,n_jobs=-1)

gs=gs.fit(X_train,y_train)

# %% [markdown]
# ## LR metrics

# %%
print("Best parameters set found :",gs.best_params_,'\n')
print("Classification report on Test set\n")

y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred),3)
precision = round(precision_score(y_true, y_pred),3)
roc_auc = round(roc_auc_score(y_true, y_pred),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
print('ROC AUC: ',roc_auc)
class_report = classification_report(y_test, y_pred)
print('Classification Report:\n', class_report)
# Out:
# Best parameters set found : {'C': 138.9495494373136, 'penalty': 'l2'}
#
# Classification report on Test set
#
# Accuracy:  0.985
# Recall:  1.0
# Precision:  0.977
# ROC AUC:  0.981
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.96      0.98        52
#          1.0       0.98      1.00      0.99        85
#
#     accuracy                           0.99       137
#    macro avg       0.99      0.98      0.98       137
# weighted avg       0.99      0.99      0.99       137

# %%
from sklearn.metrics import f1_score, confusion_matrix, roc_curve, precision_recall_curve, log_loss, matthews_corrcoef, fbeta_score

# Compute additional metrics
f1 = round(f1_score(y_true, y_pred), 3)
conf_matrix = confusion_matrix(y_true, y_pred)
fpr, tpr, _ = roc_curve(y_true, y_pred)
precision, recall, _ = precision_recall_curve(y_true, y_pred)
logloss = round(log_loss(y_true, y_pred), 3)
mcc = round(matthews_corrcoef(y_true, y_pred), 3)
f_beta = round(fbeta_score(y_true, y_pred, beta=1), 3)

# Print additional metrics
print('F1 Score:', f1)
print('Confusion Matrix:\n', conf_matrix)
print('ROC Curve - FPR:', fpr)
print('ROC Curve - TPR:', tpr)
print('Precision-Recall Curve - Precision:', precision)
print('Precision-Recall Curve - Recall:', recall)
print('Log Loss:', logloss)
print('Matthews Correlation Coefficient:', mcc)
print('F-beta Score:', f_beta)
# Out:
# F1 Score: 0.988
# Confusion Matrix:
#  [[50  2]
#  [ 0 85]]
# ROC Curve - FPR: [0.         0.03846154 1.        ]
# ROC Curve - TPR: [0. 1. 1.]
# Precision-Recall Curve - Precision: [0.62043796 0.97701149 1.        ]
# Precision-Recall Curve - Recall: [1. 1. 0.]
# Log Loss: 0.526
# Matthews Correlation Coefficient: 0.969
# F-beta Score: 0.988

# %%
import matplotlib.pyplot as plt

# Plot ROC curve
plt.figure(figsize=(5,3))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## LR matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt  # Importing plt module

# Assuming log_reg is your trained Logistic Regression model
y_pred = gs.predict(X_test)  # Use gs instead of log_reg if you want to use the grid search optimized model

# Plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Logistic Regression')
plt.show()

# %% [markdown]
# ## LR feature info

# %%
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# Assuming log_reg is your trained Logistic Regression model
coefficients = gs.best_estimator_.coef_[0]  # Use gs.best_estimator_ to get the best model from grid search
feature_names = X.columns  # Assuming X is your DataFrame without the target column

plt.figure(figsize=(8, 6))
plt.bar(feature_names, coefficients)
plt.xlabel('Feature')
plt.ylabel('Coefficient')
plt.title('Feature Coefficients in Logistic Regression')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 4-Class

# %%
list_dir =glob.glob("/Users/Gaia_1/Desktop/tesi/Data after PP thresh 3/*.txt")

# List to hold individual DataFrames
dfs = []

# Iterate through each file in the directory
for file in list_dir:
    # Read the file into a DataFrame
    #file_path = os.path.join(directory, filename)
    df = pd.read_csv(file) #, delimiter='\t')  # Assuming tab-separated values
    dfs.append(df)

# Merge all DataFrames into a single DataFrame
merged_df = pd.concat(dfs, ignore_index=True)

# Save the merged DataFrame as CSV
merged_df.to_csv("merged_data.csv", index=False)
dataset_after=merged_df

dataset_after = dataset_after.drop(['Unnamed: 0'],axis=1)
dataset_after
# Out:
#           mu1      lam1       mu2    sigma2       mu3    sigma3        w1  \
# 0    0.029989  0.023791  0.050000  0.025455  0.301780  0.317919  0.814444
# 1    0.030000  0.023087  0.050000  0.025142  0.273312  0.328372  0.813396
# 2    0.028645  0.024061  0.050000  0.029190  0.180386  0.221539  0.804252
# 3    0.030000  0.024694  0.050000  0.017556  0.272991  0.290797  0.918604
# 4    0.030000  0.024102  0.051366  0.010000  0.255269  0.292689  0.917414
# ..        ...       ...       ...       ...       ...       ...       ...
# 805  0.030000  0.024695  0.059022  0.036943  0.100000  0.106931  0.435041
# 806  0.030000  0.026658  0.053893  0.049967  0.100000  0.123759  0.376015
# 807  0.029975  0.025515  0.056269  0.033665  0.102328  0.103310  0.341048
# 808  0.030000  0.022255  0.052986  0.031594  0.100000  0.098919  0.366657
# 809  0.030000  0.031514  0.050000  0.067299  0.100000  0.141414  0.269847
#
#            w2            w3  Target  Stimulation
# 0    0.185555  4.704015e-07     0.0          1.0
# 1    0.186604  3.058176e-12     0.0          1.0
# 2    0.195748  2.771986e-30     0.0          1.0
# 3    0.081396  5.773332e-11     0.0          1.0
# 4    0.082586  2.747613e-15     0.0          1.0
# ..        ...           ...     ...          ...
# 805  0.311040  2.539190e-01     0.0          0.0
# 806  0.450747  1.732381e-01     0.0          0.0
# 807  0.360353  2.985997e-01     0.0          0.0
# 808  0.305299  3.280442e-01     0.0          0.0
# 809  0.503332  2.268207e-01     0.0          0.0
#
# [810 rows x 11 columns]

# %%
print('Target LRRK2 vs Healthy\n',dataset_after['Target'].value_counts())
print('Stimulated LRRK2 vs Healthy\n',dataset_after['Stimulation'].value_counts())
# Out:
# Target LRRK2 vs Healthy
#  0.0    405
# 1.0    405
# Name: Target, dtype: int64
# Stimulated LRRK2 vs Healthy
#  0.0    455
# 1.0    355
# Name: Stimulation, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Load the dataset
#dataset = pd.read_csv("dataset_after.csv")
dataset=dataset_after
# Combine "target" and "stimulation" columns to create a new categorical variable
#dataset['class'] = dataset['Target'].astype(int) + dataset['Stimulation'].astype(int)
dataset['class'] = np.where((dataset['Target'] == 0) & (dataset['Stimulation'] == 0), 0,
                   np.where((dataset['Target'] == 0) & (dataset['Stimulation'] == 1), 1,
                   np.where((dataset['Target'] == 1) & (dataset['Stimulation'] == 0), 2, 3)))


# Split the dataset into features (X) and target variable (y)
X = dataset.drop(["Stimulation", "Target", "class"], axis=1)
y = dataset["class"]

# Split the data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=85)
# Out:
# 85

# %%
dataset_after['class'].value_counts()
# Out:
# 2    282
# 1    232
# 0    173
# 3    123
# Name: class, dtype: int64

# %%
dataset_after['class'].value_counts(1)
# Out:
# 2    0.348148
# 1    0.286420
# 0    0.213580
# 3    0.151852
# Name: class, dtype: float64

# %% [markdown]
# # Classification Tree

# %%
print("Classification report on Test set\n")
gs = DecisionTreeClassifier(max_depth=7,random_state=85)
gs.fit(X_train,y_train)
y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred,average = 'weighted'),3)
precision = round(precision_score(y_true, y_pred,average = 'weighted'),3)
#roc_auc = round(roc_auc_score(y_true, y_pred,multi_class = 'ovr'),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
# Out:
# Classification report on Test set
#
# Accuracy:  0.753
# Recall:  0.753
# Precision:  0.75

# %%
class_report = classification_report(y_test, y_pred)
print('Classification Report:\n', class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.76      0.72        38
#            1       0.81      0.76      0.79        51
#            2       0.80      0.86      0.83        50
#            3       0.61      0.48      0.54        23
#
#     accuracy                           0.75       162
#    macro avg       0.73      0.72      0.72       162
# weighted avg       0.75      0.75      0.75       162

# %%
class_report = classification_report(y_test, y_pred)
print('Classification Report:\n', class_report)
#print('ROC AUC: ',roc_auc)
from sklearn import metrics
cm=metrics.confusion_matrix(y_true,y_pred,labels=[0,1,2,3])
df_cm = pd.DataFrame(cm,columns=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'],index=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'])
plt.figure(figsize = (8,6))
sns.set(font_scale=1.) # for label size
chart = sns.heatmap(df_cm,annot=True,cmap="Blues")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_yticklabels(chart.get_yticklabels(), rotation=45)
plt.xlabel('Predicted',fontdict={'size':20})
plt.ylabel('True',fontdict={'size':20})
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.76      0.72        38
#            1       0.81      0.76      0.79        51
#            2       0.80      0.86      0.83        50
#            3       0.61      0.48      0.54        23
#
#     accuracy                           0.75       162
#    macro avg       0.73      0.72      0.72       162
# weighted avg       0.75      0.75      0.75       162
# Text(67.24999999999999, 0.5, 'True')

# %%
import matplotlib.pyplot as plt

# Plot ROC curve
plt.figure(figsize=(20,10))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

# %%
plt.figure(figsize=(15, 8))
importances = gs.feature_importances_
indices = np.argsort(importances)[::-1]
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), importances[indices], align="center")
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation=90)  # Set feature names as x-labels
plt.xlabel('Feature')
plt.ylabel('Feature Importance')
plt.savefig('4class_feat_import_decision_tree.jpg')
plt.show()

# %% [markdown]
# # Logistic Regression

# %%
print("Classification report on Test set\n")
gs = LogisticRegression(penalty='l2',C=0.5)#,random_state=12)
gs.fit(X_train,y_train)
y_true, y_pred = y_test, gs.predict(X_test)
# Out:
# Classification report on Test set

# %%
class_report = classification_report(y_test, y_pred)
print('Classification Report:\n', class_report)
#print('ROC AUC: ',roc_auc)
from sklearn import metrics
cm=metrics.confusion_matrix(y_true,y_pred,labels=[0,1,2,3])
df_cm = pd.DataFrame(cm,columns=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'],index=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'])
plt.figure(figsize = (8,6))
sns.set(font_scale=1.) # for label size
chart = sns.heatmap(df_cm,annot=True,cmap="Blues")
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_yticklabels(chart.get_yticklabels(), rotation=45)
plt.xlabel('Predicted',fontdict={'size':20})
plt.ylabel('True',fontdict={'size':20})
# Out:
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.61      0.65        38
#            1       0.79      0.82      0.81        51
#            2       0.66      1.00      0.79        50
#            3       0.00      0.00      0.00        23
#
#     accuracy                           0.71       162
#    macro avg       0.54      0.61      0.56       162
# weighted avg       0.62      0.71      0.65       162
# Text(67.24999999999999, 0.5, 'True')

# %%
accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred,average = 'weighted'),3)
precision = round(precision_score(y_true, y_pred,average = 'weighted'),3)
#roc_auc = round(roc_auc_score(y_true, y_pred,multi_class = 'ovr'),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
#print('ROC AUC: ',roc_auc)
# Out:
# Accuracy:  0.698
# Recall:  0.698
# Precision:  0.597
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm=metrics.confusion_matrix(y_true,y_pred)
df_cm = pd.DataFrame(cm)
plt.figure(figsize = (5,3))
sns.set(font_scale=0.8) # for label size
sns.heatmap(df_cm,annot=True,cmap="Blues")
# Out:
# <Axes: >

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6975308641975309
#               precision    recall  f1-score   support
#
#            0       0.82      0.57      0.68        40
#            1       0.75      0.90      0.82        40
#            2       0.63      1.00      0.77        54
#            3       0.00      0.00      0.00        28
#
#     accuracy                           0.70       162
#    macro avg       0.55      0.62      0.57       162
# weighted avg       0.60      0.70      0.63       162
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7318840579710145
#               precision    recall  f1-score   support
#
#            0       0.70      0.79      0.74        33
#            1       0.86      0.84      0.85        50
#            2       0.58      0.93      0.71        27
#            3       0.89      0.29      0.43        28
#
#     accuracy                           0.73       138
#    macro avg       0.76      0.71      0.68       138
# weighted avg       0.77      0.73      0.71       138

# %%
coefficients = model.coef_[0]

# Match coefficients with feature names
feature_names = X.columns

# Plot feature importance
plt.figure(figsize=(5, 3))
plt.barh(feature_names, coefficients, color='skyblue')
plt.xlabel('Coefficient Magnitude')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# # Random Forest

# %%
from hyperopt.pyll import scope
from hyperopt import hp
from hyperopt import fmin, tpe, Trials
from sklearn.model_selection import cross_val_score
#@scope.define
#def intero(a):
#     return int(a)

# %%
from hyperopt import hp

space = {}


#RF
space['n_estimators'] = hp.choice('n_estimators', np.arange(50, 300,1, dtype=int))
space['max_samples'] = hp.uniform('max_samples',0.4,1)
space['max_features'] = hp.uniform('max_features',0.4,1)
space['criterion'] = hp.choice('criterion',['gini','entropy'])
space['max_depth'] = scope.int(hp.quniform('max_depth',3,10,1))
space['ccp_alpha']=hp.uniform('ccp_alpha',0,0.001)
#space['bootstrap']=hp.choice('bootstrap',[False,True])
space['bootstrap'] = hp.choice('bootstrap', [True])
space['min_samples_leaf']=scope.int(hp.quniform('min_samples_leaf',1,5,1))
space['min_samples_split']=scope.int(hp.quniform('min_samples_split',2,10,1))

# %%
from sklearn.ensemble import RandomForestClassifier

def objective(params):
        ######################## hyper params ##############################

        params_RF = {}
        
        params_RF['n_estimators'] = params['n_estimators']
        params_RF['max_samples'] = params['max_samples']
        params_RF['max_features'] = params['max_features']
        params_RF['criterion'] = params['criterion']
        params_RF['max_depth'] = params['max_depth']
        params_RF['ccp_alpha'] = params['ccp_alpha']
        params_RF['bootstrap'] = params['bootstrap']
        params_RF['min_samples_leaf'] = params['min_samples_leaf']
        params_RF['min_samples_split'] = params['min_samples_split']
        

        ########################## Classifier definition ###################

        classifier = RandomForestClassifier(n_jobs=-1)
        classifier.set_params(**params_RF)

        
        ######################### Model testing ################################

        shuffle = StratifiedKFold(n_splits=4, shuffle=True, random_state=12)
        
        

        score = cross_val_score(classifier, X_train, y_train, cv=shuffle, scoring='accuracy', n_jobs=-1)
        score = np.mean(score)
        
        

        return 1 - score

    ######################## Start optim ####################################



# The Trials object will store details of each iteration
trials = Trials()

    # Run the hyperparameter search using the tpe algorithm
best = fmin(objective,
                space,
                algo=tpe.suggest,
                max_evals=500,
                trials=trials)
# Out:
# 100%|█████████████████████| 500/500 [11:21<00:00,  1.36s/trial, best loss: 0.25]

# %%
cat = {}
cat['n_estimators'] = np.arange(50, 150, dtype=int)
cat['bootstrap'] = [False,True]
cat['criterion'] = ['gini','entropy']
best_models = performance_visualizer(trials, 300, choice=True, **cat)

# %%
best_dict = best_models.to_dict(orient='records')[-1]

# %%
best_dict.pop('performance')
# Out:
# 0.75

# %%
best_dict['min_samples_leaf']=int(best_dict['min_samples_leaf'])
best_dict['min_samples_split']=int(best_dict['min_samples_split'])
best_dict['max_depth']=int(best_dict['max_depth'])
best_dict['bootstrap']=True

# %%
print("Classification report on Test set\n")
gs = RandomForestClassifier()
gs.set_params(**best_dict)
gs.fit(X_train,y_train)
y_true, y_pred = y_test, gs.predict(X_test)

accuracy = round(accuracy_score(y_true, y_pred),3)
recall = round(recall_score(y_true, y_pred,average = 'weighted'),3)
precision = round(precision_score(y_true, y_pred,average = 'weighted'),3)
#roc_auc = round(roc_auc_score(y_true, y_pred,multi_class = 'ovr'),3)

print('Accuracy: ',accuracy)
print('Recall: ',recall)
print('Precision: ',precision)
#print('ROC AUC: ',roc_auc)
cm=metrics.confusion_matrix(y_true,y_pred,labels=[0,1,2,3])
df_cm = pd.DataFrame(cm,columns=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'],index=['Healthy control','LRRK2 control','Healthy stim','LRRK2 stim'])
plt.figure(figsize = (5,3))
sns.set(font_scale=1.) # for label size
chart = sns.heatmap(df_cm,annot=True,cmap='Blues')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_yticklabels(chart.get_yticklabels(), rotation=45)
plt.xlabel('Predicted Label',fontdict={'size':20})
plt.ylabel('True Label',fontdict={'size':20})
# Out:
# Classification report on Test set
#
# Accuracy:  0.716
# Recall:  0.716
# Precision:  0.701
# Text(29.749999999999993, 0.5, 'True Label')

# %%
for col in dataset_after.columns.tolist():
    print(col)
    print('Healthy')
    t = plot_boxplot(0,col,dataset,dataset_after)
    print('LRRK2')
    t = plot_boxplot(1,col,dataset,dataset_after)
    print('\n\n')
# Out:
# mu1
# Healthy
# Control:  0.013811112841217736
# Stimulation:  0.04282156812964216
# LRRK2
# Control:  0.22087853674579472
# Stimulation:  0.144709648801504
#
#
#
# lam1
# Healthy
# Control:  1.2467484625850464e-05
# Stimulation:  0.0003252605012341352
# LRRK2
# Control:  0.08433555339985027
# Stimulation:  0.039717629342686106
#
#
#
# mu2
# Healthy
# Control:  0.3044408873432026
# Stimulation:  0.39822187750044513
# LRRK2
# Control:  0.28651762451020857
# Stimulation:  0.20419534158912267
#
#
#
# sigma2
# Healthy
# Control:  0.00013173380855596
# Stimulation:  0.001660302068740765
# LRRK2
# Control:  1.2347930815040378e-06
# Stimulation:  3.843598270274097e-06
#
#
#
# mu3
# Healthy
# Control:  0.0035682518340650407
# Stimulation:  0.016531496969437995
# LRRK2
# Control:  0.2833890486642542
# Stimulation:  0.20139510014098394
#
#
#
# sigma3
# Healthy
# Control:  0.6688255023544767
# Stimulation:  0.7249196951112677
# LRRK2
# Control:  1.128580517245954e-05
# Stimulation:  2.988847835391908e-06
#
#
#
# w1
# Healthy
# Control:  1.8483340644462513e-10
# Stimulation:  1.5796466206657472e-07
# LRRK2
# Control:  0.000261355858576732
# Stimulation:  1.3670727526027352e-05
#
#
#
# w2
# Healthy
# Control:  5.887082412579501e-08
# Stimulation:  8.176950911109851e-06
# LRRK2
# Control:  0.08309741907442122
# Stimulation:  0.05395542925505161
#
#
#
# w3
# Healthy
# Control:  4.916770994309406e-06
# Stimulation:  0.00017123775723591538
# LRRK2
# Control:  0.9652302483539488
# Stimulation:  0.959357574953372
#
#
#
# Target
# Healthy
# Control:  nan
# Stimulation:  nan
# LRRK2
# Control:  nan
# Stimulation:  nan
#
#
#
# Stimulation
# Healthy
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1813: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1813: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /var/folders/d6/n7zzsskd0jv11v_qxbdvkkf40000gn/T/ipykernel_94830/77030850.py:42: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   stat, t = stats.ttest_ind(y_list_param_boxplot[:len1], y_list_param_boxplot[len1:len1+len2])
# /var/folders/d6/n7zzsskd0jv11v_qxbdvkkf40000gn/T/ipykernel_94830/77030850.py:50: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   stat, t = stats.ttest_ind(y_list_param_boxplot[:len1], y_list_param_boxplot[len1+len2:])
# /var/folders/d6/n7zzsskd0jv11v_qxbdvkkf40000gn/T/ipykernel_94830/77030850.py:26: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(5, 5))
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1813: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /var/folders/d6/n7zzsskd0jv11v_qxbdvkkf40000gn/T/ipykernel_94830/77030850.py:50: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   stat, t = stats.ttest_ind(y_list_param_boxplot[:len1], y_list_param_boxplot[len1+len2:])
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1813: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /var/folders/d6/n7zzsskd0jv11v_qxbdvkkf40000gn/T/ipykernel_94830/77030850.py:50: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   stat, t = stats.ttest_ind(y_list_param_boxplot[:len1], y_list_param_boxplot[len1+len2:])
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1813: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /var/folders/d6/n7zzsskd0jv11v_qxbdvkkf40000gn/T/ipykernel_94830/77030850.py:50: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   stat, t = stats.ttest_ind(y_list_param_boxplot[:len1], y_list_param_boxplot[len1+len2:])
# Control:  3.8257676198160716e-44
# Stimulation:  5.051294990552321e-35
# LRRK2
# Control:  2.77630150810389e-25
# Stimulation:  5.290480629918378e-31
#
#
#
# class
# Healthy
# Control:  3.8257676198160716e-44
# Stimulation:  5.051294990552321e-35
# LRRK2
# Control:  2.77630150810389e-25
# Stimulation:  5.290480629918378e-31
# /Users/Gaia_1/anaconda3/lib/python3.11/site-packages/scipy/stats/_morestats.py:1813: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# /var/folders/d6/n7zzsskd0jv11v_qxbdvkkf40000gn/T/ipykernel_94830/77030850.py:42: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   stat, t = stats.ttest_ind(y_list_param_boxplot[:len1], y_list_param_boxplot[len1:len1+len2])
# /var/folders/d6/n7zzsskd0jv11v_qxbdvkkf40000gn/T/ipykernel_94830/77030850.py:50: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   stat, t = stats.ttest_ind(y_list_param_boxplot[:len1], y_list_param_boxplot[len1+len2:])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

def plot_boxplot(target, column, dataset, dataset_after):
    x_list_param_boxplot = []
    y_list_param_boxplot = []

    y_list_param_boxplot.extend(dataset[dataset['Target'] == target][column].values)
    len1 = len(y_list_param_boxplot)
    
    y_list_param_boxplot.extend(dataset_after[(dataset_after['Target'] == target) & (dataset_after['Stimulation'] == 0)][column].values)
    len2 = len(y_list_param_boxplot) - len1
    
    y_list_param_boxplot.extend(dataset_after[(dataset_after['Target'] == target) & (dataset_after['Stimulation'] == 1)][column].values)
    len3 = len(y_list_param_boxplot) - len1 - len2

    strs1 = ["Baseline"] * len1
    strs2 = ["Control"] * len2
    strs3 = ["Stimulated"] * len3

    x_list_param_boxplot.extend(strs1)
    x_list_param_boxplot.extend(strs2)
    x_list_param_boxplot.extend(strs3)

    plt.figure(figsize=(5, 5))
    
    if target == 0:
        title = 'Healthy - ' + column
    else:
        title = 'LRRK2 - ' + column
    plt.title(title)
    sns.boxplot(x=x_list_param_boxplot, y=y_list_param_boxplot)
    
    #return y_list_param_boxplot
    stat, p_original = stats.shapiro(y_list_param_boxplot[:len1])
    stat, p = stats.shapiro(y_list_param_boxplot[len1:len1+len2])
    if (p <= 0.05) and (p_original <= 0.05):
        stat, t = stats.mannwhitneyu(y_list_param_boxplot[:len1], y_list_param_boxplot[len1:len1+len2], alternative='two-sided')
        print('Control: ', t)
    else:
        stat, t = stats.ttest_ind(y_list_param_boxplot[:len1], y_list_param_boxplot[len1:len1+len2])
        print('Control: ', t)

    stat, p = stats.shapiro(y_list_param_boxplot[len1+len2:])
    if (p <= 0.05) and (p_original <= 0.05):
        stat, t = stats.mannwhitneyu(y_list_param_boxplot[:len1], y_list_param_boxplot[len1+len2:], alternative='two-sided')
        print('Stimulation: ', t)
    else:
        stat, t = stats.ttest_ind(y_list_param_boxplot[:len1], y_list_param_boxplot[len1+len2:])
        print('Stimulation: ', t)

# %%
def performance_visualizer(trials_obj,n_models,choice=False,**choice_var):
    
    import pandas as pd
    
    performance = [1-t['result']['loss'] for t in trials_obj.trials]
    
    
    hyperparam= list(trials_obj.trials[0]['misc']['vals'].keys())
    
    values_dict ={}
    
    for i in hyperparam:
        
        values_dict[i]=[]
        
        for j in trials_obj.trials:
            
            if(len(j['misc']['vals'][i])==0):
                
                values_dict[i].append(np.NaN)
                
            else:
            
                values_dict[i].append(j['misc']['vals'][i][0])
                
    out = pd.DataFrame.from_dict(values_dict)
    
    out['performance'] = performance
    
    out=out.sort_values(by=['performance'])
    
    
    if choice:
        
        for i in list(choice_var.keys()):
        
            for j,_ in enumerate(choice_var[i]):
        
                out[i]=out[i].replace(j,choice_var[i][j])
    
    return out.tail(n_models)
